# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer, make_column_selector

from sklearn.model_selection import cross_validate
from sklearn.calibration import LabelEncoder
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform, loguniform

from IPython.display import display

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

import numpy as np
import os
import pandas as pd

import json

# %% [markdown]
# # Data loading

# %%
data_path = "../data"
DATA = []
for file in os.listdir(data_path):
    DATA.append(pd.read_csv(os.path.join(data_path,file)))

# %%
for data in DATA:
    print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           5000 non-null   object
#  1   Location       5000 non-null   object
#  2   MinTemp        4975 non-null   float64
#  3   MaxTemp        4993 non-null   float64
#  4   Rainfall       4955 non-null   float64
#  5   Evaporation    2853 non-null   float64
#  6   Sunshine       2612 non-null   float64
#  7   WindGustDir    4665 non-null   object
#  8   WindGustSpeed  4667 non-null   float64
#  9   WindDir9am     4608 non-null   object
#  10  WindDir3pm     4868 non-null   object
#  11  WindSpeed9am   4961 non-null   float64
#  12  WindSpeed3pm   4914 non-null   float64
#  13  Humidity9am    4943 non-null   float64
#  14  Humidity3pm    4882 non-null   float64
#  15  Pressure9am    4493 non-null   float64
#  16  Pressure3pm    4496 non-null   float64
#  17  Cloud9am       3103 non-null   float64
#  18  Cloud3pm       3009 non-null   float64
#  19  Temp9am        4976 non-null   float64
#  20  Temp3pm        4916 non-null   float64
#  21  RainToday      4955 non-null   object
#  22  RainTomorrow   5000 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 898.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         5000 non-null   int64
#  1   id                                 5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Customer Type                      5000 non-null   object
#  4   Age                                5000 non-null   int64
#  5   Type of Travel                     5000 non-null   object
#  6   Class                              5000 non-null   object
#  7   Flight Distance                    5000 non-null   int64
#  8   Inflight wifi service              5000 non-null   int64
#  9   Departure/Arrival time convenient  5000 non-null   int64
#  10  Ease of Online booking             5000 non-null   int64
#  11  Gate location                      5000 non-null   int64
#  12  Food and drink                     5000 non-null   int64
#  13  Online boarding                    5000 non-null   int64
#  14  Seat comfort                       5000 non-null   int64
#  15  Inflight entertainment             5000 non-null   int64
#  16  On-board service                   5000 non-null   int64
#  17  Leg room service                   5000 non-null   int64
#  18  Baggage handling                   5000 non-null   int64
#  19  Checkin service                    5000 non-null   int64
#  20  Inflight service                   5000 non-null   int64
#  21  Cleanliness                        5000 non-null   int64
#  22  Departure Delay in Minutes         5000 non-null   int64
#  23  Arrival Delay in Minutes           4981 non-null   float64
#  24  satisfaction                       5000 non-null   object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 976.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        5000 non-null   int64
#  1   job        5000 non-null   object
#  2   marital    5000 non-null   object
#  3   education  5000 non-null   object
#  4   default    5000 non-null   object
#  5   balance    5000 non-null   int64
#  6   housing    5000 non-null   object
#  7   loan       5000 non-null   object
#  8   contact    5000 non-null   object
#  9   day        5000 non-null   int64
#  10  month      5000 non-null   object
#  11  duration   5000 non-null   int64
#  12  campaign   5000 non-null   int64
#  13  pdays      5000 non-null   int64
#  14  previous   5000 non-null   int64
#  15  poutcome   5000 non-null   object
#  16  y          5000 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 664.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   season                5000 non-null   object
#  1   cap-diameter          5000 non-null   float64
#  2   cap-shape             5000 non-null   object
#  3   cap-surface           3839 non-null   object
#  4   cap-color             5000 non-null   object
#  5   does-bruise-or-bleed  5000 non-null   object
#  6   gill-attachment       4215 non-null   object
#  7   gill-spacing          2992 non-null   object
#  8   gill-color            5000 non-null   object
#  9   stem-height           5000 non-null   float64
#  10  stem-width            5000 non-null   float64
#  11  stem-root             747 non-null    object
#  12  stem-surface          1934 non-null   object
#  13  stem-color            5000 non-null   object
#  14  veil-type             258 non-null    object
#  15  veil-color            578 non-null    object
#  16  has-ring              5000 non-null   object
#  17  ring-type             4784 non-null   object
#  18  spore-print-color     513 non-null    object
#  19  habitat               5000 non-null   object
#  20  class                 5000 non-null   object
# dtypes: float64(3), object(18)
# memory usage: 820.4+ KB
# None

# %% [markdown]
# # Creating pipelines

# %%
num_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer()),
    ('scale', MinMaxScaler())
])

cat_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy="constant", fill_value="missing")),
    ('one-hot', OneHotEncoder(handle_unknown='ignore'))
])


col_trans = ColumnTransformer([
    ('num_pipeline', num_pipeline, make_column_selector(dtype_include = np.number)),
    ('cat_pipeline', cat_pipeline, make_column_selector(dtype_include = np.object_))
])

# %% [markdown]
# # Defining algorithms for the experiments

# %%
classifiers = [
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    XGBClassifier(),
]

pipelines = []

# %%
for classifier in classifiers:
    pipelines.append((type(classifier), Pipeline([("transformer", col_trans), ("model", classifier)])))

# %%
pipelines
# Out:
# [(sklearn.tree._classes.DecisionTreeClassifier,
#   Pipeline(steps=[('transformer',
#                    ColumnTransformer(transformers=[('num_pipeline',
#                                                     Pipeline(steps=[('impute',
#                                                                      SimpleImputer()),
#                                                                     ('scale',
#                                                                      MinMaxScaler())]),
#                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x00000227F24DB190>),
#                                                    ('cat_pipeline',
#                                                     Pipeline(steps=[('impute',
#                                                                      SimpleImputer(fill_value='missing',
#                                                                                    strategy='constant')),
#                                                                     ('one-hot',
#                                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x00000227F19F6510>)])),
#                   ('model', DecisionTreeClassifier())])),
#  (sklearn.ensemble._forest.RandomForestClassifier,
#   Pipeline(steps=[('transformer',
#                    ColumnTransformer(transformers=[('num_pipeline',
#                                                     Pipeline(steps=[('impute',
#                                                                      SimpleImputer()),
#                                                                     ('scale',
#                                                                      MinMaxScaler())]),
#                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x00000227F24DB190>),
#                                                    ('cat_pipeline',
#                                                     Pipeline(steps=[('impute',
#                                                                      SimpleImputer(fill_value='missing',
#                                                                                    strategy='constant')),
#                                                                     ('one-hot',
#                                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x00000227F19F6510>)])),
#                   ('model', RandomForestClassifier())])),
#  (xgboost.sklearn.XGBClassifier,
#   Pipeline(steps=[('transformer',
#                    ColumnTransformer(transformers=[('num_pipeline',
#                                                     Pipeline(steps=[('impute',
#                                                                      SimpleImputer()),
#                                                                     ('scale',
#                                                                      MinMaxScaler())]),
#                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x00000227F24DB190>),
#                                                    ('cat_pipeline',
#                                                     Pipeline(steps=[('impute',
#                                                                      SimpleImputer(fill_value='missing',
#                                                                                    strategy='constant')),
#                                                                     ('one-hot',
#                                                                      OneHo...
#                                  feature_types=None, gamma=None, grow_policy=None,
#                                  importance_type=None,
#                                  interaction_constraints=None, learning_rate=None,
#                                  max_bin=None, max_cat_threshold=None,
#                                  max_cat_to_onehot=None, max_delta_step=None,
#                                  max_depth=None, max_leaves=None,
#                                  min_child_weight=None, missing=nan,
#                                  monotone_constraints=None, multi_strategy=None,
#                                  n_estimators=None, n_jobs=None,
#                                  num_parallel_tree=None, random_state=None, ...))]))]

# %%
scores = []

for pipe in pipelines:
    pipe_score = []
    for data in DATA:
        score = cross_validate(pipe[1], data.iloc[:, :-1], LabelEncoder().fit_transform(data.iloc[:,-1]), cv = 5, scoring="roc_auc")
        pipe_score.append(score["test_score"].mean())

    scores.append((pipe[0], pipe_score))

# %%
os.listdir("../data")
# Out:
# ['banking_final.csv',
#  'flights_final.csv',
#  'mushrooms_final.csv',
#  'weather_final.csv']

# %%
scores
# Out:
# [(sklearn.tree._classes.DecisionTreeClassifier,
#   [0.6856017268248299,
#    0.9118589079864705,
#    0.9854175523838447,
#    0.6788933190280879]),
#  (sklearn.ensemble._forest.RandomForestClassifier,
#   [0.9175702490538278, 0.9863045570267867, 1.0, 0.8444766611174457]),
#  (xgboost.sklearn.XGBClassifier,
#   [0.9103290065917472,
#    0.9891123481904669,
#    0.9999846138273105,
#    0.8337667489284263])]

# %% [markdown]
# # Random Searching - searching for new defaults

# %%
param_distributions = [
    {
        "model__max_depth": randint(1, 31),
        "model__min_samples_split": randint(2, 61),
        "model__criterion": ["gini", "entropy"],
        "model__min_samples_leaf": randint(1, 61)
    },
    {
        "model__n_estimators": randint(100, 501),      
        "model__min_samples_leaf": randint(1, 251),    
        "model__max_samples": uniform(0.5, 0.5),        
        "model__max_features": uniform(1e-6, 1 - 1e-6)   
    },
    {
        "model__max_depth": randint(1, 20),
        "model__min_child_weight": randint(0, 20),
        "model__eta": uniform(0.01, 0.1), 
        "model__alpha": loguniform(1e-4, 10)
}
]

# %%
best_params = [[],[],[],[]]
pipe_best_models = []
pipe_best_scores = []
history = [[],[],[]]
for i,pipe in enumerate(pipelines):    
    for j,data in enumerate(DATA):
        rs = RandomizedSearchCV(pipe[1], 
                                param_distributions= param_distributions[i],
                                verbose=766751,
                                random_state=42,
                                cv=5,
                                n_iter=1000,
                                n_jobs=-1,
                                scoring="roc_auc"
                                )
        rs.fit(data.iloc[:, :-1],LabelEncoder().fit_transform(data.iloc[:,-1]))
        pipe_best_scores.append(rs.best_score_)
        pipe_best_models.append(rs.best_estimator_)
        best_params[j].append(rs.best_params_)
        history[i].append(rs.cv_results_)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# %%
history_datasets = []
for h in history:
    df = pd.concat([pd.DataFrame(h[i]) for i in range(len(h))], keys=range(len(h)), names=['dataset'])
    df = df.reset_index()
    df.drop(columns='level_1', inplace=True)
    history_datasets.append(df)
print(f"{pipelines[0][0]} shape: {history_datasets[0].shape}")
print(f"{pipelines[1][0]} shape: {history_datasets[1].shape}")
print(f"{pipelines[2][0]} shape: {history_datasets[2].shape}")
# Out:
# <class 'sklearn.tree._classes.DecisionTreeClassifier'> shape: (4000, 18)
# <class 'sklearn.ensemble._forest.RandomForestClassifier'> shape: (4000, 18)
# <class 'xgboost.sklearn.XGBClassifier'> shape: (4000, 18)

# %%
model_names = ['DecisionTree','RandomForest','XGBoost']

# %% [markdown]
# # Saving history to csv files

# %%
for i, df in enumerate(history_datasets):
    df.to_csv(f'../history/history_dataset_{model_names[i]}.csv', index=False)

# %% [markdown]
# # Reading history from csv

# %%
history_DecisionTree = pd.read_csv('../history/history_dataset_DecisionTree.csv')
history_RandomForest = pd.read_csv('../history/history_dataset_RandomForest.csv')
history_XGBoost = pd.read_csv('../history/history_dataset_XGBoost.csv')

# %%
pd.set_option('display.max_colwidth', None)

print(history_DecisionTree[history_DecisionTree['mean_test_score'] == 0.5].shape[0])
print(history_RandomForest[history_RandomForest['mean_test_score'] == 0.5].shape[0])
print(history_XGBoost[history_XGBoost['mean_test_score'] == 0.5].shape[0])
# Out:
# 0
# 0
# 0

# %%
history_XGBoost.shape
# Out:
# (4000, 18)

# %%
history_RandomForest.head()
# Out:
#    dataset  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0       1.289590      0.006801         0.043627        0.006232
# 1        0       2.010566      0.072784         0.064181        0.010854
# 2        0       1.672137      0.018012         0.075803        0.002932
# 3        0       8.327508      0.266172         0.105625        0.010530
# 4        0       3.010676      0.071347         0.065256        0.007643
#
#    param_model__max_features  param_model__max_samples  \
# 0                   0.374541                  0.975357
# 1                   0.598659                  0.578009
# 2                   0.058085                  0.933088
# 3                   0.708073                  0.510292
# 4                   0.832443                  0.606170
#
#    param_model__min_samples_leaf  param_model__n_estimators  \
# 0                            107                        171
# 1                            211                        314
# 2                            100                        459
# 3                              2                        443
# 4                            192                        376
#
#                                                                                                                                                params  \
# 0   {'model__max_features': 0.3745407443072436, 'model__max_samples': 0.9753571532049581, 'model__min_samples_leaf': 107, 'model__n_estimators': 171}
# 1   {'model__max_features': 0.5986588855385524, 'model__max_samples': 0.5780093202212182, 'model__min_samples_leaf': 211, 'model__n_estimators': 314}
# 2  {'model__max_features': 0.05808455408458729, 'model__max_samples': 0.9330880728874675, 'model__min_samples_leaf': 100, 'model__n_estimators': 459}
# 3     {'model__max_features': 0.7080728697234677, 'model__max_samples': 0.5102922471479012, 'model__min_samples_leaf': 2, 'model__n_estimators': 443}
# 4    {'model__max_features': 0.832442808357781, 'model__max_samples': 0.6061695553391381, 'model__min_samples_leaf': 192, 'model__n_estimators': 376}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.899256           0.880371           0.878696           0.852988
# 1           0.858273           0.854135           0.854909           0.819419
# 2           0.847102           0.862086           0.859705           0.834790
# 3           0.932011           0.941071           0.910503           0.913722
# 4           0.862619           0.852963           0.852562           0.819400
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.882239         0.878710        0.014826              319
# 1           0.844958         0.846339        0.014165              899
# 2           0.858834         0.852504        0.010264              794
# 3           0.928130         0.925087        0.011442                5
# 4           0.840124         0.845533        0.014891              917

# %%
history_XGBoost.head()
# Out:
#    dataset  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0       0.165986      0.013078         0.015945        0.005451
# 1        0       0.160500      0.013494         0.011362        0.004381
# 2        0       0.134376      0.005874         0.014310        0.003767
# 3        0       0.140599      0.005001         0.016829        0.010731
# 4        0       0.145276      0.009771         0.017556        0.002008
#
#    param_model__alpha  param_model__eta  param_model__max_depth  \
# 0          383.530058          0.950762                      11
# 1          613.027264          0.156843                       3
# 2           59.478595          0.866307                       4
# 3          725.067296          0.021541                       2
# 4          852.422241          0.213108                      12
#
#    param_model__min_child_weight  \
# 0                             72
# 1                             87
# 2                            104
# 3                             88
# 4                             21
#
#                                                                                                                          params  \
# 0  {'model__alpha': 383.5300582621992, 'model__eta': 0.9507624369700627, 'model__max_depth': 11, 'model__min_child_weight': 72}
# 1  {'model__alpha': 613.0272643802655, 'model__eta': 0.15684284098887946, 'model__max_depth': 3, 'model__min_child_weight': 87}
# 2  {'model__alpha': 59.47859542273625, 'model__eta': 0.8663068331325768, 'model__max_depth': 4, 'model__min_child_weight': 104}
# 3   {'model__alpha': 725.0672962256506, 'model__eta': 0.0215409547505917, 'model__max_depth': 2, 'model__min_child_weight': 88}
# 4  {'model__alpha': 852.4222407421319, 'model__eta': 0.2131083107655044, 'model__max_depth': 12, 'model__min_child_weight': 21}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.500000           0.500000           0.500000           0.500000
# 1           0.500000           0.500000           0.500000           0.500000
# 2           0.840699           0.839393           0.830057           0.802664
# 3           0.500000           0.500000           0.500000           0.500000
# 4           0.500000           0.500000           0.500000           0.500000
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.500000         0.500000        0.000000              714
# 1           0.500000         0.500000        0.000000              714
# 2           0.842297         0.831022        0.014805              160
# 3           0.500000         0.500000        0.000000              714
# 4           0.500000         0.500000        0.000000              714

# %% [markdown]
# # New defaults below

# %%
def get_best_params_overall(df):
    df['params_str'] = df['params'].apply(lambda x: str(x))
    grouped_mean = df.groupby(['params_str'])['mean_test_score'].mean().reset_index()
    grouped_mean.sort_values(by='mean_test_score', ascending=False, inplace=True)
    return grouped_mean.iloc[0, 0], grouped_mean.iloc[0, 1]

# %%
best_params_DecisionTree, best_params_DecisionTree_score = get_best_params_overall(history_DecisionTree)
print(f"Best params for DecisionTree: {best_params_DecisionTree}") 
print(f"with score: {best_params_DecisionTree_score}")
# Out:
# Best params for DecisionTree: {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# with score: 0.9036077061469168

# %%
best_params_RandomForest, best_params_RandomForest_score = get_best_params_overall(history_RandomForest)
print(f"Best params for RandomForest: {best_params_RandomForest}") 
print(f"with score: {best_params_RandomForest_score}")
# Out:
# Best params for RandomForest: {'model__max_features': 0.49816568848070625, 'model__max_samples': 0.738105348394507, 'model__min_samples_leaf': 3, 'model__n_estimators': 478}
# with score: 0.9403427016521764

# %%
best_params_XGBoost, best_params_XGBoost_score = get_best_params_overall(history_XGBoost)
print(f"Best params for XGBoost: {best_params_XGBoost}")
print(f"With score: {best_params_XGBoost_score}")
# Out:
# Best params for XGBoost: {'model__alpha': 1.2481751282245537, 'model__eta': 0.09798219139516953, 'model__max_depth': 16, 'model__min_child_weight': 0}
# With score: 0.9396460899136064

# %% [markdown]
# # Tunability

# %% [markdown]
# ##### Now let's compute tunability of each of the ML algorithms. We'll start with looking for the optimal configuration of the hyperparameters for each of the dataset

# %%
def get_best_params_per_dataset(df):
    df['params_str'] = df['params'].apply(lambda x: str(x))
    best_params_per_dataset = df.sort_values(['dataset', 'rank_test_score'], ascending=[True, True]).groupby('dataset').first().reset_index()
    best_params_per_dataset.rename(columns={'params_str': 'best_params', 'mean_test_score': 'best_score'}, inplace=True)
    best_params_per_dataset = best_params_per_dataset[['dataset', 'best_params', 'best_score']]
    default_params, _ = get_best_params_overall(df)
    score_for_default_params = df[df['params_str'] == default_params][['dataset', 'mean_test_score']].rename(columns={'mean_test_score': 'default_score'})
    best_params_per_dataset = best_params_per_dataset.merge(score_for_default_params, on='dataset', how='left')
    best_params_per_dataset['abs_tunability'] = best_params_per_dataset['best_score'] - best_params_per_dataset['default_score']
    best_params_per_dataset['rel_tunability (%)'] = best_params_per_dataset['abs_tunability'] / best_params_per_dataset['default_score'] * 100 
    return best_params_per_dataset

# %% [markdown]
# ### Best configuration of the hyperparameters for each of the dataset is presented below with it's tunability percentage

# %%
best_params_per_dataset_DecisionTree = get_best_params_per_dataset(history_DecisionTree)
best_params_per_dataset_DecisionTree
# Out:
#    dataset  \
# 0        0
# 1        1
# 2        2
# 3        3
#
#                                                                                                               best_params  \
# 0      {'model__criterion': 'gini', 'model__max_depth': 16, 'model__min_samples_leaf': 1, 'model__min_samples_split': 54}
# 1  {'model__criterion': 'entropy', 'model__max_depth': 27, 'model__min_samples_leaf': 36, 'model__min_samples_split': 20}
# 2      {'model__criterion': 'gini', 'model__max_depth': 27, 'model__min_samples_leaf': 3, 'model__min_samples_split': 18}
# 3   {'model__criterion': 'entropy', 'model__max_depth': 7, 'model__min_samples_leaf': 45, 'model__min_samples_split': 47}
#
#    best_score  default_score  abs_tunability  rel_tunability (%)
# 0    0.875509       0.869608        0.005901            0.678539
# 1    0.976032       0.971264        0.004768            0.490882
# 2    0.987830       0.976445        0.011385            1.165960
# 3    0.816965       0.797114        0.019851            2.490372

# %%
best_params_per_dataset_RandomForest = get_best_params_per_dataset(history_RandomForest)
best_params_per_dataset_RandomForest
# Out:
#    dataset  \
# 0        0
# 1        1
# 2        2
# 3        3
#
#                                                                                                                                         best_params  \
# 0   {'model__max_features': 0.2487150238733573, 'model__max_samples': 0.8085724933020151, 'model__min_samples_leaf': 1, 'model__n_estimators': 412}
# 1  {'model__max_features': 0.33700383942810985, 'model__max_samples': 0.9144416829413047, 'model__min_samples_leaf': 1, 'model__n_estimators': 232}
# 2  {'model__max_features': 0.08962724952860296, 'model__max_samples': 0.8588178929543148, 'model__min_samples_leaf': 2, 'model__n_estimators': 176}
# 3   {'model__max_features': 0.5387022592509163, 'model__max_samples': 0.7489062540171452, 'model__min_samples_leaf': 6, 'model__n_estimators': 266}
#
#    best_score  default_score  abs_tunability  rel_tunability (%)
# 0    0.925725       0.925189        0.000536            0.057961
# 1    0.988073       0.986360        0.001713            0.173679
# 2    0.999999       0.999973        0.000026            0.002591
# 3    0.851208       0.849848        0.001359            0.159969

# %%
best_params_per_dataset_XGBoost = get_best_params_per_dataset(history_XGBoost)
best_params_per_dataset_XGBoost
# Out:
#    dataset  \
# 0        0
# 1        1
# 2        2
# 3        3
#
#                                                                                                                         best_params  \
# 0     {'model__alpha': 1.2481751282245537, 'model__eta': 0.09798219139516953, 'model__max_depth': 16, 'model__min_child_weight': 0}
# 1      {'model__alpha': 4.384474294125061, 'model__eta': 0.10963982936790555, 'model__max_depth': 12, 'model__min_child_weight': 2}
# 2   {'model__alpha': 0.005033310605507513, 'model__eta': 0.10404485057361726, 'model__max_depth': 11, 'model__min_child_weight': 0}
# 3  {'model__alpha': 0.04733513937713775, 'model__eta': 0.057661948412641204, 'model__max_depth': 13, 'model__min_child_weight': 11}
#
#    best_score  default_score  abs_tunability  rel_tunability (%)
# 0    0.920403       0.920403        0.000000            0.000000
# 1    0.990395       0.990130        0.000266            0.026820
# 2    0.999994       0.999985        0.000009            0.000891
# 3    0.850615       0.848066        0.002550            0.300633

# %% [markdown]
# # Testing the tunability of individual hyperparameters

# %%
history_DecisionTree = pd.read_csv('../history/history_dataset_DecisionTree.csv')
history_RandomForest = pd.read_csv('../history/history_dataset_RandomForest.csv')
history_XGBoost = pd.read_csv('../history/history_dataset_XGBoost.csv')

# %%
def do_random_search(clf, param_distributions):
    global DATA 
    history = []
    for j,data in enumerate(DATA):
        rs = RandomizedSearchCV(clf, 
                                param_distributions= param_distributions,
                                #verbose=766751,
                                random_state=42,
                                cv=5,
                                n_iter=200,
                                n_jobs=-1,
                                scoring="roc_auc"
                                )
        rs.fit(data.iloc[:, :-1],LabelEncoder().fit_transform(data.iloc[:,-1]))
        history.append(rs.cv_results_)
    return history

# %% [markdown]
# ## Decision tree

# %%
param_distributions_Decision_Tree = param_distributions[0]
tunable_parameters_DT = param_distributions_Decision_Tree.keys()
tunable_parameters_DT
# Out:
# dict_keys(['model__max_depth', 'model__min_samples_split', 'model__criterion', 'model__min_samples_leaf'])

# %%
param_distributions_Decision_Tree
# Out:
# {'model__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x133824f10>,
#  'model__min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x132188e90>,
#  'model__criterion': ['gini', 'entropy'],
#  'model__min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x133826a10>}

# %%
best_params_DT_dict = json.loads(best_params_DecisionTree.replace("'", "\""))
best_params_DT_dict = {key: [value] for key, value in best_params_DT_dict.items()}
best_params_DT_dict
# Out:
# {'model__criterion': ['gini'],
#  'model__max_depth': [17],
#  'model__min_samples_leaf': [10],
#  'model__min_samples_split': [58]}

# %%
param_history = {}
for param in tunable_parameters_DT:
    temp_param_grid = {**best_params_DT_dict} 
    temp_param_grid.update({param:param_distributions_Decision_Tree[param]})
    print(temp_param_grid)
    print("Testing param", param)
    history = do_random_search(pipelines[0][1], temp_param_grid)
    param_history.update({param: history})
# Out:
# {'model__criterion': ['gini'], 'model__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000208E79B4550>, 'model__min_samples_leaf': [10], 'model__min_samples_split': [58]}
# Testing param model__max_depth
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'model__criterion': ['gini'], 'model__max_depth': [17], 'model__min_samples_leaf': [10], 'model__min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000208E6845090>}
# Testing param model__min_samples_split
# {'model__criterion': ['gini', 'entropy'], 'model__max_depth': [17], 'model__min_samples_leaf': [10], 'model__min_samples_split': [58]}
# Testing param model__criterion
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\sklearn\model_selection\_search.py:320: UserWarning: The total space of parameters 2 is smaller than n_iter=200. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\sklearn\model_selection\_search.py:320: UserWarning: The total space of parameters 2 is smaller than n_iter=200. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\sklearn\model_selection\_search.py:320: UserWarning: The total space of parameters 2 is smaller than n_iter=200. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\sklearn\model_selection\_search.py:320: UserWarning: The total space of parameters 2 is smaller than n_iter=200. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# {'model__criterion': ['gini'], 'model__max_depth': [17], 'model__min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000208E79B6710>, 'model__min_samples_split': [58]}
# Testing param model__min_samples_leaf

# %%
len(param_history["model__max_depth"][])
# Out:
# 17

# %%
params_history_frames_DT = {}
for param, history in param_history.items():
    df = pd.concat([pd.DataFrame(history[i]) for i in range(len(history))], keys=range(len(history)), names=['dataset'])
    df = df.reset_index()
    df.drop(columns='level_1', inplace=True)
    params_history_frames_DT.update({param:df})

# %%
params_history_frames_DT["model__criterion"]
# Out:
#    dataset  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0       0.105099      0.008780         0.015429        0.003671
# 1        0       0.114604      0.012346         0.012940        0.002294
# 2        1       0.040952      0.007055         0.006948        0.001580
# 3        1       0.044230      0.005163         0.005204        0.000452
# 4        2       0.046389      0.003247         0.011586        0.004546
# 5        2       0.045041      0.002042         0.006710        0.001326
# 6        3       0.077533      0.007429         0.011376        0.002776
# 7        3       0.080284      0.009185         0.008840        0.000378
#
#    param_model__min_samples_split  param_model__min_samples_leaf  \
# 0                              58                             10
# 1                              58                             10
# 2                              58                             10
# 3                              58                             10
# 4                              58                             10
# 5                              58                             10
# 6                              58                             10
# 7                              58                             10
#
#    param_model__max_depth param_model__criterion  \
# 0                      17                   gini
# 1                      17                entropy
# 2                      17                   gini
# 3                      17                entropy
# 4                      17                   gini
# 5                      17                entropy
# 6                      17                   gini
# 7                      17                entropy
#
#                                                                                                                    params  \
# 0     {'model__min_samples_split': 58, 'model__min_samples_leaf': 10, 'model__max_depth': 17, 'model__criterion': 'gini'}
# 1  {'model__min_samples_split': 58, 'model__min_samples_leaf': 10, 'model__max_depth': 17, 'model__criterion': 'entropy'}
# 2     {'model__min_samples_split': 58, 'model__min_samples_leaf': 10, 'model__max_depth': 17, 'model__criterion': 'gini'}
# 3  {'model__min_samples_split': 58, 'model__min_samples_leaf': 10, 'model__max_depth': 17, 'model__criterion': 'entropy'}
# 4     {'model__min_samples_split': 58, 'model__min_samples_leaf': 10, 'model__max_depth': 17, 'model__criterion': 'gini'}
# 5  {'model__min_samples_split': 58, 'model__min_samples_leaf': 10, 'model__max_depth': 17, 'model__criterion': 'entropy'}
# 6     {'model__min_samples_split': 58, 'model__min_samples_leaf': 10, 'model__max_depth': 17, 'model__criterion': 'gini'}
# 7  {'model__min_samples_split': 58, 'model__min_samples_leaf': 10, 'model__max_depth': 17, 'model__criterion': 'entropy'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.787883           0.800885           0.789166           0.804345
# 1           0.771594           0.789281           0.775129           0.783114
# 2           0.975798           0.971953           0.964360           0.975191
# 3           0.981627           0.973520           0.967011           0.976724
# 4           0.861568           0.902895           0.847828           0.873421
# 5           0.855224           0.894338           0.847901           0.851003
# 6           0.978860           0.988254           0.971594           0.969296
# 7           0.975028           0.980824           0.973653           0.986539
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.807687         0.797993        0.008035                1
# 1           0.793746         0.782573        0.008320                2
# 2           0.968272         0.971114        0.004312                2
# 3           0.973755         0.974527        0.004761                1
# 4           0.863093         0.869761        0.018460                1
# 5           0.868770         0.863447        0.017010                2
# 6           0.973894         0.976380        0.006729                2
# 7           0.975463         0.978301        0.004788                1

# %%
params_history_frames_DT['model__max_depth']
# Out:
#      dataset  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0       0.107094      0.016469         0.012695        0.002983
# 1          0       0.122068      0.007226         0.017022        0.004310
# 2          0       0.122834      0.010963         0.014593        0.004015
# 3          0       0.102597      0.011336         0.012477        0.003648
# 4          0       0.094956      0.013095         0.009644        0.001571
# ..       ...            ...           ...              ...             ...
# 795        3       0.083718      0.008882         0.012290        0.002154
# 796        3       0.052561      0.008390         0.012371        0.003251
# 797        3       0.093595      0.002104         0.009494        0.001203
# 798        3       0.050612      0.004125         0.010582        0.002098
# 799        3       0.083870      0.004224         0.009993        0.002250
#
#     param_model__criterion  param_model__max_depth  \
# 0                     gini                       7
# 1                     gini                      20
# 2                     gini                      29
# 3                     gini                      15
# 4                     gini                      11
# ..                     ...                     ...
# 795                   gini                      29
# 796                   gini                       4
# 797                   gini                      30
# 798                   gini                       5
# 799                   gini                      23
#
#      param_model__min_samples_leaf  param_model__min_samples_split  \
# 0                               10                              58
# 1                               10                              58
# 2                               10                              58
# 3                               10                              58
# 4                               10                              58
# ..                             ...                             ...
# 795                             10                              58
# 796                             10                              58
# 797                             10                              58
# 798                             10                              58
# 799                             10                              58
#
#                                                                                                                   params  \
# 0     {'model__criterion': 'gini', 'model__max_depth': 7, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# 1    {'model__criterion': 'gini', 'model__max_depth': 20, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# 2    {'model__criterion': 'gini', 'model__max_depth': 29, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# 3    {'model__criterion': 'gini', 'model__max_depth': 15, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# 4    {'model__criterion': 'gini', 'model__max_depth': 11, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# ..                                                                                                                   ...
# 795  {'model__criterion': 'gini', 'model__max_depth': 29, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# 796   {'model__criterion': 'gini', 'model__max_depth': 4, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# 797  {'model__criterion': 'gini', 'model__max_depth': 30, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# 798   {'model__criterion': 'gini', 'model__max_depth': 5, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
# 799  {'model__criterion': 'gini', 'model__max_depth': 23, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.787423           0.812503           0.797988
# 1             0.788119           0.795348           0.789710
# 2             0.787998           0.798676           0.789166
# 3             0.783157           0.794033           0.788769
# 4             0.791269           0.798647           0.799395
# ..                 ...                ...                ...
# 795           0.983842           0.989135           0.977992
# 796           0.777016           0.772864           0.771021
# 797           0.983842           0.989135           0.977992
# 798           0.816716           0.815860           0.822976
# 799           0.983842           0.989135           0.978231
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0             0.813216           0.821115         0.806449        0.012092
# 1             0.801270           0.799576         0.794804        0.005206
# 2             0.797537           0.796837         0.794043        0.004512
# 3             0.808174           0.801999         0.795226        0.008970
# 4             0.804118           0.793543         0.797394        0.004542
# ..                 ...                ...              ...             ...
# 795           0.969296           0.980356         0.980124        0.006586
# 796           0.777688           0.753694         0.770457        0.008746
# 797           0.969430           0.980170         0.980114        0.006541
# 798           0.829819           0.790297         0.815134        0.013395
# 799           0.969296           0.980170         0.980135        0.006570
#
#      rank_test_score
# 0                 14
# 1                125
# 2                147
# 3                107
# 4                 56
# ..               ...
# 795               57
# 796              172
# 797               65
# 798              166
# 799               44
#
# [800 rows x 18 columns]

# %%
params_history_frames_DT['model__min_samples_leaf']
# Out:
#      dataset  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0       0.084143      0.006159         0.015894        0.003470
# 1          0       0.082901      0.002799         0.019535        0.004657
# 2          0       0.118521      0.006652         0.016944        0.003846
# 3          0       0.111362      0.003045         0.012652        0.002128
# 4          0       0.102354      0.007219         0.014424        0.003492
# ..       ...            ...           ...              ...             ...
# 795        3       0.087806      0.010458         0.013088        0.002083
# 796        3       0.089958      0.005880         0.014912        0.003691
# 797        3       0.090991      0.012452         0.013759        0.002187
# 798        3       0.091313      0.007543         0.014628        0.003508
# 799        3       0.089942      0.011846         0.011092        0.002543
#
#     param_model__criterion  param_model__max_depth  \
# 0                     gini                      17
# 1                     gini                      17
# 2                     gini                      17
# 3                     gini                      17
# 4                     gini                      17
# ..                     ...                     ...
# 795                   gini                      17
# 796                   gini                      17
# 797                   gini                      17
# 798                   gini                      17
# 799                   gini                      17
#
#      param_model__min_samples_leaf  param_model__min_samples_split  \
# 0                               39                              58
# 1                               52                              58
# 2                               29                              58
# 3                               15                              58
# 4                               43                              58
# ..                             ...                             ...
# 795                             43                              58
# 796                             29                              58
# 797                             36                              58
# 798                             13                              58
# 799                             32                              58
#
#                                                                                                                   params  \
# 0    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 39, 'model__min_samples_split': 58}
# 1    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 52, 'model__min_samples_split': 58}
# 2    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 29, 'model__min_samples_split': 58}
# 3    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 15, 'model__min_samples_split': 58}
# 4    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 43, 'model__min_samples_split': 58}
# ..                                                                                                                   ...
# 795  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 43, 'model__min_samples_split': 58}
# 796  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 29, 'model__min_samples_split': 58}
# 797  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 36, 'model__min_samples_split': 58}
# 798  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 13, 'model__min_samples_split': 58}
# 799  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 32, 'model__min_samples_split': 58}
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.797292           0.810846           0.798794
# 1             0.797548           0.806310           0.795543
# 2             0.793556           0.798264           0.800928
# 3             0.784932           0.801552           0.798437
# 4             0.801661           0.810440           0.796803
# ..                 ...                ...                ...
# 795           0.927517           0.936200           0.944952
# 796           0.951572           0.962508           0.950054
# 797           0.948896           0.947442           0.935759
# 798           0.973505           0.987007           0.963525
# 799           0.949667           0.955583           0.944588
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0             0.826523           0.826962         0.812083        0.012859
# 1             0.828683           0.820422         0.809701        0.012922
# 2             0.813783           0.825703         0.806447        0.011732
# 3             0.825930           0.808774         0.803925        0.013448
# 4             0.829411           0.824846         0.812632        0.012700
# ..                 ...                ...              ...             ...
# 795           0.922405           0.952967         0.936808        0.011150
# 796           0.954153           0.957318         0.955121        0.004441
# 797           0.938638           0.939536         0.942054        0.005167
# 798           0.970254           0.972125         0.973283        0.007670
# 799           0.948430           0.949764         0.949606        0.003530
#
#      rank_test_score
# 0                 18
# 1                 59
# 2                119
# 3                147
# 4                 13
# ..               ...
# 795              141
# 796               98
# 797              121
# 798               41
# 799              104
#
# [800 rows x 18 columns]

# %%
params_history_frames_DT['model__min_samples_split']
# Out:
#      dataset  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0       0.104002      0.008128         0.015526        0.002978
# 1          0       0.125067      0.012540         0.013333        0.003034
# 2          0       0.160459      0.020617         0.014780        0.004172
# 3          0       0.141070      0.010011         0.015746        0.002139
# 4          0       0.119967      0.012509         0.015516        0.003821
# ..       ...            ...           ...              ...             ...
# 795        3       0.115553      0.017846         0.029131        0.022153
# 796        3       0.130162      0.012242         0.016124        0.006800
# 797        3       0.099085      0.004707         0.015498        0.004152
# 798        3       0.093473      0.007794         0.012530        0.002267
# 799        3       0.086037      0.006252         0.009925        0.001523
#
#     param_model__criterion  param_model__max_depth  \
# 0                     gini                      17
# 1                     gini                      17
# 2                     gini                      17
# 3                     gini                      17
# 4                     gini                      17
# ..                     ...                     ...
# 795                   gini                      17
# 796                   gini                      17
# 797                   gini                      17
# 798                   gini                      17
# 799                   gini                      17
#
#      param_model__min_samples_leaf  param_model__min_samples_split  \
# 0                               10                              40
# 1                               10                              53
# 2                               10                              30
# 3                               10                              16
# 4                               10                              44
# ..                             ...                             ...
# 795                             10                              29
# 796                             10                               3
# 797                             10                              43
# 798                             10                              46
# 799                             10                              58
#
#                                                                                                                   params  \
# 0    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 40}
# 1    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 53}
# 2    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 30}
# 3    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 16}
# 4    {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 44}
# ..                                                                                                                   ...
# 795  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 29}
# 796   {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 3}
# 797  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 43}
# 798  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 46}
# 799  {'model__criterion': 'gini', 'model__max_depth': 17, 'model__min_samples_leaf': 10, 'model__min_samples_split': 58}
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.764943           0.796521           0.765789
# 1             0.775253           0.789669           0.781699
# 2             0.760258           0.780376           0.753331
# 3             0.752134           0.776199           0.745130
# 4             0.770317           0.795258           0.768850
# ..                 ...                ...                ...
# 795           0.982429           0.990588           0.979028
# 796           0.983239           0.990349           0.980472
# 797           0.978965           0.990485           0.975483
# 798           0.978767           0.990485           0.975483
# 799           0.978860           0.988254           0.971594
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0             0.787509           0.794672         0.781887        0.013824
# 1             0.801932           0.797884         0.789287        0.009884
# 2             0.773156           0.780169         0.769458        0.010884
# 3             0.760574           0.780668         0.762941        0.013636
# 4             0.789057           0.797720         0.784240        0.012305
# ..                 ...                ...              ...             ...
# 795           0.972740           0.982205         0.981398        0.005775
# 796           0.975890           0.982976         0.982585        0.004694
# 797           0.971258           0.977482         0.978735        0.006421
# 798           0.971254           0.976722         0.978542        0.006457
# 799           0.969296           0.973671         0.976335        0.006746
#
#      rank_test_score
# 0                 57
# 1                 31
# 2                103
# 3                143
# 4                 49
# ..               ...
# 795               98
# 796               65
# 797              144
# 798              161
# 799              193
#
# [800 rows x 18 columns]

# %%
def get_best_params_per_dataset_for_measuring_param_tunability(df, history):
    df['params_str'] = df['params'].apply(lambda x: str(x))
    best_params_per_dataset = df.sort_values(['dataset', 'rank_test_score'], ascending=[True, True]).groupby('dataset').first().reset_index()
    best_params_per_dataset.rename(columns={'params_str': 'best_params', 'mean_test_score': 'best_score'}, inplace=True)
    best_params_per_dataset = best_params_per_dataset[['dataset', 'best_params', 'best_score']]
    default_params, _ = get_best_params_overall(history)
    score_for_default_params = history[history['params_str'] == default_params][['dataset', 'mean_test_score']].rename(columns={'mean_test_score': 'default_score'})
    best_params_per_dataset = best_params_per_dataset.merge(score_for_default_params, on='dataset', how='left')
    condition = best_params_per_dataset['best_score'] < best_params_per_dataset['default_score']
    best_params_per_dataset.loc[condition, 'best_score'] = best_params_per_dataset['default_score']
    best_params_per_dataset.loc[condition, 'best_params'] = default_params
    best_params_per_dataset['abs_tunability'] = (best_params_per_dataset['best_score'] - best_params_per_dataset['default_score'])
    best_params_per_dataset['rel_tunability (%)'] = best_params_per_dataset['abs_tunability'] / best_params_per_dataset['default_score'] * 100 
    return best_params_per_dataset

# %% [markdown]
# ### Saving results to file

# %%
for param, history in params_history_frames_DT.items():
    print(history.shape)
    history.to_csv(f'../history/history_hyperparameter_tuning_DT_{param}.csv', index=False)
# Out:
# (800, 19)
# (800, 19)
# (8, 19)
# (800, 19)

# %%
params_history_frames_DT = {}
for param in ["model__max_depth", "model__min_samples_split","model__criterion","model__min_samples_leaf"]:
    file_path = f'../history/history_hyperparameter_tuning_DT_{param}.csv'
    if os.path.exists(file_path):
        params_history_frames_DT[param] = pd.read_csv(file_path)

# %% [markdown]
# # Chosen hyperparameters with tunability are presented below

# %% [markdown]
# ## Short reminder. First results are for **Decision Tree**

# %%
for param in tunable_parameters_DT:
    print("Results for param:", param)
    display(get_best_params_per_dataset_for_measuring_param_tunability(params_history_frames_DT[param], history_DecisionTree).head(10))
    print(get_best_params_per_dataset_for_measuring_param_tunability(params_history_frames_DT[param], history_DecisionTree)['rel_tunability (%)'].mean())
# Out:
# Results for param: model__max_depth
#    dataset                                        best_params  best_score  \
# 0        0  {'model__criterion': 'gini', 'model__max_depth...    0.870655
# 1        1  {'model__criterion': 'gini', 'model__max_depth...    0.972119
# 2        2  {'model__criterion': 'gini', 'model__max_depth...    0.980219
# 3        3  {'model__criterion': 'gini', 'model__max_depth...    0.809058
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.869608        0.001046            0.120325
# 1       0.971264        0.000855            0.088001
# 2       0.976445        0.003774            0.386553
# 3       0.797114        0.011944            1.498442
# 0.5233300674738862
# Results for param: model__min_samples_split
#    dataset                                        best_params  best_score  \
# 0        0  {'model__criterion': 'gini', 'model__max_depth...    0.869703
# 1        1  {'model__criterion': 'gini', 'model__max_depth...    0.971474
# 2        2  {'model__criterion': 'gini', 'model__max_depth...    0.983828
# 3        3  {'model__criterion': 'gini', 'model__max_depth...    0.797682
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.869608        0.000095            0.010908
# 1       0.971264        0.000210            0.021614
# 2       0.976445        0.007383            0.756104
# 3       0.797114        0.000568            0.071285
# 0.21497769336818326
# Results for param: model__criterion
#    dataset                                        best_params  best_score  \
# 0        0  {'model__min_samples_split': 58, 'model__min_s...    0.869608
# 1        1  {'model__min_samples_split': 58, 'model__min_s...    0.975514
# 2        2  {'model__min_samples_split': 58, 'model__min_s...    0.979113
# 3        3  {'model__criterion': 'gini', 'model__max_depth...    0.797114
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.869608        0.000000            0.000000
# 1       0.971264        0.004250            0.437538
# 2       0.976445        0.002669            0.273307
# 3       0.797114        0.000000            0.000000
# 0.17771128119431467
# Results for param: model__min_samples_leaf
#    dataset                                        best_params  best_score  \
# 0        0  {'model__criterion': 'gini', 'model__max_depth...    0.873927
# 1        1  {'model__criterion': 'gini', 'model__max_depth...    0.973532
# 2        2  {'model__criterion': 'gini', 'model__max_depth...    0.981708
# 3        3  {'model__criterion': 'gini', 'model__max_depth...    0.813505
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.869608        0.004319            0.496660
# 1       0.971264        0.002267            0.233443
# 2       0.976445        0.005264            0.539067
# 3       0.797114        0.016391            2.056296
# 0.8313664969773633

# %% [markdown]
# ## **Random Forest**

# %%
param_distributions_Random_Forest = param_distributions[1]
tunable_parameters_RF = param_distributions_Random_Forest.keys()
tunable_parameters_RF
# Out:
# dict_keys(['model__n_estimators', 'model__min_samples_leaf', 'model__max_samples', 'model__max_features'])

# %%
best_params_RF_dict = json.loads(best_params_RandomForest.replace("'", "\""))
best_params_RF_dict = {key: [value] for key, value in best_params_RF_dict.items()}
best_params_RF_dict
# Out:
# {'model__max_features': [0.49816568848070625],
#  'model__max_samples': [0.738105348394507],
#  'model__min_samples_leaf': [3],
#  'model__n_estimators': [478]}

# %%
param_history = {}
for param in tunable_parameters_RF:
    temp_param_grid = {**best_params_RF_dict} 
    temp_param_grid.update({param:param_distributions_Random_Forest[param]})
    print(temp_param_grid)
    print("Testing param", param)
    history = do_random_search(pipelines[1][1], temp_param_grid)
    param_history.update({param: history})
# Out:
# {'model__max_features': [0.49816568848070625], 'model__max_samples': [0.738105348394507], 'model__min_samples_leaf': [3], 'model__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000208E79B6CD0>}
# Testing param model__n_estimators
# {'model__max_features': [0.49816568848070625], 'model__max_samples': [0.738105348394507], 'model__min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000208E79B72D0>, 'model__n_estimators': [478]}
# Testing param model__min_samples_leaf
# {'model__max_features': [0.49816568848070625], 'model__max_samples': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000208E79B7890>, 'model__min_samples_leaf': [3], 'model__n_estimators': [478]}
# Testing param model__max_samples
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'model__max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000208E79B7E90>, 'model__max_samples': [0.738105348394507], 'model__min_samples_leaf': [3], 'model__n_estimators': [478]}
# Testing param model__max_features
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
params_history_frames_RF = {}
for param, history in param_history.items():
    df = pd.concat([pd.DataFrame(history[i]) for i in range(len(history))], keys=range(len(history)), names=['dataset'])
    df = df.reset_index()
    df.drop(columns='level_1', inplace=True)
    params_history_frames_RF.update({param:df})

# %%
for param, history in params_history_frames_RF.items():
    print(history.shape)
    history.to_csv(f'../history/history_hyperparameter_tuning_RF_{param}.csv', index=False)

# %%
params_history_frames_RF = {}
for param in ["model__n_estimators", "model__min_samples_leaf","model__max_samples","model__max_features"]:
    file_path = f'../history/history_hyperparameter_tuning_RF_{param}.csv'
    if os.path.exists(file_path):
        params_history_frames_RF[param] = pd.read_csv(file_path)

# %%
for param in tunable_parameters_RF:
    print("Results for param:", param)
    display(get_best_params_per_dataset_for_measuring_param_tunability(params_history_frames_RF[param], history_RandomForest).head(10))
    print(get_best_params_per_dataset_for_measuring_param_tunability(params_history_frames_RF[param], history_RandomForest)['rel_tunability (%)'].mean())
# Out:
# Results for param: model__n_estimators
#    dataset                                        best_params  best_score  \
# 0        0  {'model__max_features': 0.49816568848070625, '...    0.926011
# 1        1  {'model__max_features': 0.49816568848070625, '...    0.986698
# 2        2  {'model__max_features': 0.49816568848070625, '...    0.999983
# 3        3  {'model__max_features': 0.49816568848070625, '...    0.851273
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.925189        0.000822            0.088824
# 1       0.986360        0.000338            0.034250
# 2       0.999973        0.000010            0.000972
# 3       0.849848        0.001425            0.167688
# 0.07293348135510604
# Results for param: model__min_samples_leaf
#    dataset                                        best_params  best_score  \
# 0        0  {'model__max_features': 0.49816568848070625, '...    0.926471
# 1        1  {'model__max_features': 0.49816568848070625, '...    0.987534
# 2        2  {'model__max_features': 0.49816568848070625, '...    0.999990
# 3        3  {'model__max_features': 0.49816568848070625, '...    0.851094
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.925189        0.001282            0.138520
# 1       0.986360        0.001174            0.119052
# 2       0.999973        0.000017            0.001701
# 3       0.849848        0.001245            0.146538
# 0.1014524194347725
# Results for param: model__max_samples
#    dataset                                        best_params  best_score  \
# 0        0  {'model__max_features': 0.49816568848070625, '...    0.925849
# 1        1  {'model__max_features': 0.49816568848070625, '...    0.987003
# 2        2  {'model__max_features': 0.49816568848070625, '...    0.999988
# 3        3  {'model__max_features': 0.49816568848070625, '...    0.851302
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.925189        0.000660            0.071352
# 1       0.986360        0.000642            0.065124
# 2       0.999973        0.000015            0.001458
# 3       0.849848        0.001454            0.171035
# 0.07724223682261862
# Results for param: model__max_features
#    dataset                                        best_params  best_score  \
# 0        0  {'model__max_features': 0.4894532708248027, 'm...    0.925715
# 1        1  {'model__max_features': 0.3745407443072436, 'm...    0.986765
# 2        2  {'model__max_features': 0.09767301633426986, '...    0.999994
# 3        3  {'model__max_features': 0.11586994365607019, '...    0.851665
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.925189        0.000526            0.056810
# 1       0.986360        0.000405            0.041084
# 2       0.999973        0.000021            0.002106
# 3       0.849848        0.001817            0.213761
# 0.07843993039905967

# %% [markdown]
# ## **XGBoost**

# %%
param_distributions_XGBoost = param_distributions[2]
tunable_parameters_XGB = param_distributions_XGBoost.keys()
tunable_parameters_XGB
# Out:
# dict_keys(['model__max_depth', 'model__min_child_weight', 'model__eta', 'model__alpha'])

# %%
best_params_XGB_dict = json.loads(best_params_XGBoost.replace("'", "\""))
best_params_XGB_dict = {key: [value] for key, value in best_params_XGB_dict.items()}
best_params_XGB_dict
# Out:
# {'model__alpha': [3.963066389815045],
#  'model__eta': [0.10674596881842251],
#  'model__max_depth': [12],
#  'model__min_child_weight': [1]}

# %%
param_history = {}
for param in tunable_parameters_XGB:
    temp_param_grid = {**best_params_XGB_dict} 
    temp_param_grid.update({param:param_distributions_XGBoost[param]})
    print(temp_param_grid)
    print("Testing param", param)
    history = do_random_search(pipelines[2][1], temp_param_grid)
    param_history.update({param: history})
# Out:
# {'model__alpha': [3.963066389815045], 'model__eta': [0.10674596881842251], 'model__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001AC3E0C2610>, 'model__min_child_weight': [1]}
# Testing param model__max_depth
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'model__alpha': [3.963066389815045], 'model__eta': [0.10674596881842251], 'model__max_depth': [12], 'model__min_child_weight': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001AC3E0C34D0>}
# Testing param model__min_child_weight
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'model__alpha': [3.963066389815045], 'model__eta': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001AC3E0C3890>, 'model__max_depth': [12], 'model__min_child_weight': [1]}
# Testing param model__eta
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'model__alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001AC3E0C1690>, 'model__eta': [0.10674596881842251], 'model__max_depth': [12], 'model__min_child_weight': [1]}
# Testing param model__alpha
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Semestr_5\Automatyczne_uczenie_maszynowe\Projekt\AutoML-project1\code\automl1\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
params_history_frames_XGB = {}
for param, history in param_history.items():
    df = pd.concat([pd.DataFrame(history[i]) for i in range(len(history))], keys=range(len(history)), names=['dataset'])
    df = df.reset_index()
    df.drop(columns='level_1', inplace=True)
    params_history_frames_XGB.update({param:df})

# %%
for param, history in params_history_frames_XGB.items():
    print(history.shape)
    history.to_csv(f'../history/history_hyperparameter_tuning_XGB_{param}.csv', index=False)
# Out:
# (800, 18)
# (800, 18)
# (800, 18)
# (800, 18)

# %%
params_history_frames_XGB = {}
for param in ["model__max_depth", "model__min_child_weight", "model__eta", "model__alpha"]:
    file_path = f'../history/history_hyperparameter_tuning_XGB_{param}.csv'
    if os.path.exists(file_path):
        params_history_frames_XGB[param] = pd.read_csv(file_path)

# %%
for param in tunable_parameters_XGB:
    print("Results for param:", param)
    display(get_best_params_per_dataset_for_measuring_param_tunability(params_history_frames_XGB[param], history_XGBoost).head(10))
    print(get_best_params_per_dataset_for_measuring_param_tunability(params_history_frames_XGB[param], history_XGBoost)['rel_tunability (%)'].mean())
# Out:
# Results for param: model__max_depth
#    dataset                                        best_params  best_score  \
# 0        0  {'model__alpha': 3.963066389815045, 'model__et...    0.921431
# 1        1  {'model__alpha': 3.963066389815045, 'model__et...    0.990526
# 2        2  {'model__alpha': 1.2481751282245537, 'model__e...    0.999985
# 3        3  {'model__alpha': 3.963066389815045, 'model__et...    0.848334
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.920403        0.001028            0.111686
# 1       0.990130        0.000396            0.040025
# 2       0.999985        0.000000            0.000000
# 3       0.848066        0.000268            0.031644
# 0.045838851005807944
# Results for param: model__min_child_weight
#    dataset                                        best_params  best_score  \
# 0        0  {'model__alpha': 3.963066389815045, 'model__et...    0.921714
# 1        1  {'model__alpha': 3.963066389815045, 'model__et...    0.990526
# 2        2  {'model__alpha': 1.2481751282245537, 'model__e...    0.999985
# 3        3  {'model__alpha': 1.2481751282245537, 'model__e...    0.848066
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.920403        0.001311            0.142395
# 1       0.990130        0.000396            0.040025
# 2       0.999985        0.000000            0.000000
# 3       0.848066        0.000000            0.000000
# 0.045604903458540576
# Results for param: model__eta
#    dataset                                        best_params  best_score  \
# 0        0  {'model__alpha': 3.963066389815045, 'model__et...    0.922175
# 1        1  {'model__alpha': 3.963066389815045, 'model__et...    0.990520
# 2        2  {'model__alpha': 1.2481751282245537, 'model__e...    0.999985
# 3        3  {'model__alpha': 3.963066389815045, 'model__et...    0.850173
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.920403        0.001771            0.192454
# 1       0.990130        0.000390            0.039369
# 2       0.999985        0.000000            0.000000
# 3       0.848066        0.002107            0.248461
# 0.12007089310680277
# Results for param: model__alpha
#    dataset                                        best_params  best_score  \
# 0        0  {'model__alpha': 3.477998816092334, 'model__et...    0.921544
# 1        1  {'model__alpha': 2.7293781650374753, 'model__e...    0.990449
# 2        2  {'model__alpha': 1.2481751282245537, 'model__e...    0.999985
# 3        3  {'model__alpha': 6.732248920775331, 'model__et...    0.849878
#
#    default_score  abs_tunability  rel_tunability (%)
# 0       0.920403        0.001140            0.123886
# 1       0.990130        0.000319            0.032233
# 2       0.999985        0.000000            0.000000
# 3       0.848066        0.001812            0.213652
# 0.0924425447962211
