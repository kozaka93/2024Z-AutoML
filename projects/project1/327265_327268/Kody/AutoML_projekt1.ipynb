# %% [markdown]
# # Testing tunability of models

# %%
# Packages
import copy

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import random
from sklearn.model_selection import ParameterSampler
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
from skopt import BayesSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, make_column_selector
import warnings
warnings.filterwarnings('ignore')
from sklearn.svm import SVC
from sklearn.linear_model import ElasticNet
from timeit import default_timer as timer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from skopt.space import Real, Integer
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, roc_curve, make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
np.random.seed(42)

# %%
# diabetes = pd.DataFrame(pd.read_csv("C:/Users/jancw/Desktop/Studia/Sem5/AutoML/Project_1/Datasets/diabetes.csv"))
diabetes = pd.DataFrame(pd.read_csv("../data/diabetes.csv"))
students = pd.DataFrame(pd.read_csv('../data/students.csv'))
# students = pd.DataFrame(pd.read_csv('C:/Users/jancw/Desktop/Studia/Sem5/AutoML/Project_1/Datasets/students.csv'))
students = students.loc[students.Target!='Enrolled']
# telco = pd.DataFrame(pd.read_csv('C:/Users/jancw/Desktop/Studia/Sem5/AutoML/Project_1/Datasets/telco.csv'))
telco = pd.DataFrame(pd.read_csv('../data/telco.csv'))
telco['TotalCharges'] = pd.to_numeric(telco['TotalCharges'],errors='coerce')
telco = telco.iloc[:,1:] # id column
# pistachio = pd.DataFrame(pd.read_csv('C:/Users/jancw/Desktop/Studia/Sem5/AutoML/Project_1/Datasets/pistachio.csv'))
pistachio = pd.DataFrame(pd.read_csv('../data/pistachio.csv'))
datasets = {'diabetes': diabetes,'students': students,'telco': telco,'pistachio': pistachio}

# %% [markdown]
# # Wybór danych i rekonesans

# %%
# datasets sizes
for key in datasets:
    print(f'{key} len: {len(datasets.get(key))}')
# Out:
# diabetes len: 100000
# students len: 3630
# telco len: 7043
# pistachio len: 2148

# %%
# we need about 1500 rows from each set
random_seed = 24
datasets_wanted_size = {}
for key in datasets:
    dataset_size = len(datasets.get(key))
    X = datasets.get(key)
    y = datasets.get(key).iloc[:,-1]
    rest,data_wanted_size = train_test_split(X,test_size=1500/dataset_size,stratify=y,random_state=random_seed)
    datasets_wanted_size[key] = data_wanted_size

# %%
def save_datasets_as_csv(datasets, directory):

    # Tworzenie katalogu, jeśli nie istnieje
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Iteracja po słowniku i zapis do plików CSV
    for dataset_name, data in datasets.items():
        # Pełna ścieżka do pliku
        filepath = os.path.join(directory, f"{dataset_name}.csv")
        
        # Zapisz dane do CSV
        if isinstance(data, pd.DataFrame):
            data.to_csv(filepath, index=False)  # Bez indeksów
        else:
            # Jeśli dane nie są DataFrame, spróbuj przekonwertować
            pd.DataFrame(data).to_csv(filepath, index=False)
        
        print(f"Zapisano {dataset_name} do pliku {filepath}")


save_datasets_as_csv(datasets_wanted_size, '.\\Dane')
# Out:
# Zapisano diabetes do pliku .\Dane\diabetes.csv
# Zapisano students do pliku .\Dane\students.csv
# Zapisano telco do pliku .\Dane\telco.csv
# Zapisano pistachio do pliku .\Dane\pistachio.csv

# %%
# typy kolumn
for key in datasets_wanted_size:
    print(key + ':')
    print(f'{datasets_wanted_size.get(key).dtypes.value_counts()}\n')
# Out:
# diabetes:
# int64      4
# float64    3
# object     2
# Name: count, dtype: int64
#
# students:
# int64      29
# float64     5
# object      1
# Name: count, dtype: int64
#
# telco:
# object     16
# int64       2
# float64     2
# Name: count, dtype: int64
#
# pistachio:
# float64    26
# int64       2
# object      1
# Name: count, dtype: int64

# %%
# rozkład y
for key in datasets_wanted_size:
    print(key+':')
    print(f'{datasets_wanted_size.get(key).iloc[:,-1].value_counts()}\n')

# zmieniamy dla każdego zbioru ,y na wartości {0,1}
label_encoder = LabelEncoder()
for key in datasets_wanted_size:
    datasets_wanted_size[key].iloc[:,-1] = label_encoder.fit_transform(datasets_wanted_size[key].iloc[:,-1])
    datasets_wanted_size[key] = datasets_wanted_size[key].astype({datasets_wanted_size.get(key).columns[-1]: 'int64'})
# Out:
# diabetes:
# diabetes
# 0    1373
# 1     127
# Name: count, dtype: int64
#
# students:
# Target
# Graduate    913
# Dropout     587
# Name: count, dtype: int64
#
# telco:
# Churn
# No     1102
# Yes     398
# Name: count, dtype: int64
#
# pistachio:
# Class
# Kirmizi_Pistachio    860
# Siirt_Pistachio      640
# Name: count, dtype: int64

# %% [markdown]
# Sprawdzanie wartości zmiennyck o typach 'object'

# %%
dataset = datasets_wanted_size.get('diabetes')
object_columns = dataset.select_dtypes(include='object')
object_columns_unique_values = {column: dataset[column].unique() for column in object_columns}

for key in object_columns_unique_values:
    print(f'{key}: {object_columns_unique_values.get(key)}')

dataset.head(3)

# nulls :
    # czy w gender: 'Other'==null
    # czy w smoking_history 'No info'==null

# object column encoding :
    # gender - 
    # smoking_history -
# Out:
# gender: ['Male' 'Female']
# smoking_history: ['former' 'never' 'ever' 'No Info' 'not current' 'current']
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 60094    Male  62.0             1              1          former  27.32
# 90264    Male  61.0             0              0           never  58.05
# 53832  Female  73.0             0              0           never  27.32
#
#        HbA1c_level  blood_glucose_level  diabetes
# 60094          4.8                  155         0
# 90264          5.7                  155         1
# 53832          6.5                  200         0

# %%
dataset = datasets_wanted_size.get('students')
object_columns = dataset.select_dtypes(include='object')
object_columns_unique_values = {column: dataset[column].unique() for column in object_columns}

for key in object_columns_unique_values:
    print(f'{key}: {object_columns_unique_values.get(key)}')

# kolumny są numeryczne

dataset.head(3)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 4310               1                15                  1       6
# 4318               1                 1                  1       2
# 209                1                12                  1      11
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 4310                           1                      14            1
# 4318                           1                       1           14
# 209                            1                      12            1
#
#       Mother's qualification  Father's qualification  Mother's occupation  \
# 4310                      23                      27                   10
# 4318                       1                       1                   10
# 209                        3                      14                    3
#
#       ...  Curricular units 2nd sem (credited)  \
# 4310  ...                                    1
# 4318  ...                                    4
# 209   ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 4310                                    6
# 4318                                   11
# 209                                     6
#
#       Curricular units 2nd sem (evaluations)  \
# 4310                                      12
# 4318                                      12
# 209                                        6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 4310                                    6                            13.625
# 4318                                   11                            15.000
# 209                                     5                            12.800
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 4310                                               0               12.4
# 4318                                               0                8.9
# 209                                                0               16.2
#
#       Inflation rate   GDP  Target
# 4310             0.5  1.79       1
# 4318             1.4  3.51       1
# 209              0.3 -0.92       0
#
# [3 rows x 35 columns]

# %%
dataset = datasets_wanted_size.get('telco')
object_columns = dataset.select_dtypes(include='object')
object_columns_unique_values = {column: dataset[column].unique() for column in object_columns}

for key in object_columns_unique_values:
    print(f'{key}: {object_columns_unique_values.get(key)}')
    
dataset.head(3)

# object column encoding :
    # wszytkie kolumny wartościach binarnych - label encoding
    # Contract - 
    # TotalCharges - zmiana typu na float, (są wartości ' ' ,które mogą być traktowane jako null)
    # pozostałe - one-hot encoding
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['Yes' 'No' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['Yes' 'No' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['Yes' 'No' 'No internet service']
# Contract: ['Two year' 'Month-to-month' 'One year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4726  Female              0     Yes         No      72           No
# 5892    Male              0      No         No      10          Yes
# 274     Male              0      No         No       1          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 4726  No phone service             DSL            Yes          Yes
# 5892                No             DSL            Yes           No
# 274                 No     Fiber optic             No           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 4726              Yes          No          No             Yes        Two year
# 5892               No          No          No              No  Month-to-month
# 274                No          No          No              No  Month-to-month
#
#      PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 4726              Yes  Electronic check           49.20       3580.95      0
# 5892              Yes      Mailed check           51.65        524.50      0
# 274                No      Mailed check           70.60         70.60      1

# %%
dataset = datasets_wanted_size.get('pistachio')
object_columns = dataset.select_dtypes(include='object')
object_columns_unique_values = {column: dataset[column].unique() for column in object_columns}

for key in object_columns_unique_values:
    print(f'{key}: {object_columns_unique_values.get(key)}')

# kolumny są numeryczne

dataset.head(3)
# Out:
#        Area  Perimeter  Major_Axis  Minor_Axis  Eccentricity   Eqdiasq  \
# 1682  80139  1075.2321    418.1198    244.6082        0.8110  319.4310
# 89    85969  2345.6279    421.6958    291.1149        0.7235  330.8461
# 2021  95334  1251.7111    488.1582    249.2888        0.8598  348.4007
#
#       Solidity  Convex_Area  Extent  Aspect_Ratio  ...  StdDev_RR  StdDev_RG  \
# 1682    0.9928        80719  0.7494        1.7093  ...    14.5330    15.2768
# 89      0.8702        98789  0.7033        1.4486  ...    18.2206    18.1049
# 2021    0.9858        96705  0.7721        1.9582  ...    23.4085    24.2855
#
#       StdDev_RB  Skew_RR  Skew_RG  Skew_RB  Kurtosis_RR  Kurtosis_RG  \
# 1682    14.2298  -0.7579  -0.6986  -0.3487       3.4817       3.2926
# 89      16.7189  -0.9762  -0.9983  -0.7881       3.1975       3.3114
# 2021    22.0737  -0.6492  -0.4470  -0.4217       2.6227       2.3029
#
#       Kurtosis_RB  Class
# 1682       2.6470      1
# 89         3.3104      0
# 2021       2.2124      1
#
# [3 rows x 29 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# - jeżeli kolumna ma 2 wartości to label encoding, wpp one-hot encoding ,(może coś innego pomyśleć) - wzialem dummy onehotencoder do pipeline
# -

# %%
# notatnik
# diabetes.nunique()==2

# pip_num = Pipeline(steps=[('impute',SimpleImputer()),
#                           ('scale',MinMaxScaler())])
# pip_cat = Pipeline(steps=[
#     ('ohe',OneHotEncoder()),
#     ('impute',SimpleImputer())])

# col_trans = ColumnTransformer([
#     ("numeric",pip_num,make_column_selector(dtype_include= np.number)),
#     ("cat",pip_cat,make_column_selector(dtype_include= np.object_))
# ])

# model_pipeline = Pipeline([("trans",col_trans),("model",RandomForestClassifier())])
# model_pipeline.fit(datasets_X_test.get('telco'),np.array(datasets_y_test.get('telco')))

# %% [markdown]
# # Modele

# %%
# 1 - DecisionTreeClassifier

# class sklearn.tree.DecisionTreeClassifier(*, 
#                                         criterion='gini',
#                                         splitter='best',
#                                         max_depth=[],
#                                         min_samples_split=2, 
#                                         min_samples_leaf=1, 
#                                         min_weight_fraction_leaf=0.0, 
#                                         max_features=None, 
#                                         random_state=None, 
#                                         max_leaf_nodes=None, 
#                                         min_impurity_decrease=0.0, 
#                                         class_weight=None, 
#                                         ccp_alpha=0.0, 
#                                         monotonic_cst=None)

# %%
# 2 - LogisticRegression

# class sklearn.linear_model.LogisticRegression(penalty='l2', 
#                                               *, 
#                                               dual=False, 
#                                               tol=0.0001, 
#                                               C=1.0, 
#                                               fit_intercept=True, 
#                                               intercept_scaling=1, 
#                                               class_weight=None, 
#                                               random_state=None, 
#                                               solver='lbfgs', 
#                                               max_iter=100, 
#                                               multi_class='deprecated', 
#                                               verbose=0, 
#                                               warm_start=False, 
#                                               n_jobs=None, 
#                                               l1_ratio=None)

# %%
# 3 - GradientBoostingClassifier

# class sklearn.ensemble.GradientBoostingClassifier(*, 
#                                                   loss='log_loss', 
#                                                   learning_rate=0.1, 
#                                                   n_estimators=100, 
#                                                   subsample=1.0, 
#                                                   criterion='friedman_mse', 
#                                                   min_samples_split=2, 
#                                                   min_samples_leaf=1, 
#                                                   min_weight_fraction_leaf=0.0, 
#                                                   max_depth=3, 
#                                                   min_impurity_decrease=0.0, 
#                                                   init=None, random_state=None, 
#                                                   max_features=None, 
#                                                   verbose=0, 
#                                                   max_leaf_nodes=None, 
#                                                   warm_start=False, 
#                                                   validation_fraction=0.1, 
#                                                   n_iter_no_change=None, 
#                                                   tol=0.0001, 
#                                                   ccp_alpha=0.0)

# %%
# Import the required classifiers from scikit-learn

# Create objects of the classifiers
logistic_regression = LogisticRegression()
decision_tree = DecisionTreeClassifier()
random_forest = RandomForestClassifier()
gradient_boosting = GradientBoostingClassifier()
ada_boost = AdaBoostClassifier()
bagging_classifier = BaggingClassifier()
k_neighbors = KNeighborsClassifier()
support_vector_machine = SVC()

# Display the classifier objects
classifiers = {
    "Logistic Regression": logistic_regression,
    "Decision Tree": decision_tree,
    "Random Forest": random_forest,
    "Gradient Boosting": gradient_boosting,
    "AdaBoost": ada_boost,
    "Bagging Classifier": bagging_classifier,
    "K-Neighbors": k_neighbors,
    "Support Vector Machine": support_vector_machine
}

# %%
random_seed = 24
datasets_X_train = {}
datasets_X_test = {}
datasets_y_train = {}
datasets_y_test = {}
for key in datasets_wanted_size:
    dataset_size = len(datasets_wanted_size.get(key))
    X = datasets_wanted_size.get(key).iloc[:,:-1]
    y = datasets_wanted_size.get(key).iloc[:,-1]
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=random_seed)
    datasets_X_train[key] = X_train
    datasets_X_test[key] = X_test
    datasets_y_train[key] = y_train
    datasets_y_test[key] = y_test

# %%
tabela_wyników = {}

pip_num = Pipeline(steps=[('impute',SimpleImputer()),
                          ('scale',MinMaxScaler())])
pip_cat = Pipeline(steps=[
    ('ohe',OneHotEncoder(drop='first')),
    ('impute',SimpleImputer())])
col_trans = ColumnTransformer([
    ("numeric",pip_num,make_column_selector(dtype_include= np.number)),
    ("cat",pip_cat,make_column_selector(dtype_include= np.object_))
])


example_pipeline = Pipeline([("trans",col_trans),("model",RandomForestClassifier())])
example_pipeline.fit(datasets_X_test.get('telco'),np.array(datasets_y_test.get('telco')))
# Out:
# Pipeline(steps=[('trans',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    MinMaxScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7EBC7B050>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first')),
#                                                                   ('impute',
#                                                                    SimpleImputer())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7EBC82330>)])),
#                 ('model', RandomForestClassifier())])

# %%
set_key = 'students'

for key in classifiers:
    start = timer()
    model_pipeline = Pipeline([("trans",col_trans),("model",classifiers[key])])
    model_pipeline.fit(datasets_X_train.get(set_key),datasets_y_train.get(set_key))    
    end = timer()
    y_hat = model_pipeline.predict(datasets_X_test.get(set_key))
    tabela_wyników[key] = [accuracy_score(y_hat,datasets_y_test.get(set_key)),end-start] #== [accuracy, time]


# pistachio
# {'Logistic Regression': [0.8766666666666667, 0.014618600020185113],
#  'Decision Tree': [0.8066666666666666, 0.02735049999319017],
#  'Random Forest': [0.8533333333333334, 0.3635247000493109],
#  'Gradient Boosting': [0.8666666666666667, 0.9874855000525713],
#  'AdaBoost': [0.8933333333333333, 0.2399780999403447],
#  'Bagging Classifier': [0.8466666666666667, 0.16180030000396073],
#  'K-Neighbors': [0.8766666666666667, 0.004990700050257146],
#  'Support Vector Machine': [0.89, 0.021320700063370168]}

# diabetes
# {'Logistic Regression': [0.96, 0.02030680002644658],
#  'Decision Tree': [0.94, 0.007484599947929382],
#  'Random Forest': [0.98, 0.11521570000331849],
#  'Gradient Boosting': [0.97, 0.14825059997383505],
#  'AdaBoost': [0.97, 0.078939100028947],
#  'Bagging Classifier': [0.97, 0.02978769992478192],
#  'K-Neighbors': [0.9266666666666666, 0.00779770000372082],
#  'Support Vector Machine': [0.96, 0.011258100043050945]}

# telco
# {'Logistic Regression': [0.8033333333333333, 0.024130700039677322],
#  'Decision Tree': [0.7566666666666667, 0.015992800006642938],
#  'Random Forest': [0.8, 0.15928849996998906],
#  'Gradient Boosting': [0.7966666666666666, 0.24993829999584705],
#  'AdaBoost': [0.8066666666666666, 0.10428309999406338],
#  'Bagging Classifier': [0.7833333333333333, 0.04923330002930015],
#  'K-Neighbors': [0.75, 0.011039600009098649],
#  'Support Vector Machine': [0.81, 0.028400499955751002]}

# students 
# {'Logistic Regression': [0.9066666666666666, 0.011891300091519952],
#  'Decision Tree': [0.8666666666666667, 0.01138309994712472],
#  'Random Forest': [0.9166666666666666, 0.1611720999935642],
#  'Gradient Boosting': [0.9233333333333333, 0.2623509999830276],
#  'AdaBoost': [0.9133333333333333, 0.12784590001683682],
#  'Bagging Classifier': [0.8966666666666666, 0.054303099983371794],
#  'K-Neighbors': [0.8233333333333334, 0.00486270000692457],
#  'Support Vector Machine': [0.8833333333333333, 0.0196890999795869]}

# %%
tabela_wyników
# Out:
# {'Logistic Regression': [0.9066666666666666, 0.026161199901252985],
#  'Decision Tree': [0.8733333333333333, 0.019780399976298213],
#  'Random Forest': [0.92, 0.2595732999034226],
#  'Gradient Boosting': [0.9233333333333333, 0.4002435998991132],
#  'AdaBoost': [0.9133333333333333, 0.18256230000406504],
#  'Bagging Classifier': [0.9, 0.09091700008139014],
#  'K-Neighbors': [0.8233333333333334, 0.017063400009647012],
#  'Support Vector Machine': [0.8833333333333333, 0.04597860015928745]}

# %% [markdown]
# # Wybrane modele

# %%
models = {
    # 'Elastic Net' : ElasticNet,
    # "KNN" : KNeighborsClassifier,
    'Decision Tree' : DecisionTreeClassifier,
    'Random Forest' : RandomForestClassifier,
    'Logistic Regression' : LogisticRegression
}

# %% [markdown]
# # Zapisywanie modelu

# %%
import pickle

def save_models(best_of_method, pth):
    for model, datasets in best_of_method.items():
        m = model.replace(" ",'')
        for ds, model_trained in datasets.items():
            path = os.path.join(pth, f"{m}{ds}.pkl")
            directory = os.path.dirname(pth)
            if not os.path.exists(directory):
                os.makedirs(directory)
            with open(path, 'wb') as file:
                pickle.dump(model_trained, file )

# %% [markdown]
# # Random Search

# %%
# siatki parametrów

seed = 42
random.seed(seed)
np.random.seed(seed)
n_iter = 200


param_distributions = {
    'Logistic Regression': {
        'C': uniform(0.01, 100), 
        'penalty': ['l1', 'l2'],  
        'solver': ['liblinear'],  
    },
    'Decision Tree': { 
        'ccp_alpha': uniform(0, 1), 
        'max_depth': randint(1, 31),
        'min_samples_leaf': randint(1, 61),  
        'min_samples_split': randint(2, 61), 
    },

    'Random Forest': {  
        'n_estimators': randint(1, 2001),
        'max_samples': uniform(0.1, .1),
        'max_features': uniform(0, 1),  
        'min_samples_leaf': randint(1, 31), 
    }
}


param_samples = {
    alg: list(ParameterSampler(param_distributions[alg], n_iter=n_iter, random_state=seed))
    for alg in param_distributions
}
for alg, samples in param_samples.items():
    print(f"{alg} samples:")
    for i, sample in enumerate(samples):
        print(f"  Sample {i+1}: {sample}")
# Out:
# Logistic Regression samples:
#   Sample 1: {'C': 37.464011884736244, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 2: {'C': 18.35347898661638, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 3: {'C': 59.87584841970366, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 4: {'C': 44.59327528535911, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 5: {'C': 5.818361216819946, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 6: {'C': 33.380861113902185, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 7: {'C': 70.81725777960456, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 8: {'C': 5.651157902710025, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 9: {'C': 83.25426408004218, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 10: {'C': 0.08787658410143283, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 11: {'C': 18.350450985343382, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 12: {'C': 61.17531604882809, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 13: {'C': 43.20450186421157, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 14: {'C': 52.48746602583891, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 15: {'C': 13.959386065204184, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 16: {'C': 97.38555188414593, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 17: {'C': 45.61699842170359, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 18: {'C': 61.848600933308724, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 19: {'C': 51.43344384136116, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 20: {'C': 46.68628932479799, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 21: {'C': 60.76448519014384, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 22: {'C': 45.059925196954296, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 23: {'C': 94.89855372533333, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 24: {'C': 56.33882178455393, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 25: {'C': 30.47137691733707, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 26: {'C': 23.099382562214902, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 27: {'C': 44.02524937396013, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 28: {'C': 61.00966577826209, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 29: {'C': 3.4488521115218393, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 30: {'C': 39.11606075732408, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 31: {'C': 66.2622284353982, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 32: {'C': 42.525587449124465, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 33: {'C': 54.681027934327965, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 34: {'C': 3.141329245555858, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 35: {'C': 77.52328233611146, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 36: {'C': 39.52502360018144, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 37: {'C': 59.79999788110851, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 38: {'C': 32.664076880583536, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 39: {'C': 19.60828624191452, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 40: {'C': 96.12720243493492, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 41: {'C': 38.8777289689482, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 42: {'C': 53.979213238907974, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 43: {'C': 35.68533266935893, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 44: {'C': 60.71342476866847, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 45: {'C': 14.102422497476264, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 46: {'C': 16.53669390630025, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 47: {'C': 98.69869366005173, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 48: {'C': 39.498151817556966, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 49: {'C': 0.5622117123602399, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 50: {'C': 19.894240408880517, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 51: {'C': 72.91071680409874, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 52: {'C': 60.60599747810114, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 53: {'C': 35.856572854427256, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 54: {'C': 91.50596755437809, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 55: {'C': 62.33981268275579, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 56: {'C': 9.551011649041131, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 57: {'C': 31.108232171566222, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 58: {'C': 66.60223566174967, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 59: {'C': 63.76574713552131, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 60: {'C': 56.13434258477011, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 61: {'C': 11.96942459383017, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 62: {'C': 84.9013824266084, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 63: {'C': 56.13771975694962, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 64: {'C': 25.6168322761324, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 65: {'C': 52.283282938199406, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 66: {'C': 11.099082081183132, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 67: {'C': 10.799142699330444, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 68: {'C': 89.58635956735195, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 69: {'C': 31.44559810763267, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 70: {'C': 69.56160864261275, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 71: {'C': 24.939222914887495, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 72: {'C': 53.99410913016731, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 73: {'C': 22.889816549162248, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 74: {'C': 59.8965466488536, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 75: {'C': 16.132128725400445, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 76: {'C': 62.44540481337932, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 77: {'C': 63.35037565104234, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 78: {'C': 45.66345704829102, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 79: {'C': 18.667005888603587, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 80: {'C': 88.33802589188683, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 81: {'C': 80.75401551640626, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 82: {'C': 35.63978380769749, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 83: {'C': 11.015192452767677, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 84: {'C': 64.77901205413623, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 85: {'C': 81.81147659224932, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 86: {'C': 30.488125815802906, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 87: {'C': 51.08473025775657, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 88: {'C': 48.49299713589832, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 89: {'C': 11.99653673336828, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 90: {'C': 24.42255222477742, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 91: {'C': 32.330293202075524, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 92: {'C': 55.82020020173412, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 93: {'C': 36.3729602379294, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 94: {'C': 25.40154139343447, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 95: {'C': 25.18822958253642, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 96: {'C': 71.2370589924442, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 97: {'C': 28.494049437746764, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 98: {'C': 26.6881014275285, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 99: {'C': 50.27790232288615, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 100: {'C': 3.3150732900548383, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 101: {'C': 90.83658859666538, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 102: {'C': 68.08054515547668, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 103: {'C': 48.9552760277563, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 104: {'C': 55.29930890713279, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 105: {'C': 67.22355474058786, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 106: {'C': 36.97544560614045, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 107: {'C': 72.83163486118596, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 108: {'C': 47.04006344460384, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 109: {'C': 63.362971076089465, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 110: {'C': 81.6531873219384, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 111: {'C': 83.5402495589238, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 112: {'C': 50.82987767407187, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 113: {'C': 4.087514155476391, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 114: {'C': 32.605890520188474, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 115: {'C': 1.6687828927856152, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 116: {'C': 80.96010461397155, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 117: {'C': 64.52727904094499, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 118: {'C': 94.0623264489604, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 119: {'C': 38.683534630053735, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 120: {'C': 83.7810105907328, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 121: {'C': 34.11663510502585, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 122: {'C': 20.91716207377137, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 123: {'C': 87.74393533809811, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 124: {'C': 22.865002179729967, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 125: {'C': 81.73222002012159, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 126: {'C': 51.67358912710143, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 127: {'C': 24.19522909004517, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 128: {'C': 96.55193512887936, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 129: {'C': 90.05180571633305, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 130: {'C': 18.88071083413794, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 131: {'C': 34.93095746126609, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 132: {'C': 84.6761142238306, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 133: {'C': 88.71864242651174, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 134: {'C': 88.78700987609598, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 135: {'C': 8.423996499504883, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 136: {'C': 78.54406511139436, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 137: {'C': 60.65290596595899, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 138: {'C': 37.23827665617431, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 139: {'C': 66.36017691080559, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 140: {'C': 28.402097473746572, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 141: {'C': 54.88337893665861, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 142: {'C': 44.85241429862473, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 143: {'C': 22.43693094605598, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 144: {'C': 1.8175363615520868, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 145: {'C': 32.54996981592677, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 146: {'C': 36.65687845828599, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 147: {'C': 84.9323410494178, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 148: {'C': 30.816079185238923, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 149: {'C': 9.377476782809248, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 150: {'C': 63.64326181858954, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 151: {'C': 24.40896433790836, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 152: {'C': 97.8992858275009, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 153: {'C': 89.21465551771134, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 154: {'C': 43.449436551042865, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 155: {'C': 50.27370931051921, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 156: {'C': 66.90240596630997, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 157: {'C': 19.534298779804452, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 158: {'C': 49.92933798847523, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 159: {'C': 2.4415966431453837, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 160: {'C': 4.370377175443375, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 161: {'C': 94.05585843529144, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 162: {'C': 27.966034179675862, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 163: {'C': 37.025870025544435, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 164: {'C': 95.31718470239532, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 165: {'C': 42.82841483173143, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 166: {'C': 57.23924691708383, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 167: {'C': 85.31094554673601, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 168: {'C': 30.579701928718187, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 169: {'C': 85.1236671516857, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 170: {'C': 48.53798742763157, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 171: {'C': 55.69012624583501, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 172: {'C': 84.43131407263114, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 173: {'C': 57.0161170089365, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 174: {'C': 20.901871761536018, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 175: {'C': 99.01538501042633, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 176: {'C': 25.426364906973877, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 177: {'C': 87.74730719279555, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 178: {'C': 84.87697949246744, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 179: {'C': 70.25840839871093, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 180: {'C': 55.29199769079077, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 181: {'C': 80.94611554785136, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 182: {'C': 25.63069435944581, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 183: {'C': 91.33405525564713, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 184: {'C': 0.5284862773986776, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 185: {'C': 79.83951789667752, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 186: {'C': 7.104091699992766, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 187: {'C': 79.58926694361011, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 188: {'C': 88.67171489506599, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 189: {'C': 37.5682952639944, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 190: {'C': 43.857412301808694, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 191: {'C': 3.6042273796742084, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 192: {'C': 15.514161672774419, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 193: {'C': 28.66412521282844, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 194: {'C': 86.05046183116752, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 195: {'C': 3.7448188749214415, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 196: {'C': 30.336551467322284, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 197: {'C': 12.716051265188478, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 198: {'C': 82.79690037875888, 'penalty': 'l2', 'solver': 'liblinear'}
#   Sample 199: {'C': 21.59210274968432, 'penalty': 'l1', 'solver': 'liblinear'}
#   Sample 200: {'C': 45.736516161372855, 'penalty': 'l2', 'solver': 'liblinear'}
# Decision Tree samples:
#   Sample 1: {'ccp_alpha': 0.3745401188473625, 'max_depth': 29, 'min_samples_leaf': 15, 'min_samples_split': 44}
#   Sample 2: {'ccp_alpha': 0.7796910002727693, 'max_depth': 21, 'min_samples_leaf': 39, 'min_samples_split': 59}
#   Sample 3: {'ccp_alpha': 0.15599452033620265, 'max_depth': 11, 'min_samples_leaf': 11, 'min_samples_split': 25}
#   Sample 4: {'ccp_alpha': 0.33370861113902184, 'max_depth': 8, 'min_samples_leaf': 24, 'min_samples_split': 4}
#   Sample 5: {'ccp_alpha': 0.020584494295802447, 'max_depth': 2, 'min_samples_leaf': 24, 'min_samples_split': 45}
#   Sample 6: {'ccp_alpha': 0.9385527090157502, 'max_depth': 2, 'min_samples_leaf': 60, 'min_samples_split': 22}
#   Sample 7: {'ccp_alpha': 0.6174815096277165, 'max_depth': 26, 'min_samples_leaf': 22, 'min_samples_split': 45}
#   Sample 8: {'ccp_alpha': 0.023062425041415757, 'max_depth': 27, 'min_samples_leaf': 59, 'min_samples_split': 43}
#   Sample 9: {'ccp_alpha': 0.04666566321361543, 'max_depth': 28, 'min_samples_leaf': 16, 'min_samples_split': 16}
#   Sample 10: {'ccp_alpha': 0.45606998421703593, 'max_depth': 15, 'min_samples_leaf': 51, 'min_samples_split': 45}
#   Sample 11: {'ccp_alpha': 0.5142344384136116, 'max_depth': 25, 'min_samples_leaf': 3, 'min_samples_split': 38}
#   Sample 12: {'ccp_alpha': 0.6075448519014384, 'max_depth': 21, 'min_samples_leaf': 9, 'min_samples_split': 40}
#   Sample 13: {'ccp_alpha': 0.013264961159866528, 'max_depth': 25, 'min_samples_leaf': 60, 'min_samples_split': 15}
#   Sample 14: {'ccp_alpha': 0.8083973481164611, 'max_depth': 9, 'min_samples_leaf': 26, 'min_samples_split': 54}
#   Sample 15: {'ccp_alpha': 0.230893825622149, 'max_depth': 28, 'min_samples_leaf': 47, 'min_samples_split': 8}
#   Sample 16: {'ccp_alpha': 0.6099966577826209, 'max_depth': 8, 'min_samples_leaf': 47, 'min_samples_split': 36}
#   Sample 17: {'ccp_alpha': 0.9093204020787821, 'max_depth': 4, 'min_samples_leaf': 50, 'min_samples_split': 41}
#   Sample 18: {'ccp_alpha': 0.7553614103176525, 'max_depth': 30, 'min_samples_leaf': 6, 'min_samples_split': 55}
#   Sample 19: {'ccp_alpha': 0.5467102793432796, 'max_depth': 22, 'min_samples_leaf': 29, 'min_samples_split': 19}
#   Sample 20: {'ccp_alpha': 0.7751328233611146, 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 37}
#   Sample 21: {'ccp_alpha': 0.5978999788110851, 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 9}
#   Sample 22: {'ccp_alpha': 0.5704439744053994, 'max_depth': 28, 'min_samples_leaf': 57, 'min_samples_split': 41}
#   Sample 23: {'ccp_alpha': 0.8445338486781514, 'max_depth': 13, 'min_samples_leaf': 18, 'min_samples_split': 48}
#   Sample 24: {'ccp_alpha': 0.8287375091519293, 'max_depth': 26, 'min_samples_leaf': 25, 'min_samples_split': 46}
#   Sample 25: {'ccp_alpha': 0.14092422497476265, 'max_depth': 15, 'min_samples_leaf': 45, 'min_samples_split': 2}
#   Sample 26: {'ccp_alpha': 0.01563640674119393, 'max_depth': 9, 'min_samples_leaf': 24, 'min_samples_split': 2}
#   Sample 27: {'ccp_alpha': 0.1987156815341724, 'max_depth': 24, 'min_samples_leaf': 11, 'min_samples_split': 52}
#   Sample 28: {'ccp_alpha': 0.7068573438476171, 'max_depth': 3, 'min_samples_leaf': 35, 'min_samples_split': 34}
#   Sample 29: {'ccp_alpha': 0.6059599747810114, 'max_depth': 10, 'min_samples_leaf': 39, 'min_samples_split': 59}
#   Sample 30: {'ccp_alpha': 0.11586905952512971, 'max_depth': 7, 'min_samples_leaf': 9, 'min_samples_split': 9}
#   Sample 31: {'ccp_alpha': 0.4494506741382034, 'max_depth': 1, 'min_samples_leaf': 48, 'min_samples_split': 56}
#   Sample 32: {'ccp_alpha': 0.3109823217156622, 'max_depth': 24, 'min_samples_leaf': 37, 'min_samples_split': 36}
#   Sample 33: {'ccp_alpha': 0.5912977877077271, 'max_depth': 22, 'min_samples_leaf': 27, 'min_samples_split': 36}
#   Sample 34: {'ccp_alpha': 0.4722149251619493, 'max_depth': 5, 'min_samples_leaf': 47, 'min_samples_split': 15}
#   Sample 35: {'ccp_alpha': 0.8489138242660839, 'max_depth': 5, 'min_samples_leaf': 26, 'min_samples_split': 56}
#   Sample 36: {'ccp_alpha': 0.770967179954561, 'max_depth': 7, 'min_samples_leaf': 27, 'min_samples_split': 10}
#   Sample 37: {'ccp_alpha': 0.7106628896857874, 'max_depth': 26, 'min_samples_leaf': 42, 'min_samples_split': 14}
#   Sample 38: {'ccp_alpha': 0.2017192023353962, 'max_depth': 7, 'min_samples_leaf': 49, 'min_samples_split': 53}
#   Sample 39: {'ccp_alpha': 0.5632755719763837, 'max_depth': 4, 'min_samples_leaf': 30, 'min_samples_split': 38}
#   Sample 40: {'ccp_alpha': 0.24929222914887494, 'max_depth': 13, 'min_samples_leaf': 15, 'min_samples_split': 44}
#   Sample 41: {'ccp_alpha': 0.2030612247347694, 'max_depth': 13, 'min_samples_leaf': 32, 'min_samples_split': 8}
#   Sample 42: {'ccp_alpha': 0.289751452913768, 'max_depth': 22, 'min_samples_leaf': 28, 'min_samples_split': 3}
#   Sample 43: {'ccp_alpha': 0.6243540481337932, 'max_depth': 30, 'min_samples_leaf': 57, 'min_samples_split': 54}
#   Sample 44: {'ccp_alpha': 0.8714605901877177, 'max_depth': 28, 'min_samples_leaf': 44, 'min_samples_split': 45}
#   Sample 45: {'ccp_alpha': 0.4165099478703662, 'max_depth': 30, 'min_samples_leaf': 11, 'min_samples_split': 59}
#   Sample 46: {'ccp_alpha': 0.12208795470067335, 'max_depth': 25, 'min_samples_leaf': 39, 'min_samples_split': 34}
#   Sample 47: {'ccp_alpha': 0.2721322493846353, 'max_depth': 27, 'min_samples_leaf': 57, 'min_samples_split': 53}
#   Sample 48: {'ccp_alpha': 0.352568856334169, 'max_depth': 3, 'min_samples_leaf': 39, 'min_samples_split': 7}
#   Sample 49: {'ccp_alpha': 0.5107473025775657, 'max_depth': 9, 'min_samples_leaf': 37, 'min_samples_split': 34}
#   Sample 50: {'ccp_alpha': 0.1198653673336828, 'max_depth': 12, 'min_samples_leaf': 24, 'min_samples_split': 16}
#   Sample 51: {'ccp_alpha': 0.16829104217293056, 'max_depth': 24, 'min_samples_leaf': 41, 'min_samples_split': 53}
#   Sample 52: {'ccp_alpha': 0.363629602379294, 'max_depth': 17, 'min_samples_leaf': 58, 'min_samples_split': 53}
#   Sample 53: {'ccp_alpha': 0.2468760628386012, 'max_depth': 7, 'min_samples_leaf': 2, 'min_samples_split': 4}
#   Sample 54: {'ccp_alpha': 0.30087830981676966, 'max_depth': 17, 'min_samples_leaf': 56, 'min_samples_split': 18}
#   Sample 55: {'ccp_alpha': 0.266781014275285, 'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 29}
#   Sample 56: {'ccp_alpha': 0.05147875124998935, 'max_depth': 5, 'min_samples_leaf': 32, 'min_samples_split': 34}
#   Sample 57: {'ccp_alpha': 0.6343513447013638, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 54}
#   Sample 58: {'ccp_alpha': 0.489452760277563, 'max_depth': 6, 'min_samples_leaf': 32, 'min_samples_split': 56}
#   Sample 59: {'ccp_alpha': 0.6721355474058786, 'max_depth': 11, 'min_samples_leaf': 56, 'min_samples_split': 60}
#   Sample 60: {'ccp_alpha': 0.24215993827742588, 'max_depth': 6, 'min_samples_leaf': 24, 'min_samples_split': 6}
#   Sample 61: {'ccp_alpha': 0.6323058305935795, 'max_depth': 6, 'min_samples_leaf': 22, 'min_samples_split': 12}
#   Sample 62: {'ccp_alpha': 0.8164318732193839, 'max_depth': 16, 'min_samples_leaf': 33, 'min_samples_split': 10}
#   Sample 63: {'ccp_alpha': 0.32078006497173583, 'max_depth': 6, 'min_samples_leaf': 16, 'min_samples_split': 30}
#   Sample 64: {'ccp_alpha': 0.8583588048137198, 'max_depth': 28, 'min_samples_leaf': 59, 'min_samples_split': 37}
#   Sample 65: {'ccp_alpha': 0.016587828927856152, 'max_depth': 3, 'min_samples_leaf': 19, 'min_samples_split': 21}
#   Sample 66: {'ccp_alpha': 0.6451727904094499, 'max_depth': 20, 'min_samples_leaf': 41, 'min_samples_split': 34}
#   Sample 67: {'ccp_alpha': 0.3975720210875223, 'max_depth': 7, 'min_samples_leaf': 18, 'min_samples_split': 41}
#   Sample 68: {'ccp_alpha': 0.13752094414599325, 'max_depth': 28, 'min_samples_leaf': 57, 'min_samples_split': 26}
#   Sample 69: {'ccp_alpha': 0.20907162073771368, 'max_depth': 30, 'min_samples_leaf': 42, 'min_samples_split': 36}
#   Sample 70: {'ccp_alpha': 0.22855002179729966, 'max_depth': 16, 'min_samples_leaf': 26, 'min_samples_split': 49}
#   Sample 71: {'ccp_alpha': 0.5552008115994623, 'max_depth': 28, 'min_samples_leaf': 49, 'min_samples_split': 3}
#   Sample 72: {'ccp_alpha': 0.9962536997579243, 'max_depth': 30, 'min_samples_leaf': 12, 'min_samples_split': 6}
#   Sample 73: {'ccp_alpha': 0.9004180571633305, 'max_depth': 27, 'min_samples_leaf': 55, 'min_samples_split': 10}
#   Sample 74: {'ccp_alpha': 0.2788713525921819, 'max_depth': 19, 'min_samples_leaf': 48, 'min_samples_split': 17}
#   Sample 75: {'ccp_alpha': 0.8971102599525771, 'max_depth': 24, 'min_samples_leaf': 54, 'min_samples_split': 57}
#   Sample 76: {'ccp_alpha': 0.8877700987609598, 'max_depth': 20, 'min_samples_leaf': 11, 'min_samples_split': 50}
#   Sample 77: {'ccp_alpha': 0.16162871409461377, 'max_depth': 6, 'min_samples_leaf': 40, 'min_samples_split': 21}
#   Sample 78: {'ccp_alpha': 0.5806866214364547, 'max_depth': 16, 'min_samples_leaf': 25, 'min_samples_split': 36}
#   Sample 79: {'ccp_alpha': 0.9736638367553173, 'max_depth': 18, 'min_samples_leaf': 46, 'min_samples_split': 19}
#   Sample 80: {'ccp_alpha': 0.4856137535862266, 'max_depth': 3, 'min_samples_leaf': 16, 'min_samples_split': 42}
#   Sample 81: {'ccp_alpha': 0.17592525267734538, 'max_depth': 4, 'min_samples_leaf': 33, 'min_samples_split': 15}
#   Sample 82: {'ccp_alpha': 0.3253996981592677, 'max_depth': 20, 'min_samples_leaf': 56, 'min_samples_split': 9}
#   Sample 83: {'ccp_alpha': 0.8492234104941779, 'max_depth': 17, 'min_samples_leaf': 33, 'min_samples_split': 49}
#   Sample 84: {'ccp_alpha': 0.09367476782809248, 'max_depth': 19, 'min_samples_leaf': 22, 'min_samples_split': 56}
#   Sample 85: {'ccp_alpha': 0.25046181860558414, 'max_depth': 30, 'min_samples_leaf': 38, 'min_samples_split': 39}
#   Sample 86: {'ccp_alpha': 0.3930977246667604, 'max_depth': 22, 'min_samples_leaf': 8, 'min_samples_split': 28}
#   Sample 87: {'ccp_alpha': 0.43439436551042865, 'max_depth': 21, 'min_samples_leaf': 30, 'min_samples_split': 34}
#   Sample 88: {'ccp_alpha': 0.5769038846263591, 'max_depth': 1, 'min_samples_leaf': 5, 'min_samples_split': 49}
#   Sample 89: {'ccp_alpha': 0.2807723624408558, 'max_depth': 3, 'min_samples_leaf': 49, 'min_samples_split': 18}
#   Sample 90: {'ccp_alpha': 0.994550510797341, 'max_depth': 30, 'min_samples_leaf': 29, 'min_samples_split': 47}
#   Sample 91: {'ccp_alpha': 0.9148643902204485, 'max_depth': 3, 'min_samples_leaf': 60, 'min_samples_split': 42}
#   Sample 92: {'ccp_alpha': 0.9530718470239532, 'max_depth': 29, 'min_samples_leaf': 49, 'min_samples_split': 47}
#   Sample 93: {'ccp_alpha': 0.9666548190436696, 'max_depth': 3, 'min_samples_leaf': 60, 'min_samples_split': 34}
#   Sample 94: {'ccp_alpha': 0.07534625600612821, 'max_depth': 29, 'min_samples_leaf': 21, 'min_samples_split': 33}
#   Sample 95: {'ccp_alpha': 0.8511366715168569, 'max_depth': 3, 'min_samples_leaf': 18, 'min_samples_split': 26}
#   Sample 96: {'ccp_alpha': 0.3946914668094722, 'max_depth': 22, 'min_samples_leaf': 58, 'min_samples_split': 4}
#   Sample 97: {'ccp_alpha': 0.570061170089365, 'max_depth': 24, 'min_samples_leaf': 50, 'min_samples_split': 33}
#   Sample 98: {'ccp_alpha': 0.6711435168240506, 'max_depth': 23, 'min_samples_leaf': 2, 'min_samples_split': 28}
#   Sample 99: {'ccp_alpha': 0.29529058841893874, 'max_depth': 26, 'min_samples_leaf': 17, 'min_samples_split': 41}
#   Sample 100: {'ccp_alpha': 0.697015740995268, 'max_depth': 11, 'min_samples_leaf': 54, 'min_samples_split': 49}
#   Sample 101: {'ccp_alpha': 0.5528199769079077, 'max_depth': 10, 'min_samples_leaf': 55, 'min_samples_split': 27}
#   Sample 102: {'ccp_alpha': 0.8101133946791808, 'max_depth': 25, 'min_samples_leaf': 24, 'min_samples_split': 14}
#   Sample 103: {'ccp_alpha': 0.08159418040024036, 'max_depth': 7, 'min_samples_leaf': 57, 'min_samples_split': 37}
#   Sample 104: {'ccp_alpha': 0.7982951789667752, 'max_depth': 1, 'min_samples_leaf': 8, 'min_samples_split': 47}
#   Sample 105: {'ccp_alpha': 0.795792669436101, 'max_depth': 12, 'min_samples_leaf': 51, 'min_samples_split': 24}
#   Sample 106: {'ccp_alpha': 0.027616771873704704, 'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 33}
#   Sample 107: {'ccp_alpha': 0.578280140996174, 'max_depth': 22, 'min_samples_leaf': 51, 'min_samples_split': 26}
#   Sample 108: {'ccp_alpha': 0.1550416167277442, 'max_depth': 30, 'min_samples_leaf': 22, 'min_samples_split': 59}
#   Sample 109: {'ccp_alpha': 0.8604046183116753, 'max_depth': 17, 'min_samples_leaf': 52, 'min_samples_split': 43}
#   Sample 110: {'ccp_alpha': 0.8226005606596583, 'max_depth': 22, 'min_samples_leaf': 43, 'min_samples_split': 38}
#   Sample 111: {'ccp_alpha': 0.5222432600548044, 'max_depth': 21, 'min_samples_leaf': 60, 'min_samples_split': 45}
#   Sample 112: {'ccp_alpha': 0.9652518303907698, 'max_depth': 7, 'min_samples_leaf': 4, 'min_samples_split': 7}
#   Sample 113: {'ccp_alpha': 0.0516817211686077, 'max_depth': 20, 'min_samples_leaf': 30, 'min_samples_split': 48}
#   Sample 114: {'ccp_alpha': 0.6995122107671938, 'max_depth': 8, 'min_samples_leaf': 52, 'min_samples_split': 17}
#   Sample 115: {'ccp_alpha': 0.9758520794625346, 'max_depth': 28, 'min_samples_leaf': 42, 'min_samples_split': 31}
#   Sample 116: {'ccp_alpha': 0.04106751676787579, 'max_depth': 24, 'min_samples_leaf': 19, 'min_samples_split': 29}
#   Sample 117: {'ccp_alpha': 0.7440426429991154, 'max_depth': 26, 'min_samples_leaf': 37, 'min_samples_split': 27}
#   Sample 118: {'ccp_alpha': 0.9626484146779251, 'max_depth': 23, 'min_samples_leaf': 9, 'min_samples_split': 13}
#   Sample 119: {'ccp_alpha': 0.4089529444142699, 'max_depth': 26, 'min_samples_leaf': 58, 'min_samples_split': 2}
#   Sample 120: {'ccp_alpha': 0.44235222973110444, 'max_depth': 30, 'min_samples_leaf': 54, 'min_samples_split': 49}
#   Sample 121: {'ccp_alpha': 0.18286599710730733, 'max_depth': 13, 'min_samples_leaf': 53, 'min_samples_split': 2}
#   Sample 122: {'ccp_alpha': 0.9548652806631941, 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 23}
#   Sample 123: {'ccp_alpha': 0.7300393165618185, 'max_depth': 3, 'min_samples_leaf': 12, 'min_samples_split': 27}
#   Sample 124: {'ccp_alpha': 0.3559726786512616, 'max_depth': 5, 'min_samples_leaf': 22, 'min_samples_split': 58}
#   Sample 125: {'ccp_alpha': 0.3418796667164016, 'max_depth': 28, 'min_samples_leaf': 5, 'min_samples_split': 48}
#   Sample 126: {'ccp_alpha': 0.040728802318970136, 'max_depth': 14, 'min_samples_leaf': 52, 'min_samples_split': 6}
#   Sample 127: {'ccp_alpha': 0.4741738290873252, 'max_depth': 26, 'min_samples_leaf': 26, 'min_samples_split': 49}
#   Sample 128: {'ccp_alpha': 0.8069129770507795, 'max_depth': 4, 'min_samples_leaf': 33, 'min_samples_split': 31}
#   Sample 129: {'ccp_alpha': 0.6497736826427634, 'max_depth': 26, 'min_samples_leaf': 10, 'min_samples_split': 55}
#   Sample 130: {'ccp_alpha': 0.6350936508676438, 'max_depth': 2, 'min_samples_leaf': 52, 'min_samples_split': 32}
#   Sample 131: {'ccp_alpha': 0.01530454029038475, 'max_depth': 19, 'min_samples_leaf': 58, 'min_samples_split': 33}
#   Sample 132: {'ccp_alpha': 0.8564898411883223, 'max_depth': 5, 'min_samples_leaf': 45, 'min_samples_split': 5}
#   Sample 133: {'ccp_alpha': 0.6158511643899138, 'max_depth': 16, 'min_samples_leaf': 55, 'min_samples_split': 3}
#   Sample 134: {'ccp_alpha': 0.026511310541621813, 'max_depth': 27, 'min_samples_leaf': 20, 'min_samples_split': 25}
#   Sample 135: {'ccp_alpha': 0.6771683423829817, 'max_depth': 3, 'min_samples_leaf': 60, 'min_samples_split': 34}
#   Sample 136: {'ccp_alpha': 0.45825289049151663, 'max_depth': 19, 'min_samples_leaf': 43, 'min_samples_split': 38}
#   Sample 137: {'ccp_alpha': 0.6259396701015728, 'max_depth': 1, 'min_samples_leaf': 33, 'min_samples_split': 41}
#   Sample 138: {'ccp_alpha': 0.9053506419560637, 'max_depth': 12, 'min_samples_leaf': 29, 'min_samples_split': 14}
#   Sample 139: {'ccp_alpha': 0.21458911970837413, 'max_depth': 14, 'min_samples_leaf': 2, 'min_samples_split': 52}
#   Sample 140: {'ccp_alpha': 0.6182538843378929, 'max_depth': 23, 'min_samples_leaf': 17, 'min_samples_split': 27}
#   Sample 141: {'ccp_alpha': 0.3189756302937613, 'max_depth': 26, 'min_samples_leaf': 10, 'min_samples_split': 27}
#   Sample 142: {'ccp_alpha': 0.34062456946424, 'max_depth': 19, 'min_samples_leaf': 41, 'min_samples_split': 8}
#   Sample 143: {'ccp_alpha': 0.11816482762165625, 'max_depth': 21, 'min_samples_leaf': 50, 'min_samples_split': 46}
#   Sample 144: {'ccp_alpha': 0.9366481518557073, 'max_depth': 24, 'min_samples_leaf': 36, 'min_samples_split': 26}
#   Sample 145: {'ccp_alpha': 0.8034809303848486, 'max_depth': 25, 'min_samples_leaf': 36, 'min_samples_split': 11}
#   Sample 146: {'ccp_alpha': 0.42347094230811855, 'max_depth': 24, 'min_samples_leaf': 35, 'min_samples_split': 50}
#   Sample 147: {'ccp_alpha': 0.7316477552996402, 'max_depth': 4, 'min_samples_leaf': 18, 'min_samples_split': 50}
#   Sample 148: {'ccp_alpha': 0.7764129607419968, 'max_depth': 24, 'min_samples_leaf': 23, 'min_samples_split': 33}
#   Sample 149: {'ccp_alpha': 0.8584127518430118, 'max_depth': 17, 'min_samples_leaf': 55, 'min_samples_split': 14}
#   Sample 150: {'ccp_alpha': 0.7399087604473745, 'max_depth': 3, 'min_samples_leaf': 41, 'min_samples_split': 31}
#   Sample 151: {'ccp_alpha': 0.9025529066795667, 'max_depth': 30, 'min_samples_leaf': 20, 'min_samples_split': 49}
#   Sample 152: {'ccp_alpha': 0.38961808621920346, 'max_depth': 13, 'min_samples_leaf': 59, 'min_samples_split': 20}
#   Sample 153: {'ccp_alpha': 0.3892016787341631, 'max_depth': 12, 'min_samples_leaf': 41, 'min_samples_split': 20}
#   Sample 154: {'ccp_alpha': 0.09128667678613356, 'max_depth': 7, 'min_samples_leaf': 28, 'min_samples_split': 15}
#   Sample 155: {'ccp_alpha': 0.6767699044243033, 'max_depth': 20, 'min_samples_leaf': 19, 'min_samples_split': 59}
#   Sample 156: {'ccp_alpha': 0.6318372121697993, 'max_depth': 21, 'min_samples_leaf': 5, 'min_samples_split': 36}
#   Sample 157: {'ccp_alpha': 0.602440925901119, 'max_depth': 20, 'min_samples_leaf': 59, 'min_samples_split': 22}
#   Sample 158: {'ccp_alpha': 0.75237452943768, 'max_depth': 23, 'min_samples_leaf': 16, 'min_samples_split': 58}
#   Sample 159: {'ccp_alpha': 0.11346460201744801, 'max_depth': 21, 'min_samples_leaf': 42, 'min_samples_split': 59}
#   Sample 160: {'ccp_alpha': 0.057558760016644284, 'max_depth': 26, 'min_samples_leaf': 5, 'min_samples_split': 36}
#   Sample 161: {'ccp_alpha': 0.8877041827582998, 'max_depth': 11, 'min_samples_leaf': 11, 'min_samples_split': 19}
#   Sample 162: {'ccp_alpha': 0.9686519439741349, 'max_depth': 9, 'min_samples_leaf': 10, 'min_samples_split': 59}
#   Sample 163: {'ccp_alpha': 0.6182180633162611, 'max_depth': 29, 'min_samples_leaf': 38, 'min_samples_split': 8}
#   Sample 164: {'ccp_alpha': 0.4260914750469411, 'max_depth': 8, 'min_samples_leaf': 42, 'min_samples_split': 10}
#   Sample 165: {'ccp_alpha': 0.8218600592903562, 'max_depth': 26, 'min_samples_leaf': 2, 'min_samples_split': 6}
#   Sample 166: {'ccp_alpha': 0.5133261686923929, 'max_depth': 6, 'min_samples_leaf': 19, 'min_samples_split': 9}
#   Sample 167: {'ccp_alpha': 0.3742707957561203, 'max_depth': 1, 'min_samples_leaf': 22, 'min_samples_split': 53}
#   Sample 168: {'ccp_alpha': 0.23668519368207874, 'max_depth': 7, 'min_samples_leaf': 25, 'min_samples_split': 46}
#   Sample 169: {'ccp_alpha': 0.7533781852589416, 'max_depth': 6, 'min_samples_leaf': 60, 'min_samples_split': 32}
#   Sample 170: {'ccp_alpha': 0.48166698796411533, 'max_depth': 12, 'min_samples_leaf': 54, 'min_samples_split': 40}
#   Sample 171: {'ccp_alpha': 0.4242220092469763, 'max_depth': 26, 'min_samples_leaf': 19, 'min_samples_split': 40}
#   Sample 172: {'ccp_alpha': 0.43445184448827134, 'max_depth': 13, 'min_samples_leaf': 13, 'min_samples_split': 51}
#   Sample 173: {'ccp_alpha': 0.46866064199412627, 'max_depth': 26, 'min_samples_leaf': 20, 'min_samples_split': 29}
#   Sample 174: {'ccp_alpha': 0.7671948531085717, 'max_depth': 9, 'min_samples_leaf': 39, 'min_samples_split': 2}
#   Sample 175: {'ccp_alpha': 0.681039427096909, 'max_depth': 28, 'min_samples_leaf': 57, 'min_samples_split': 50}
#   Sample 176: {'ccp_alpha': 0.08289132169335423, 'max_depth': 1, 'min_samples_leaf': 38, 'min_samples_split': 54}
#   Sample 177: {'ccp_alpha': 0.9632225394406113, 'max_depth': 12, 'min_samples_leaf': 45, 'min_samples_split': 33}
#   Sample 178: {'ccp_alpha': 0.5560050386425845, 'max_depth': 15, 'min_samples_leaf': 21, 'min_samples_split': 17}
#   Sample 179: {'ccp_alpha': 0.5277011090862999, 'max_depth': 11, 'min_samples_leaf': 60, 'min_samples_split': 38}
#   Sample 180: {'ccp_alpha': 0.2529901679892411, 'max_depth': 19, 'min_samples_leaf': 20, 'min_samples_split': 58}
#   Sample 181: {'ccp_alpha': 0.5230978441701488, 'max_depth': 9, 'min_samples_leaf': 49, 'min_samples_split': 15}
#   Sample 182: {'ccp_alpha': 0.29449394683942987, 'max_depth': 1, 'min_samples_leaf': 53, 'min_samples_split': 55}
#   Sample 183: {'ccp_alpha': 0.5843143119231002, 'max_depth': 16, 'min_samples_leaf': 23, 'min_samples_split': 58}
#   Sample 184: {'ccp_alpha': 0.9152543416691064, 'max_depth': 10, 'min_samples_leaf': 32, 'min_samples_split': 17}
#   Sample 185: {'ccp_alpha': 0.8902637838909163, 'max_depth': 12, 'min_samples_leaf': 24, 'min_samples_split': 29}
#   Sample 186: {'ccp_alpha': 0.3356600647969632, 'max_depth': 26, 'min_samples_leaf': 28, 'min_samples_split': 37}
#   Sample 187: {'ccp_alpha': 0.46369840493998216, 'max_depth': 26, 'min_samples_leaf': 60, 'min_samples_split': 51}
#   Sample 188: {'ccp_alpha': 0.26593792496423896, 'max_depth': 5, 'min_samples_leaf': 41, 'min_samples_split': 37}
#   Sample 189: {'ccp_alpha': 0.9862107444796029, 'max_depth': 22, 'min_samples_leaf': 17, 'min_samples_split': 10}
#   Sample 190: {'ccp_alpha': 0.30952761628632774, 'max_depth': 20, 'min_samples_leaf': 13, 'min_samples_split': 29}
#   Sample 191: {'ccp_alpha': 0.2709576425151299, 'max_depth': 13, 'min_samples_leaf': 46, 'min_samples_split': 36}
#   Sample 192: {'ccp_alpha': 0.822537242923169, 'max_depth': 18, 'min_samples_leaf': 51, 'min_samples_split': 6}
#   Sample 193: {'ccp_alpha': 0.6134151959357899, 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 57}
#   Sample 194: {'ccp_alpha': 0.8766614859257927, 'max_depth': 27, 'min_samples_leaf': 45, 'min_samples_split': 6}
#   Sample 195: {'ccp_alpha': 0.026366974497252005, 'max_depth': 1, 'min_samples_leaf': 54, 'min_samples_split': 2}
#   Sample 196: {'ccp_alpha': 0.48037008186635466, 'max_depth': 15, 'min_samples_leaf': 49, 'min_samples_split': 12}
#   Sample 197: {'ccp_alpha': 0.5941307153521351, 'max_depth': 25, 'min_samples_leaf': 22, 'min_samples_split': 60}
#   Sample 198: {'ccp_alpha': 0.8421189231357087, 'max_depth': 13, 'min_samples_leaf': 33, 'min_samples_split': 35}
#   Sample 199: {'ccp_alpha': 0.03682186763599138, 'max_depth': 1, 'min_samples_leaf': 21, 'min_samples_split': 49}
#   Sample 200: {'ccp_alpha': 0.07535906035246231, 'max_depth': 28, 'min_samples_leaf': 17, 'min_samples_split': 6}
# Random Forest samples:
#   Sample 1: {'max_features': 0.3745401188473625, 'max_samples': 0.19507143064099164, 'min_samples_leaf': 11, 'n_estimators': 1096}
#   Sample 2: {'max_features': 0.5986584841970366, 'max_samples': 0.11560186404424366, 'min_samples_leaf': 19, 'n_estimators': 1239}
#   Sample 3: {'max_features': 0.05808361216819946, 'max_samples': 0.18661761457749354, 'min_samples_leaf': 4, 'n_estimators': 872}
#   Sample 4: {'max_features': 0.7080725777960455, 'max_samples': 0.10205844942958026, 'min_samples_leaf': 2, 'n_estimators': 344}
#   Sample 5: {'max_features': 0.8324426408004217, 'max_samples': 0.12123391106782762, 'min_samples_leaf': 28, 'n_estimators': 277}
#   Sample 6: {'max_features': 0.6174815096277165, 'max_samples': 0.1611653160488281, 'min_samples_leaf': 29, 'n_estimators': 748}
#   Sample 7: {'max_features': 0.023062425041415757, 'max_samples': 0.15247746602583892, 'min_samples_leaf': 10, 'n_estimators': 1500}
#   Sample 8: {'max_features': 0.9737555188414592, 'max_samples': 0.12327713404303042, 'min_samples_leaf': 30, 'n_estimators': 687}
#   Sample 9: {'max_features': 0.6183860093330873, 'max_samples': 0.1382461991267163, 'min_samples_leaf': 20, 'n_estimators': 832}
#   Sample 10: {'max_features': 0.4667628932479799, 'max_samples': 0.18599404067363207, 'min_samples_leaf': 7, 'n_estimators': 21}
#   Sample 11: {'max_features': 0.450499251969543, 'max_samples': 0.10132649611598665, 'min_samples_leaf': 25, 'n_estimators': 316}
#   Sample 12: {'max_features': 0.5632882178455393, 'max_samples': 0.13854165025399162, 'min_samples_leaf': 26, 'n_estimators': 565}
#   Sample 13: {'max_features': 0.230893825622149, 'max_samples': 0.12410254660260117, 'min_samples_leaf': 28, 'n_estimators': 1479}
#   Sample 14: {'max_features': 0.6099966577826209, 'max_samples': 0.18331949117361646, 'min_samples_leaf': 3, 'n_estimators': 206}
#   Sample 15: {'max_features': 0.3910606075732408, 'max_samples': 0.11822360877880624, 'min_samples_leaf': 4, 'n_estimators': 1026}
#   Sample 16: {'max_features': 0.4251558744912447, 'max_samples': 0.12079416628681888, 'min_samples_leaf': 4, 'n_estimators': 1846}
#   Sample 17: {'max_features': 0.03131329245555858, 'max_samples': 0.18422847745949986, 'min_samples_leaf': 12, 'n_estimators': 162}
#   Sample 18: {'max_features': 0.3951502360018144, 'max_samples': 0.19266588657937944, 'min_samples_leaf': 16, 'n_estimators': 1295}
#   Sample 19: {'max_features': 0.0884925020519195, 'max_samples': 0.11959828624191453, 'min_samples_leaf': 25, 'n_estimators': 1726}
#   Sample 20: {'max_features': 0.32533033076326434, 'max_samples': 0.13886772896894822, 'min_samples_leaf': 18, 'n_estimators': 879}
#   Sample 21: {'max_features': 0.8287375091519293, 'max_samples': 0.13567533266935894, 'min_samples_leaf': 28, 'n_estimators': 188}
#   Sample 22: {'max_features': 0.5426960831582485, 'max_samples': 0.11409242249747627, 'min_samples_leaf': 15, 'n_estimators': 1837}
#   Sample 23: {'max_features': 0.07455064367977082, 'max_samples': 0.19868869366005174, 'min_samples_leaf': 24, 'n_estimators': 1153}
#   Sample 24: {'max_features': 0.1987156815341724, 'max_samples': 0.10055221171236024, 'min_samples_leaf': 11, 'n_estimators': 1523}
#   Sample 25: {'max_features': 0.7068573438476171, 'max_samples': 0.17290071680409874, 'min_samples_leaf': 1, 'n_estimators': 379}
#   Sample 26: {'max_features': 0.07404465173409036, 'max_samples': 0.13584657285442728, 'min_samples_leaf': 9, 'n_estimators': 1052}
#   Sample 27: {'max_features': 0.8631034258755935, 'max_samples': 0.16232981268275581, 'min_samples_leaf': 2, 'n_estimators': 1057}
#   Sample 28: {'max_features': 0.06355835028602363, 'max_samples': 0.13109823217156624, 'min_samples_leaf': 24, 'n_estimators': 805}
#   Sample 29: {'max_features': 0.7296061783380641, 'max_samples': 0.16375574713552132, 'min_samples_leaf': 27, 'n_estimators': 1571}
#   Sample 30: {'max_features': 0.4722149251619493, 'max_samples': 0.11195942459383018, 'min_samples_leaf': 14, 'n_estimators': 643}
#   Sample 31: {'max_features': 0.7607850486168974, 'max_samples': 0.15612771975694964, 'min_samples_leaf': 14, 'n_estimators': 871}
#   Sample 32: {'max_features': 0.04043358953843135, 'max_samples': 0.17106628896857873, 'min_samples_leaf': 26, 'n_estimators': 1578}
#   Sample 33: {'max_features': 0.4393365018657701, 'max_samples': 0.12017192023353962, 'min_samples_leaf': 7, 'n_estimators': 1265}
#   Sample 34: {'max_features': 0.3143559810763267, 'max_samples': 0.1508570691164703, 'min_samples_leaf': 30, 'n_estimators': 485}
#   Sample 35: {'max_features': 0.24929222914887494, 'max_samples': 0.141038292303563, 'min_samples_leaf': 11, 'n_estimators': 541}
#   Sample 36: {'max_features': 0.22879816549162246, 'max_samples': 0.1076979909828793, 'min_samples_leaf': 27, 'n_estimators': 1267}
#   Sample 37: {'max_features': 0.16122128725400442, 'max_samples': 0.19296976523425732, 'min_samples_leaf': 13, 'n_estimators': 1598}
#   Sample 38: {'max_features': 0.6334037565104235, 'max_samples': 0.1871460590187718, 'min_samples_leaf': 28, 'n_estimators': 1644}
#   Sample 39: {'max_features': 0.18657005888603584, 'max_samples': 0.1892558998489978, 'min_samples_leaf': 11, 'n_estimators': 1664}
#   Sample 40: {'max_features': 0.8074401551640625, 'max_samples': 0.18960912999234933, 'min_samples_leaf': 7, 'n_estimators': 190}
#   Sample 41: {'max_features': 0.11005192452767676, 'max_samples': 0.12279351625419417, 'min_samples_leaf': 30, 'n_estimators': 633}
#   Sample 42: {'max_features': 0.8180147659224931, 'max_samples': 0.18607305832563437, 'min_samples_leaf': 7, 'n_estimators': 710}
#   Sample 43: {'max_features': 0.5107473025775657, 'max_samples': 0.1417411003148779, 'min_samples_leaf': 5, 'n_estimators': 1249}
#   Sample 44: {'max_features': 0.1198653673336828, 'max_samples': 0.1337615171403628, 'min_samples_leaf': 15, 'n_estimators': 1851}
#   Sample 45: {'max_features': 0.32320293202075523, 'max_samples': 0.1518790621743366, 'min_samples_leaf': 9, 'n_estimators': 1716}
#   Sample 46: {'max_features': 0.363629602379294, 'max_samples': 0.1971782082720961, 'min_samples_leaf': 20, 'n_estimators': 1292}
#   Sample 47: {'max_features': 0.25178229582536416, 'max_samples': 0.14972485058923857, 'min_samples_leaf': 17, 'n_estimators': 1637}
#   Sample 48: {'max_features': 0.2848404943774676, 'max_samples': 0.10368869473545328, 'min_samples_leaf': 17, 'n_estimators': 2}
#   Sample 49: {'max_features': 0.5026790232288615, 'max_samples': 0.10514787512499894, 'min_samples_leaf': 5, 'n_estimators': 1760}
#   Sample 50: {'max_features': 0.9082658859666537, 'max_samples': 0.12395618906669725, 'min_samples_leaf': 2, 'n_estimators': 1077}
#   Sample 51: {'max_features': 0.489452760277563, 'max_samples': 0.19856504541106007, 'min_samples_leaf': 23, 'n_estimators': 836}
#   Sample 52: {'max_features': 0.08085332633271525, 'max_samples': 0.13696544560614046, 'min_samples_leaf': 17, 'n_estimators': 767}
#   Sample 53: {'max_features': 0.8031397563798959, 'max_samples': 0.14703006344460384, 'min_samples_leaf': 2, 'n_estimators': 198}
#   Sample 54: {'max_features': 0.39882444244455306, 'max_samples': 0.1816431873219384, 'min_samples_leaf': 16, 'n_estimators': 609}
#   Sample 55: {'max_features': 0.15071754396542947, 'max_samples': 0.15081987767407187, 'min_samples_leaf': 16, 'n_estimators': 1373}
#   Sample 56: {'max_features': 0.8583588048137198, 'max_samples': 0.1325958905201885, 'min_samples_leaf': 4, 'n_estimators': 403}
#   Sample 57: {'max_features': 0.7111495324380178, 'max_samples': 0.18095010461397154, 'min_samples_leaf': 20, 'n_estimators': 864}
#   Sample 58: {'max_features': 0.09617655109142076, 'max_samples': 0.19405232644896042, 'min_samples_leaf': 8, 'n_estimators': 1664}
#   Sample 59: {'max_features': 0.5177513505274801, 'max_samples': 0.1837710105907328, 'min_samples_leaf': 11, 'n_estimators': 1977}
#   Sample 60: {'max_features': 0.11347352124058907, 'max_samples': 0.1924693618278563, 'min_samples_leaf': 30, 'n_estimators': 1322}
#   Sample 61: {'max_features': 0.2579416277151556, 'max_samples': 0.16599840460341792, 'min_samples_leaf': 26, 'n_estimators': 624}
#   Sample 62: {'max_features': 0.5552008115994623, 'max_samples': 0.15296505783560066, 'min_samples_leaf': 2, 'n_estimators': 897}
#   Sample 63: {'max_features': 0.09310276780589921, 'max_samples': 0.1897215757953327, 'min_samples_leaf': 5, 'n_estimators': 1184}
#   Sample 64: {'max_features': 0.6331014572732679, 'max_samples': 0.1339029791048701, 'min_samples_leaf': 3, 'n_estimators': 1683}
#   Sample 65: {'max_features': 0.7259556788702394, 'max_samples': 0.18971102599525771, 'min_samples_leaf': 24, 'n_estimators': 54}
#   Sample 66: {'max_features': 0.7798755458576239, 'max_samples': 0.16420316461542878, 'min_samples_leaf': 11, 'n_estimators': 1649}
#   Sample 67: {'max_features': 0.16162871409461377, 'max_samples': 0.18985541885270793, 'min_samples_leaf': 20, 'n_estimators': 254}
#   Sample 68: {'max_features': 0.009197051616629648, 'max_samples': 0.11014715428660321, 'min_samples_leaf': 3, 'n_estimators': 153}
#   Sample 69: {'max_features': 0.005061583846218687, 'max_samples': 0.11608080514174987, 'min_samples_leaf': 18, 'n_estimators': 1730}
#   Sample 70: {'max_features': 0.6918951976926933, 'max_samples': 0.16519612595026006, 'min_samples_leaf': 9, 'n_estimators': 161}
#   Sample 71: {'max_features': 0.018075363615520867, 'max_samples': 0.14938937151834347, 'min_samples_leaf': 16, 'n_estimators': 1940}
#   Sample 72: {'max_features': 0.3664687845828599, 'max_samples': 0.17441705230565624, 'min_samples_leaf': 3, 'n_estimators': 401}
#   Sample 73: {'max_features': 0.3080607918523892, 'max_samples': 0.15425402305548994, 'min_samples_leaf': 27, 'n_estimators': 1907}
# ...
#   Sample 80: {'max_features': 0.9148643902204485, 'max_samples': 0.13701587002554444, 'min_samples_leaf': 9, 'n_estimators': 1061}
#   Sample 81: {'max_features': 0.9283185625877254, 'max_samples': 0.14281841483173144, 'min_samples_leaf': 21, 'n_estimators': 607}
#   Sample 82: {'max_features': 0.9636199770892528, 'max_samples': 0.185300945546736, 'min_samples_leaf': 29, 'n_estimators': 981}
#   Sample 83: {'max_features': 0.19091103115034602, 'max_samples': 0.1268474856890157, 'min_samples_leaf': 3, 'n_estimators': 128}
#   Sample 84: {'max_features': 0.3726868670940493, 'max_samples': 0.13946914668094723, 'min_samples_leaf': 22, 'n_estimators': 570}
#   Sample 85: {'max_features': 0.9300168348108319, 'max_samples': 0.1070416130849544, 'min_samples_leaf': 18, 'n_estimators': 1312}
#   Sample 86: {'max_features': 0.6711435168240506, 'max_samples': 0.1358646781296164, 'min_samples_leaf': 27, 'n_estimators': 490}
#   Sample 87: {'max_features': 0.8773730719279554, 'max_samples': 0.17407686177542045, 'min_samples_leaf': 1, 'n_estimators': 1417}
#   Sample 88: {'max_features': 0.7024840839871093, 'max_samples': 0.13594911512197552, 'min_samples_leaf': 29, 'n_estimators': 1706}
#   Sample 89: {'max_features': 0.8093611554785136, 'max_samples': 0.1810113394679181, 'min_samples_leaf': 25, 'n_estimators': 408}
#   Sample 90: {'max_features': 0.9132405525564713, 'max_samples': 0.15113423988609379, 'min_samples_leaf': 25, 'n_estimators': 36}
#   Sample 91: {'max_features': 0.7982951789667752, 'max_samples': 0.16499639307777653, 'min_samples_leaf': 14, 'n_estimators': 400}
#   Sample 92: {'max_features': 0.050768531039396936, 'max_samples': 0.188661714895066, 'min_samples_leaf': 15, 'n_estimators': 1116}
#   Sample 93: {'max_features': 0.5788648955075587, 'max_samples': 0.1438474123018087, 'min_samples_leaf': 22, 'n_estimators': 51}
#   Sample 94: {'max_features': 0.46559801813246016, 'max_samples': 0.15426446347075767, 'min_samples_leaf': 29, 'n_estimators': 150}
#   Sample 95: {'max_features': 0.5908332605690108, 'max_samples': 0.10305002499390495, 'min_samples_leaf': 20, 'n_estimators': 682}
#   Sample 96: {'max_features': 0.8226005606596583, 'max_samples': 0.1360190641411263, 'min_samples_leaf': 28, 'n_estimators': 613}
#   Sample 97: {'max_features': 0.5222432600548044, 'max_samples': 0.1769993553098611, 'min_samples_leaf': 12, 'n_estimators': 1644}
#   Sample 98: {'max_features': 0.6228904758190003, 'max_samples': 0.1085347464993768, 'min_samples_leaf': 13, 'n_estimators': 992}
#   Sample 99: {'max_features': 0.531354631568148, 'max_samples': 0.15406351216101066, 'min_samples_leaf': 23, 'n_estimators': 936}
#   Sample 100: {'max_features': 0.7260913337226615, 'max_samples': 0.19758520794625348, 'min_samples_leaf': 28, 'n_estimators': 1130}
#   Sample 101: {'max_features': 0.32295647294124596, 'max_samples': 0.17951861947687037, 'min_samples_leaf': 19, 'n_estimators': 1628}
#   Sample 102: {'max_features': 0.7440426429991154, 'max_samples': 0.12508605273466614, 'min_samples_leaf': 26, 'n_estimators': 117}
#   Sample 103: {'max_features': 0.08087296661719767, 'max_samples': 0.14283144749401078, 'min_samples_leaf': 12, 'n_estimators': 1013}
#   Sample 104: {'max_features': 0.05819359550844361, 'max_samples': 0.19152137276264805, 'min_samples_leaf': 15, 'n_estimators': 802}
#   Sample 105: {'max_features': 0.23978735915740323, 'max_samples': 0.10938732900812918, 'min_samples_leaf': 25, 'n_estimators': 488}
#   Sample 106: {'max_features': 0.9346139973397097, 'max_samples': 0.16382705938433506, 'min_samples_leaf': 29, 'n_estimators': 704}
#   Sample 107: {'max_features': 0.5543540525114007, 'max_samples': 0.16117207462343525, 'min_samples_leaf': 23, 'n_estimators': 1987}
#   Sample 108: {'max_features': 0.24773098950115746, 'max_samples': 0.13559726786512616, 'min_samples_leaf': 5, 'n_estimators': 1110}
#   Sample 109: {'max_features': 0.014393488629755868, 'max_samples': 0.11160726405069163, 'min_samples_leaf': 5, 'n_estimators': 1071}
#   Sample 110: {'max_features': 0.040728802318970136, 'max_samples': 0.18554605840110072, 'min_samples_leaf': 20, 'n_estimators': 453}
#   Sample 111: {'max_features': 0.4741738290873252, 'max_samples': 0.10978341606510016, 'min_samples_leaf': 16, 'n_estimators': 341}
#   Sample 112: {'max_features': 0.4734717707805657, 'max_samples': 0.11732018699100152, 'min_samples_leaf': 30, 'n_estimators': 357}
#   Sample 113: {'max_features': 0.39850473439737344, 'max_samples': 0.16158500980522167, 'min_samples_leaf': 5, 'n_estimators': 1124}
#   Sample 114: {'max_features': 0.04530400977204452, 'max_samples': 0.13746126146264714, 'min_samples_leaf': 26, 'n_estimators': 1683}
#   Sample 115: {'max_features': 0.5031362585800877, 'max_samples': 0.18564898411883224, 'min_samples_leaf': 5, 'n_estimators': 516}
#   Sample 116: {'max_features': 0.6158511643899138, 'max_samples': 0.19438916045607574, 'min_samples_leaf': 2, 'n_estimators': 497}
#   Sample 117: {'max_features': 0.8671989335550038, 'max_samples': 0.16364035974460112, 'min_samples_leaf': 20, 'n_estimators': 1688}
#   Sample 118: {'max_features': 0.6771683423829817, 'max_samples': 0.15733670416719334, 'min_samples_leaf': 1, 'n_estimators': 1953}
#   Sample 119: {'max_features': 0.811204176736003, 'max_samples': 0.18206394757439553, 'min_samples_leaf': 12, 'n_estimators': 1859}
#   Sample 120: {'max_features': 0.8204268437712681, 'max_samples': 0.1651484771857788, 'min_samples_leaf': 11, 'n_estimators': 1580}
#   Sample 121: {'max_features': 0.27396112732113376, 'max_samples': 0.12145891197083741, 'min_samples_leaf': 14, 'n_estimators': 1922}
#   Sample 122: {'max_features': 0.03896313231023363, 'max_samples': 0.1618253884337893, 'min_samples_leaf': 23, 'n_estimators': 849}
#   Sample 123: {'max_features': 0.6557226353807422, 'max_samples': 0.13853966209655652, 'min_samples_leaf': 10, 'n_estimators': 1626}
#   Sample 124: {'max_features': 0.34062456946424, 'max_samples': 0.12606945282359033, 'min_samples_leaf': 7, 'n_estimators': 1220}
#   Sample 125: {'max_features': 0.6928903586919394, 'max_samples': 0.13483366044531975, 'min_samples_leaf': 11, 'n_estimators': 413}
#   Sample 126: {'max_features': 0.039186326675646255, 'max_samples': 0.1417946031715579, 'min_samples_leaf': 29, 'n_estimators': 761}
#   Sample 127: {'max_features': 0.5479718832480873, 'max_samples': 0.14234709423081188, 'min_samples_leaf': 24, 'n_estimators': 192}
#   Sample 128: {'max_features': 0.5759245752580846, 'max_samples': 0.173164775529964, 'min_samples_leaf': 4, 'n_estimators': 978}
#   Sample 129: {'max_features': 0.25001644921610466, 'max_samples': 0.158054401234391, 'min_samples_leaf': 23, 'n_estimators': 1214}
#   Sample 130: {'max_features': 0.5618666921437736, 'max_samples': 0.12385968597903402, 'min_samples_leaf': 23, 'n_estimators': 1549}
#   Sample 131: {'max_features': 0.7399087604473745, 'max_samples': 0.12382361524039795, 'min_samples_leaf': 30, 'n_estimators': 1297}
#   Sample 132: {'max_features': 0.5343274735305634, 'max_samples': 0.14965611906830778, 'min_samples_leaf': 25, 'n_estimators': 1366}
#   Sample 133: {'max_features': 0.2976351745093109, 'max_samples': 0.10999848871618634, 'min_samples_leaf': 4, 'n_estimators': 396}
#   Sample 134: {'max_features': 0.9585414968831983, 'max_samples': 0.184714314409559, 'min_samples_leaf': 9, 'n_estimators': 455}
#   Sample 135: {'max_features': 0.9568008851264563, 'max_samples': 0.16767699044243034, 'min_samples_leaf': 20, 'n_estimators': 851}
#   Sample 136: {'max_features': 0.49302565777180496, 'max_samples': 0.10832844111952597, 'min_samples_leaf': 5, 'n_estimators': 1123}
#   Sample 137: {'max_features': 0.602440925901119, 'max_samples': 0.1553703052345801, 'min_samples_leaf': 21, 'n_estimators': 1508}
#   Sample 138: {'max_features': 0.9461945428816902, 'max_samples': 0.17812960504712028, 'min_samples_leaf': 7, 'n_estimators': 109}
#   Sample 139: {'max_features': 0.9309291056872926, 'max_samples': 0.19742482085344104, 'min_samples_leaf': 14, 'n_estimators': 1247}
#   Sample 140: {'max_features': 0.05587115467735004, 'max_samples': 0.1737035556791009, 'min_samples_leaf': 29, 'n_estimators': 235}
#   Sample 141: {'max_features': 0.7058314838786945, 'max_samples': 0.1968651943974135, 'min_samples_leaf': 9, 'n_estimators': 1098}
#   Sample 142: {'max_features': 0.8369638742373738, 'max_samples': 0.18668687053108415, 'min_samples_leaf': 6, 'n_estimators': 1543}
#   Sample 143: {'max_features': 0.4260914750469411, 'max_samples': 0.12225764175710306, 'min_samples_leaf': 9, 'n_estimators': 946}
#   Sample 144: {'max_features': 0.8918969087767766, 'max_samples': 0.11466048216920255, 'min_samples_leaf': 29, 'n_estimators': 1189}
#   Sample 145: {'max_features': 0.2332280724245278, 'max_samples': 0.15813054172267824, 'min_samples_leaf': 13, 'n_estimators': 1857}
#   Sample 146: {'max_features': 0.8803599686384168, 'max_samples': 0.12366851936820789, 'min_samples_leaf': 7, 'n_estimators': 217}
#   Sample 147: {'max_features': 0.5918887388212843, 'max_samples': 0.13502182467003138, 'min_samples_leaf': 28, 'n_estimators': 1439}
#   Sample 148: {'max_features': 0.48166698796411533, 'max_samples': 0.13779875901222546, 'min_samples_leaf': 7, 'n_estimators': 91}
#   Sample 149: {'max_features': 0.24872415443028795, 'max_samples': 0.13302525290190986, 'min_samples_leaf': 30, 'n_estimators': 1475}
#   Sample 150: {'max_features': 0.25368217387313874, 'max_samples': 0.14052020867814172, 'min_samples_leaf': 30, 'n_estimators': 1082}
#   Sample 151: {'max_features': 0.7409738609106683, 'max_samples': 0.17671948531085718, 'min_samples_leaf': 9, 'n_estimators': 1959}
#   Sample 152: {'max_features': 0.7460448792654233, 'max_samples': 0.15833687650971598, 'min_samples_leaf': 30, 'n_estimators': 505}
#   Sample 153: {'max_features': 0.37487057952370406, 'max_samples': 0.12857120862818608, 'min_samples_leaf': 24, 'n_estimators': 929}
#   Sample 154: {'max_features': 0.22359583851945264, 'max_samples': 0.19632225394406114, 'min_samples_leaf': 12, 'n_estimators': 685}
#   Sample 155: {'max_features': 0.969878826707639, 'max_samples': 0.10431599119505762, 'min_samples_leaf': 21, 'n_estimators': 80}
#   Sample 156: {'max_features': 0.5277011090862999, 'max_samples': 0.19929647961193003, 'min_samples_leaf': 5, 'n_estimators': 1700}
#   Sample 157: {'max_features': 0.5538542844013208, 'max_samples': 0.1969302535619099, 'min_samples_leaf': 18, 'n_estimators': 47}
#   Sample 158: {'max_features': 0.6293986381352625, 'max_samples': 0.16957486889846174, 'min_samples_leaf': 1, 'n_estimators': 1397}
#   Sample 159: {'max_features': 0.6969250558638148, 'max_samples': 0.138420183137922, 'min_samples_leaf': 23, 'n_estimators': 1977}
#   Sample 160: {'max_features': 0.9152543416691064, 'max_samples': 0.19587024074078463, 'min_samples_leaf': 16, 'n_estimators': 968}
#   Sample 161: {'max_features': 0.39452179860812986, 'max_samples': 0.11067560659358844, 'min_samples_leaf': 21, 'n_estimators': 1032}
#   Sample 162: {'max_features': 0.16967990389556553, 'max_samples': 0.1646848361668724, 'min_samples_leaf': 8, 'n_estimators': 698}
#   Sample 163: {'max_features': 0.22939474570494967, 'max_samples': 0.1265937924964239, 'min_samples_leaf': 5, 'n_estimators': 41}
#   Sample 164: {'max_features': 0.2599498628542627, 'max_samples': 0.1453240846828831, 'min_samples_leaf': 17, 'n_estimators': 1225}
#   Sample 165: {'max_features': 0.30952761628632774, 'max_samples': 0.18137950197069488, 'min_samples_leaf': 28, 'n_estimators': 752}
#   Sample 166: {'max_features': 0.1626169393448913, 'max_samples': 0.19109271844938425, 'min_samples_leaf': 29, 'n_estimators': 390}
#   Sample 167: {'max_features': 0.949799913291924, 'max_samples': 0.172571950838836, 'min_samples_leaf': 15, 'n_estimators': 1945}
#   Sample 168: {'max_features': 0.4182430362906189, 'max_samples': 0.19327284833540134, 'min_samples_leaf': 18, 'n_estimators': 1275}
#   Sample 169: {'max_features': 0.04521867010618941, 'max_samples': 0.1026366974497252, 'min_samples_leaf': 1, 'n_estimators': 374}
#   Sample 170: {'max_features': 0.8105533307818329, 'max_samples': 0.19872761293149446, 'min_samples_leaf': 17, 'n_estimators': 1803}
#   Sample 171: {'max_features': 0.5941307153521351, 'max_samples': 0.13808908566310216, 'min_samples_leaf': 22, 'n_estimators': 827}
#   Sample 172: {'max_features': 0.8421189231357087, 'max_samples': 0.1838328704711138, 'min_samples_leaf': 2, 'n_estimators': 105}
#   Sample 173: {'max_features': 0.4148195023376652, 'max_samples': 0.12734070719307064, 'min_samples_leaf': 16, 'n_estimators': 823}
#   Sample 174: {'max_features': 0.8647223762550532, 'max_samples': 0.18129010091300776, 'min_samples_leaf': 5, 'n_estimators': 1894}
#   Sample 175: {'max_features': 0.9131657522576428, 'max_samples': 0.15851495323254722, 'min_samples_leaf': 21, 'n_estimators': 677}
#   Sample 176: {'max_features': 0.7570812020424559, 'max_samples': 0.13778505492757864, 'min_samples_leaf': 21, 'n_estimators': 1102}
#   Sample 177: {'max_features': 0.2050453285065249, 'max_samples': 0.12514424395117985, 'min_samples_leaf': 13, 'n_estimators': 717}
#   Sample 178: {'max_features': 0.20722764900805646, 'max_samples': 0.18782206674791924, 'min_samples_leaf': 8, 'n_estimators': 1824}
#   Sample 179: {'max_features': 0.04689646779121992, 'max_samples': 0.12686724820253076, 'min_samples_leaf': 7, 'n_estimators': 154}
#   Sample 180: {'max_features': 0.49816518664589293, 'max_samples': 0.14762106967890143, 'min_samples_leaf': 3, 'n_estimators': 1915}
#   Sample 181: {'max_features': 0.3077772397710494, 'max_samples': 0.18163857352130625, 'min_samples_leaf': 12, 'n_estimators': 389}
#   Sample 182: {'max_features': 0.08840822336564658, 'max_samples': 0.1791817839469633, 'min_samples_leaf': 17, 'n_estimators': 624}
#   Sample 183: {'max_features': 0.48004596701847513, 'max_samples': 0.14205357786650752, 'min_samples_leaf': 5, 'n_estimators': 853}
#   Sample 184: {'max_features': 0.6393613569742423, 'max_samples': 0.1805044667519362, 'min_samples_leaf': 7, 'n_estimators': 1446}
#   Sample 185: {'max_features': 0.617263712097292, 'max_samples': 0.1980462725092378, 'min_samples_leaf': 18, 'n_estimators': 98}
#   Sample 186: {'max_features': 0.6366443216222826, 'max_samples': 0.15548156085422257, 'min_samples_leaf': 19, 'n_estimators': 447}
#   Sample 187: {'max_features': 0.7263970326502283, 'max_samples': 0.15474463068991118, 'min_samples_leaf': 1, 'n_estimators': 984}
#   Sample 188: {'max_features': 0.910471278403273, 'max_samples': 0.12979594515419507, 'min_samples_leaf': 10, 'n_estimators': 1587}
#   Sample 189: {'max_features': 0.6976418714934634, 'max_samples': 0.17964717756738774, 'min_samples_leaf': 10, 'n_estimators': 184}
#   Sample 190: {'max_features': 0.8420914150187097, 'max_samples': 0.17689177413153975, 'min_samples_leaf': 20, 'n_estimators': 984}
#   Sample 191: {'max_features': 0.04586126640463295, 'max_samples': 0.16208056844220914, 'min_samples_leaf': 2, 'n_estimators': 205}
#   Sample 192: {'max_features': 0.20913079107851418, 'max_samples': 0.15796499344717385, 'min_samples_leaf': 11, 'n_estimators': 1907}
#   Sample 193: {'max_features': 0.5372634167140701, 'max_samples': 0.14601191589835721, 'min_samples_leaf': 16, 'n_estimators': 95}
#   Sample 194: {'max_features': 0.40030048891028136, 'max_samples': 0.16976675736969318, 'min_samples_leaf': 4, 'n_estimators': 360}
#   Sample 195: {'max_features': 0.696501466227079, 'max_samples': 0.14116612143575283, 'min_samples_leaf': 3, 'n_estimators': 667}
#   Sample 196: {'max_features': 0.6675577385210272, 'max_samples': 0.11723198712016299, 'min_samples_leaf': 26, 'n_estimators': 1075}
#   Sample 197: {'max_features': 0.04086861626647886, 'max_samples': 0.11689350630721645, 'min_samples_leaf': 28, 'n_estimators': 682}
#   Sample 198: {'max_features': 0.17701048427674682, 'max_samples': 0.10887025337570556, 'min_samples_leaf': 1, 'n_estimators': 645}
#   Sample 199: {'max_features': 0.46077876803272577, 'max_samples': 0.12063337184057926, 'min_samples_leaf': 2, 'n_estimators': 1969}
#   Sample 200: {'max_features': 0.5034172708548569, 'max_samples': 0.16903948286293652, 'min_samples_leaf': 9, 'n_estimators': 794}

# %%
# dicty do przechowywania wyników

best_random = {
    'Random Forest': {'diabetes': None,'students': None,'telco': None,'pistachio': None},
    'Decision Tree': {'diabetes': None,'students': None,'telco': None,'pistachio': None},
    'Logistic Regression' : {'diabetes': None,'students': None,'telco': None,'pistachio': None}
}

best_random_history = {
    'Random Forest': {'diabetes': [],'students': [],'telco': [],'pistachio':  []},
    'Decision Tree': {'diabetes': [],'students': [],'telco': [],'pistachio': []},
    'Logistic Regression' : {'diabetes': [],'students': [],'telco': [],'pistachio': []}
}

best_random_history_params = {
    'Random Forest': {'diabetes': [],'students': [],'telco': [],'pistachio':  []},
    'Decision Tree': {'diabetes': [],'students': [],'telco': [],'pistachio': []},
    'Logistic Regression' : {'diabetes': [],'students': [],'telco': [],'pistachio': []}
}

# %%
# funkcja do optymalizacji random uniform

random_history = {
    'Random Forest': {'diabetes': [],'students': [],'telco': [],'pistachio':  []},
    'Decision Tree': {'diabetes': [],'students': [],'telco': [],'pistachio': []},
    'Logistic Regression' : {'diabetes': [],'students': [],'telco': [],'pistachio': []}
}


optimization_metric = roc_auc_score
j=0
def optimize(model, param_samples):
    i = 0
    for dataset in datasets_wanted_size.keys():
        best_score = float('-inf')
        best_params = []
        for params in param_samples:
            
            estimator = models[model]()
            estimator.set_params(**params)
            pipe = Pipeline([("trans",col_trans),("model",estimator)])
            scores = cross_val_score(Pipeline([("trans",copy.deepcopy(col_trans)),("model",models[model]().set_params(**params))]), datasets_X_train[dataset], datasets_y_train[dataset], cv=3, scoring='roc_auc')  

            mean_score = scores.mean()
            std_score = scores.std()
            random_history[model][dataset].append(mean_score)
            if mean_score > best_score:
                best_score = mean_score
                best_params = params
                best_random[model][dataset] = Pipeline([("trans",copy.deepcopy(col_trans)),("model",models[model]().set_params(**params))])
                best_random[model][dataset].fit(datasets_X_train[dataset], datasets_y_train[dataset])
            best_random_history[model][dataset].append(best_score)
            best_random_history_params[model][dataset].append(best_params)
            i+=1
            # print(i,j)

# %%
for model in models.keys():
    optimize(model, param_samples[model])
    j+=1

# print(random_history)
# optimize('Random Forest', param_samples['Random Forest'])

# %%
save_models(best_random, '.\\Wyniki\\RandomSearch')

# %%
for model in models.keys():
    for dataset in datasets_wanted_size.keys():
        print(model,dataset)
        print(np.mean(random_history[model][dataset]))
        print(np.std(random_history[model][dataset]))
# Out:
# Decision Tree diabetes
# 0.5097439194256937
# 0.0417368271833306
# Decision Tree students
# 0.5794263298676795
# 0.14112083525361058
# Decision Tree telco
# 0.5135605720275531
# 0.05124294548307242
# Decision Tree pistachio
# 0.586077557117509
# 0.15332374285813066
# Random Forest diabetes
# 0.8914213677274188
# 0.02788266454305634
# Random Forest students
# 0.926642467353819
# 0.00916251500220737
# Random Forest telco
# 0.840161270483036
# 0.013288907555244363
# Random Forest pistachio
# 0.9462859406195568
# 0.0067005321832206925
# Logistic Regression diabetes
# 0.9429277831351118
# 0.010606427026409957
# Logistic Regression students
# 0.9513518341040479
# 0.002501556529722389
# Logistic Regression telco
# 0.8439648579557609
# 0.00033082568064931244
# Logistic Regression pistachio
# 0.9795944252906708
# 0.002333514783808032

# %%
best_random_200iter_archive_v1 = best_random.copy()
best_random_history_200iter_archive_v1 = best_random_history.copy()
best_random_history_params_200iter_archive_v1 = best_random_history_params.copy()

# %%
print(best_random_history)
# Out:
# {'Random Forest': {'diabetes': [0.9009027108111004, 0.9009027108111004, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.932484195864138, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985, 0.9397299903567985], 'students': [0.9324122431726877, 0.93241 ...

# %%
# ile iteracji każdej metody potrzebujemy żeby uzyskać stabilne wyniki optymalizacji
def best_metric_so_far(model):
    kolory = {
        'diabetes': 'red',
        'students': 'green',
        'telco': 'blue',
        'pistachio': 'purple'
    }
    for key  in best_random_history[model].keys():
        plt.plot(best_random_history[model][key],label = key,c = kolory[key])
    plt.legend()
    plt.title(f'{model}: best roc_auc_score')
    # plt.xticks([i for i in range(n_iter)], labels=[i+1 for i in range(n_iter)])
    plt.show()
    return

def chart_1():
    for i,key  in enumerate(best_random_history.keys()):
        # print(i,key)
        plt.subplot(3, 1, i+1)
        best_metric_so_far(key)
    return

# %%
# best_metric_so_far('Random Forest')
chart_1()

# %% [markdown]
# # Bayes Search

# %%
best_bayes = {
    'Random Forest': {'diabetes': None,'students': None,'telco': None,'pistachio': None},
    'Decision Tree': {'diabetes': None,'students': None,'telco': None,'pistachio': None},
    'Logistic Regression' : {'diabetes': None,'students': None,'telco': None,'pistachio': None}
}

best_bayes_score_history = {
    'Random Forest': {'diabetes': None,'students': None,'telco': None,'pistachio': None},
    'Decision Tree': {'diabetes': None,'students': None,'telco': None,'pistachio': None},
    'Logistic Regression' : {'diabetes': None,'students': None,'telco': None,'pistachio': None}
}

# %%
# siatki parametrów bayes
param_space_bayes = {
    'Logistic Regression': {
        'model__C': Real(0.01, 100.0, prior='uniform'),  
        'model__penalty': ['l1', 'l2'],                  
        'model__solver': ['liblinear'],                  
    },
    'Decision Tree': { 
        'model__ccp_alpha': Real(0.0, 1.0, prior='uniform'), 
        'model__max_depth': Integer(1, 30),                  
        'model__min_samples_leaf': Integer(1, 60),           
        'model__min_samples_split': Integer(2, 60),           
    },
    'Random Forest': {  
        'model__n_estimators': Integer(1, 2000),              
        'model__max_samples': Real(0.01, 1.0, prior='uniform'), 
        'model__max_features': Real(0.01, 1.0, prior='uniform'),
        'model__min_samples_leaf': Integer(1, 30),            
    }
}



# clas_model = LogisticRegression(max_iter=5000)
# search_space =
#   [
#    {
#     "solver": Categorical(['liblinear']),
#     "penalty": Categorical(['l1', 'l2']),
#     "fit_intercept": Categorical([True, False]),
#     #"warm_start": Categorical([True, False])
#    },
#    {
#     "solver": Categorical(['lbfgs', 'newton-cg', 'sag']),
#     "penalty": Categorical(['l2', 'none']),
#     "fit_intercept": Categorical([True, False]),
#     #"warm_start": Categorical([True, False])
#    },
#    {
#     "solver": Categorical(['saga']),
#     "penalty": Categorical(['l1', 'l2', 'none']),
#     "fit_intercept": Categorical([True, False]),
#     #"warm_start": Categorical([True, False])
#    },
#    {
#     "solver": Categorical(['saga']),
#     "penalty": Categorical(['elasticnet']),
#     "fit_intercept": Categorical([True, False]),
#     "l1_ratio": Real(0, 1, prior='uniform'),
#     #"warm_start": Categorical([True, False])
#    },
#   ]
# bayes_search = BayesSearchCV(clas_model, search_space, n_iter=12, scoring="accuracy", n_jobs=-1, cv=5)

# %%
scoring_metric = roc_auc_score

def bayes_optimize(model,param_space):
    for dataset in datasets_wanted_size.keys():
        opt = BayesSearchCV(
        Pipeline([("trans",col_trans),("model",models[model]())]),
        param_space,
        n_iter=50, 
        cv=2,       
        n_jobs=-1,  
        scoring=make_scorer(scoring_metric, needs_proba=True)
        )

        opt.fit(datasets_X_train[dataset],datasets_y_train[dataset])
        
        best_bayes[model][dataset] = opt.best_estimator_
        best_bayes_score_history[model][dataset] = opt.cv_results_['mean_test_score']

# %% [markdown]
# # Loswe punkty startowe ,a zbieżnosć BayesSearch

# %%
import numpy as np
from scipy.stats import uniform, randint
from skopt.space import Real

def sample_starting_points(param_space, n):
    """
    Losuje n punktów startowych na podstawie zadanej przestrzeni hiperparametrów.
    
    Args:
        param_space (dict): Słownik opisujący przestrzeń hiperparametrów. 
                            Wartości mogą być typu Real, Integer, lub lista.
        n (int): Liczba punktów startowych do wylosowania.
    
    Returns:
        list[dict]: Lista słowników z wylosowanymi punktami startowymi.
    """
    sampled_points = []
    
    for _ in range(n):
        point = {}
        for param, space in param_space.items():
            if isinstance(space, list):  # Dyskretna lista wartości
                point[param] = np.random.choice(space)
            elif isinstance(space, tuple) and hasattr(space[0], 'rvs'):  # np. Real/Integer
                point[param] = space[0].rvs(*space[1:])  # Losowanie z określonego rozkładu
            elif hasattr(space, 'rvs'):  # np. uniform lub inne rozkłady
                point[param] = space.rvs()
            else:
                raise ValueError(f"Nieobsługiwany typ przestrzeni dla {param}: {type(space)}")
        sampled_points.append(point)
    
    return sampled_points

param_space = { 
        'ccp_alpha': uniform(0, 1), 
        'max_depth': randint(1, 31),
        'min_samples_leaf': randint(1, 61),  
        'min_samples_split': randint(2, 61), 
    }

n = 5
print(sample_starting_points(param_space, n))
# Out:
# [{'ccp_alpha': 0.3429314442115151, 'max_depth': 19, 'min_samples_leaf': 58, 'min_samples_split': 8}, {'ccp_alpha': 0.020964858947121523, 'max_depth': 4, 'min_samples_leaf': 33, 'min_samples_split': 42}, {'ccp_alpha': 0.6171952738408194, 'max_depth': 1, 'min_samples_leaf': 6, 'min_samples_split': 44}, {'ccp_alpha': 0.07565104578810355, 'max_depth': 28, 'min_samples_leaf': 20, 'min_samples_split': 10}, {'ccp_alpha': 0.7198698358868902, 'max_depth': 18, 'min_samples_leaf': 18, 'min_samples_split': 6}]

# %%
# funkcja do optymalizacji bayesowaskiej i plotowania dla roznych punktow startowych


import matplotlib.pyplot as plt
from skopt import BayesSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import make_scorer, roc_auc_score

bayes_history = {
    'Random Forest': {'diabetes': [],'students': [],'telco': [],'pistachio':  []},
    'Decision Tree': {'diabetes': [],'students': [],'telco': [],'pistachio': []},
    'Logistic Regression' : {'diabetes': [],'students': [],'telco': [],'pistachio': []}
} 
# Modified bayes_optimize function
def bayes_optimize2(model, param_space, n):


    # Nie wiem jak ustawic punkt startowy w tym gównie wiec zaczynam z roznymi random seedami
    random_seed = [int(i * abs(np.sin(i&10)) + 10) for i in range(1,n+1)]
    score_history = {}  
    # starting_points = sample_starting_points(param_space, n)
    
    i = -1
    fig, axs = plt.subplots(1,4,figsize=(15, 5))
    for dataset in datasets_wanted_size.keys():
        
        i +=1
        for j in range(n):
            pipeline = Pipeline([("trans", copy.deepcopy(col_trans)), ("model", models[model]())])

            opt = BayesSearchCV(
                pipeline,
                param_space,
                n_iter=30,
                cv=2,
                n_jobs=-1,
                scoring=make_scorer(scoring_metric, needs_proba=True),
                random_state=random_seed[j]
                )

            opt.fit(
                datasets_X_train[dataset],
                datasets_y_train[dataset]
                    # Starting point for parameters
            )
            best_bayes[model][dataset] = opt.best_estimator_
            score_history[dataset] = opt.cv_results_['mean_test_score']
            bayes_history[model][dataset] = bayes_history[model][dataset] + list(score_history[dataset])
            # bayes_history[model][dataset]
            # print(list(score_history[dataset]))
            # print(bayes_history[model][dataset])
            axs[i].plot(score_history[dataset], label=f'{dataset}')
        axs[i].set_title(dataset)
        axs[i].set_ylim(.4,1)
    fig.suptitle('Bayes Optimization with different starting points for '+model, fontsize=16)
    plt.show()

    return best_bayes, score_history  # Return results for further inspection if needed

# %%
bayes_optimize2("Decision Tree", param_space_bayes['Decision Tree'],3)
# Out:
# ({'Random Forest': {'diabetes': None,
#    'students': None,
#    'telco': None,
#    'pistachio': None},
#   'Decision Tree': {'diabetes': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA8DC40>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA65010>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_split=60))]),
#    'students': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA64B60>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA67B60>)])),
#                    ('model',
#                     DecisionTreeClassifier(ccp_alpha=0.0038736462249052647,
#                                            max_depth=5, min_samples_leaf=39,
#                                            min_samples_split=8))]),
#    'telco': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA64D70>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA65160>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_leaf=60,
#                                            min_samples_split=60))]),
#    'pistachio': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA81490>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA83AA0>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_leaf=60,
#                                            min_samples_split=60))])},
#   'Logistic Regression': {'diabetes': None,
#    'students': None,
#    'telco': None,
#    'pistachio': None}},
#  {'diabetes': array([0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.80392157, 0.80702882, 0.5       , 0.66500589,
#          0.65686275, 0.80743062, 0.66500589, 0.65686275, 0.65686275,
#          0.5       , 0.5       , 0.5       , 0.5       , 0.80260902,
#          0.5       , 0.82601164, 0.82622594, 0.66500589, 0.86651309]),
#   'students': array([0.5       , 0.5       , 0.84798892, 0.84798892, 0.5       ,
#          0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.84798892, 0.84798892, 0.88364617, 0.84798892, 0.5       ,
#          0.84798892, 0.84798892, 0.84798892, 0.84798892, 0.86229379,
#          0.84798892, 0.84798892, 0.84798892, 0.84798892, 0.90392597,
#          0.84798892, 0.84798892, 0.84798892, 0.5       , 0.84798892]),
#   'telco': array([0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.76942056, 0.65854832, 0.64853677, 0.5       ,
#          0.72068911, 0.76781614, 0.64853677, 0.5       , 0.80423637,
#          0.80222194, 0.80423637, 0.80423637, 0.64853677, 0.80423637,
#          0.5       , 0.80423637, 0.80423637, 0.80423637, 0.71968368]),
#   'pistachio': array([0.5       , 0.5       , 0.85483285, 0.85483285, 0.5       ,
#          0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.85483285, 0.85483285, 0.90999444, 0.85483285, 0.5       ,
#          0.85483285, 0.85483285, 0.90699378, 0.9253242 , 0.5       ,
#          0.85483285, 0.5       , 0.5       , 0.82873819, 0.85483285,
#          0.85483285, 0.85483285, 0.85483285, 0.92486146, 0.85483285])})

# %%
bayes_optimize2('Random Forest', param_space_bayes["Random Forest"],3)
# Out:
# ({'Random Forest': {'diabetes': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA83B00>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEDB8E00>)])),
#                    ('model',
#                     RandomForestClassifier(max_features=0.01, max_samples=0.01,
#                                            n_estimators=2000))]),
#    'students': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7832C1F10>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7832C1970>)])),
#                    ('model',
#                     RandomForestClassifier(max_features=0.22305797620504839,
#                                            max_samples=0.5520829293042747,
#                                            n_estimators=1873))]),
#    'telco': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA66A50>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D781FD68D0>)])),
#                    ('model',
#                     RandomForestClassifier(max_features=0.39448082029326637,
#                                            max_samples=0.5260645137528964,
#                                            min_samples_leaf=6,
#                                            n_estimators=759))]),
#    'pistachio': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA84A70>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA853D0>)])),
#                    ('model',
#                     RandomForestClassifier(max_features=0.01, max_samples=1.0,
#                                            n_estimators=498))])},
#   'Decision Tree': {'diabetes': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA8DC40>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA65010>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_split=60))]),
#    'students': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA64B60>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA67B60>)])),
#                    ('model',
#                     DecisionTreeClassifier(ccp_alpha=0.0038736462249052647,
#                                            max_depth=5, min_samples_leaf=39,
#                                            min_samples_split=8))]),
#    'telco': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA64D70>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA65160>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_leaf=60,
#                                            min_samples_split=60))]),
#    'pistachio': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA81490>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA83AA0>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_leaf=60,
#                                            min_samples_split=60))])},
#   'Logistic Regression': {'diabetes': None,
#    'students': None,
#    'telco': None,
#    'pistachio': None}},
#  {'diabetes': array([0.89344262, 0.8887371 , 0.8896657 , 0.8940855 , 0.89746955,
#          0.85536091, 0.91891675, 0.92037216, 0.88776385, 0.89177292,
#          0.75230365, 0.89215686, 0.5       , 0.82128826, 0.91710418,
#          0.91702382, 0.88851388, 0.89058538, 0.63262081, 0.8903443 ,
#          0.88894246, 0.93187257, 0.9167381 , 0.8932819 , 0.9204793 ,
#          0.91470231, 0.92342584, 0.91871138, 0.89565699, 0.91772028]),
#   'students': array([0.92659283, 0.93270767, 0.924232  , 0.92878461, 0.93715535,
#          0.92118624, 0.93953949, 0.94086855, 0.92794521, 0.928464  ,
#          0.93377441, 0.93765957, 0.93708248, 0.91924803, 0.9250889 ,
#          0.93932673, 0.93531915, 0.91725444, 0.93799184, 0.92427572,
#          0.93862431, 0.94167881, 0.93951326, 0.93584961, 0.5       ,
#          0.81087147, 0.89012533, 0.93933547, 0.93998543, 0.81296998]),
#   'telco': array([0.83928037, 0.84832927, 0.84247494, 0.84503487, 0.85165932,
#          0.82323978, 0.85421926, 0.85350618, 0.84059955, 0.843024  ,
#          0.63545544, 0.8388133 , 0.6550507 , 0.82928308, 0.81943553,
#          0.83675609, 0.82031261, 0.84066016, 0.84177969, 0.84228954,
#          0.82979292, 0.85110312, 0.84406509, 0.5       , 0.83915914,
#          0.5       , 0.84854319, 0.84424336, 0.60157019, 0.84469259]),
#   'pistachio': array([0.943683  , 0.94745867, 0.94590866, 0.94480151, 0.95068359,
#          0.94370004, 0.95239826, 0.95442519, 0.94363758, 0.94430187,
#          0.95284963, 0.94862259, 0.95125136, 0.95396246, 0.95439964,
#          0.96031295, 0.9495878 , 0.81411246, 0.96086653, 0.9507574 ,
#          0.96143714, 0.94390443, 0.9612441 , 0.96082111, 0.95501567,
#          0.96099712, 0.96157908, 0.96159895, 0.95331804, 0.95234716])})

# %%
bayes_optimize2('Logistic Regression', param_space_bayes["Logistic Regression"],3)
# Out:
# ({'Random Forest': {'diabetes': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA83B00>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEDB8E00>)])),
#                    ('model',
#                     RandomForestClassifier(max_features=0.01, max_samples=0.01,
#                                            n_estimators=2000))]),
#    'students': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7832C1F10>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7832C1970>)])),
#                    ('model',
#                     RandomForestClassifier(max_features=0.22305797620504839,
#                                            max_samples=0.5520829293042747,
#                                            n_estimators=1873))]),
#    'telco': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA66A50>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D781FD68D0>)])),
#                    ('model',
#                     RandomForestClassifier(max_features=0.39448082029326637,
#                                            max_samples=0.5260645137528964,
#                                            min_samples_leaf=6,
#                                            n_estimators=759))]),
#    'pistachio': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA84A70>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA853D0>)])),
#                    ('model',
#                     RandomForestClassifier(max_features=0.01, max_samples=1.0,
#                                            n_estimators=498))])},
#   'Decision Tree': {'diabetes': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA8DC40>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA65010>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_split=60))]),
#    'students': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA64B60>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA67B60>)])),
#                    ('model',
#                     DecisionTreeClassifier(ccp_alpha=0.0038736462249052647,
#                                            max_depth=5, min_samples_leaf=39,
#                                            min_samples_split=8))]),
#    'telco': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA64D70>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA65160>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_leaf=60,
#                                            min_samples_split=60))]),
#    'pistachio': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA81490>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA83AA0>)])),
#                    ('model',
#                     DecisionTreeClassifier(max_depth=30, min_samples_leaf=60,
#                                            min_samples_split=60))])},
#   'Logistic Regression': {'diabetes': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA8E390>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D783091370>)])),
#                    ('model',
#                     LogisticRegression(C=92.39821534498665, solver='liblinear'))]),
#    'students': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7830934A0>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D783091790>)])),
#                    ('model',
#                     LogisticRegression(C=6.369496039444517, penalty='l1',
#                                        solver='liblinear'))]),
#    'telco': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA80770>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA63BC0>)])),
#                    ('model',
#                     LogisticRegression(C=4.4791716101709085, penalty='l1',
#                                        solver='liblinear'))]),
#    'pistachio': Pipeline(steps=[('trans',
#                     ColumnTransformer(transformers=[('numeric',
#                                                      Pipeline(steps=[('impute',
#                                                                       SimpleImputer()),
#                                                                      ('scale',
#                                                                       MinMaxScaler())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA630B0>),
#                                                     ('cat',
#                                                      Pipeline(steps=[('ohe',
#                                                                       OneHotEncoder(drop='first')),
#                                                                      ('impute',
#                                                                       SimpleImputer())]),
#                                                      <sklearn.compose._column_transformer.make_column_selector object at 0x000001D7FEA602C0>)])),
#                    ('model',
#                     LogisticRegression(C=72.65442695354241, solver='liblinear'))])}},
#  {'diabetes': array([0.93364049, 0.93356906, 0.93351548, 0.93342619, 0.93365834,
#          0.93369406, 0.93365834, 0.93353334, 0.93351548, 0.9335512 ,
#          0.93358691, 0.93412265, 0.93371192, 0.93353334, 0.93408693,
#          0.93365834, 0.9336762 , 0.93397978, 0.9336762 , 0.93317618,
#          0.93369406, 0.9336762 , 0.93365834, 0.9332119 , 0.93397978,
#          0.93360477, 0.93369406, 0.93372978, 0.93351548, 0.93415836]),
#   'students': array([0.94835908, 0.94823084, 0.94881959, 0.94791606, 0.94807928,
#          0.94795103, 0.94830079, 0.94822501, 0.94808511, 0.9483241 ,
#          0.94861556, 0.94862722, 0.90230836, 0.94803847, 0.9485631 ,
#          0.94863305, 0.94554357, 0.94803847, 0.9485631 , 0.94806762,
#          0.9479044 , 0.9485631 , 0.94731565, 0.94835908, 0.94845818,
#          0.94937919, 0.94827164, 0.94862139, 0.94812591, 0.949181  ]),
#   'telco': array([0.84321653, 0.84321653, 0.84321653, 0.84405796, 0.8433021 ,
#          0.84340906, 0.84365864, 0.84386543, 0.84387969, 0.84381551,
#          0.84356594, 0.84350176, 0.84365864, 0.8432094 , 0.830588  ,
#          0.84351602, 0.84400091, 0.84344472, 0.84427901, 0.84355168,
#          0.84424336, 0.84356594, 0.84355881, 0.84347324, 0.84433606,
#          0.84469259, 0.8434875 , 0.84325219, 0.84350889, 0.84418631]),
#   'pistachio': array([0.97794786, 0.97787405, 0.97820335, 0.97745957, 0.9778343 ,
#          0.97769236, 0.9780898 , 0.97791379, 0.97773778, 0.97800463,
#          0.97826581, 0.97831123, 0.5       , 0.97766965, 0.9780387 ,
#          0.97827716, 0.97820335, 0.97824877, 0.97827716, 0.9778343 ,
#          0.97778888, 0.97693155, 0.97766965, 0.9779365 , 0.97782862,
#          0.97779456, 0.97773778, 0.97827148, 0.9781409 , 0.97794786])})

# %%
save_models(best_bayes, '.\\Wyniki\\BayesSearch')

# %%
for model in models.keys():
    for dataset in datasets_wanted_size.keys():
        print(model,dataset)
        print(np.mean(bayes_history[model][dataset]))
        print(np.std(bayes_history[model][dataset]))
# Out:
# Decision Tree diabetes
# 0.5
# 0.0
# Decision Tree students
# 0.586997231127951
# 0.15068362443142388
# Decision Tree telco
# 0.5063976062122962
# 0.01692647502385774
# Decision Tree pistachio
# 0.5887082122093024
# 0.15364713059511345
# Random Forest diabetes
# 0.8933533340476446
# 0.018713726129800132
# Random Forest students
# 0.93077564849898
# 0.00938984257545421
# Random Forest telco
# 0.8431470072305652
# 0.011602824588790382
# Random Forest pistachio
# 0.9499855928642806
# 0.0038813816100281883
# Logistic Regression diabetes
# 0.9334819993571198
# 0.0006660519781914138
# Logistic Regression students
# 0.9483860390556689
# 0.0005140282258502008
# Logistic Regression telco
# 0.8434964132403486
# 0.00039035075050410036
# Logistic Regression pistachio
# 0.9780032135719476
# 0.00034166233350573503

# %% [markdown]
# # Inne techniki losowania punktów w random search

# %%
# mniejsze wartosci bardziej prawdopodobne

# %%
# custom distribution for

import numpy as np
from scipy.stats import loguniform, uniform
from sklearn.model_selection import ParameterSampler

seed = 42
random.seed(seed)
np.random.seed(seed)
n_iter = 200


def weighted_randint(low, high, size=1):
    # Sample from an exponential distribution, then scale to [low, high)
    probs = np.exp(-np.linspace(0, 3, high - low))  # Exponentially decaying probabilities
    probs /= probs.sum()  # Normalize to sum to 1
    return np.random.choice(np.arange(low, high), size=size, p=probs)[0]

# Define parameter distributions with callable weighted_randint
param_distributions_exp = {
    'Logistic Regression': {
        'C': (loguniform, 0.01, 100),  
        'penalty': (list, ['l1', 'l2']),  
        'solver': (list, ['liblinear']),  
    },
    'Decision Tree': { 
        'ccp_alpha': (loguniform, 0.001, 1),
        'max_depth': (weighted_randint, 1, 31),
        'min_samples_leaf': (weighted_randint, 1, 31),  
        'min_samples_split': (weighted_randint, 2, 31),  
    },
    'Random Forest': {  
        'n_estimators': (weighted_randint, 1, 201), 
        'max_samples': (uniform, 0.1,.9),
        'max_features': (uniform, 0.01, .95), 
        'min_samples_leaf': (weighted_randint, 1, 31), 
    }
}

def sample_custom_dist(tup):
    if len(tup) ==2 :
        return tup[1][random.randint(0,len(tup[1])-1)]
    elif tup[0] == weighted_randint:
        return weighted_randint(tup[1],tup[2])
    else:
        return tup[0](tup[1],tup[2]).rvs()
        

param_samples_exp = {
    alg: 
        [({key:sample_custom_dist(tup) for key, tup in param_distributions_exp[alg].items()}) for i in range(n_iter)]
    
    for alg in param_distributions_exp.keys()
}
param_samples_exp
# Out:
# {'Logistic Regression': [{'C': 0.31489116479568624,
#    'penalty': 'l1',
#    'solver': 'liblinear'},
#   {'C': 63.512210106407046, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 8.471801418819979, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 2.481040974867813, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.04207988669606638, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.042070539502879395, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.017073967431528128, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 29.154431891537552, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 2.5378155082656657, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 6.79657809075816, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.012087541473056965, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 75.7947995334801, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 21.368329072358772, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.07068974950624607, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.053370327626039576, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.05415244119402541, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.1648044642797898, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.256104370001356, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.5342937261279778, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.14618962793704965, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 2.801635158716261, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.03613894271216528, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.14742753159914673, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.2920433847181412, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.6672367170464207, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 13.826232179369875, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.0629064429458615, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.1400863701127328, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 2.342384984711291, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.015339162591163621, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 2.69264691008618, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.04809461967501574, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.018205657658407266, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 62.451395747430766, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 72.86653737491046, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 17.12337597316399, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.1653693718282443, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.024586032763280065, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 5.456725485601478, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.5762487216478605, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.030771802712506867, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.9565499215943827, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.013726318898045875, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 43.37920697490943, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.10842262717330164, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 4.467752817973908, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.17654048052495078, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 1.2030178871154673, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 1.5375920235481764, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.05488047000766046, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 75.56810141274431, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 12.60466458564947, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 57.27904470799624, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 37.95853142670641, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 2.463768595899747, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 48.696409415209004, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.022592797420156956, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.06080390190296603, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.015167330688076212, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.20013420622879985, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.358681649862755, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.12172958098369972, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 20.651425578959262, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.26730883107816716, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.13296521457299515, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 1.4817820606039094, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.0366181922039243, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 16.172900811143155, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.01987021538542863, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 88.62326508576255, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 12.273800987852969, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.06235377135673159, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.01052176186845113, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 18.27450885981603, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 6.720930050156114, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 8.241925264876453, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 12.164139351417068, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.019777828512462722, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.27155819552829413, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.029072088906598452, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 28.34090429514775, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 3.1130959561221245, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.2106648601704221, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.01795698422567764, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.17535949529764422, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.19986340778528885, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 8.28752236376816, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 3.550012525851161, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 35.387588647792406, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.7742116473996251, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.03008686821445845, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 7.128188058401368, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 11.044350847124697, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.7583640270008525, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 12.130221181165163, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.9444574254983568, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.2329098365270517, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.5130551760589835, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.012637946338082878, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.02701255772543908, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.0133572404119741, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 3.5127047262708473, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.1808939009276715, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 1.0821382910613992, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 42.68407710065497, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.0993502390906369, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.4380580767905656, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 10.524574681335638, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.08226074946221039, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.020319809838424987, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.14421346497969495, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.044145368764944806, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 52.334804885400885, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 17.07975034295824, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 3.4167643418329705, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 30.608522106722507, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 16.394127471631606, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.05575453980775373, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 37.173717478250516, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 1.4367095138664232, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 16.973078532467014, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 38.403004190988575, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.18707420137660272, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.027555462077796637, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.08160948743089923, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.5110120656497166, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 18.709365688887363, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 27.728241828010635, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.010661259689433893, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.1040511903162256, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.4673518999562751, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.07734482156646796, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.030162092627967783, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.2241097161910952, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 59.106986190885465, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.19625093208439867, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 1.1889469769530472, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 6.487477066058681, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.28478585168562975, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 77.11312991331113, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 70.76022085822012, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.10165510266418734, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.9749762207436125, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.15977662354833877, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.13783578294796386, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.014045842344024706, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 2.7431991397796702, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.0249816559563216, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.016066267921727714, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.13019246714361576, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 42.95992790539129, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.09083381663660589, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.03798214508453259, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.9074256288983865, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 87.61971101023695, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.09294394155644994, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 4.881375191603673, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 11.129571947046015, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.08923807143379786, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 8.182111518618424, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.295891528209531, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 3.382387201936218, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 3.420730367009227, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.390268671103501, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.022969898716342106, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 21.938654178115062, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.19192001101561892, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.055728075000299644, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.014557961490251991, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 2.3097861492693577, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 5.131654955148327, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.011650681118986135, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.117820920069873, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.080534710303161, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 3.8079493367685617, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.04982711200081135, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 5.804314717414074, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.3523233163198314, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 55.836727227548245, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.0354881840301095, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.23134781612225622, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.028437674894443682, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 49.97749370303173, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 32.31152185441099, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.10758866306767922, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 4.364516946807794, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 18.573288333114874, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 1.6626592254031876, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 1.314021022620739, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.09277034327414721, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.023572794556769815, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 38.802797007866886, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 39.96430167694255, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 3.4072643485301923, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 0.2270487755790924, 'penalty': 'l1', 'solver': 'liblinear'},
#   {'C': 0.24936660834465202, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 8.013508750140629, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 38.765111709116326, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 35.34644144196585, 'penalty': 'l2', 'solver': 'liblinear'},
#   {'C': 13.16746532693615, 'penalty': 'l2', 'solver': 'liblinear'}],
#  'Decision Tree': [{'ccp_alpha': 0.0843519134174305,
#    'max_depth': 1,
#    'min_samples_leaf': 2,
#    'min_samples_split': 20},
#   {'ccp_alpha': 0.06596099207886094,
#    'max_depth': 1,
#    'min_samples_leaf': 1,
#    'min_samples_split': 11},
#   {'ccp_alpha': 0.0010355826161899187,
#    'max_depth': 2,
#    'min_samples_leaf': 8,
#    'min_samples_split': 12},
#   {'ccp_alpha': 0.0903407680553777,
#    'max_depth': 3,
#    'min_samples_leaf': 12,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.009466710461838312,
#    'max_depth': 13,
#    'min_samples_leaf': 10,
#    'min_samples_split': 17},
#   {'ccp_alpha': 0.0939374305615398,
#    'max_depth': 8,
#    'min_samples_leaf': 1,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.006246073681318088,
#    'max_depth': 3,
#    'min_samples_leaf': 26,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.4743945221058973,
#    'max_depth': 9,
#    'min_samples_leaf': 14,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.05379125214937586,
#    'max_depth': 7,
#    'min_samples_leaf': 2,
#    'min_samples_split': 12},
#   {'ccp_alpha': 0.0069553195441582885,
#    'max_depth': 1,
#    'min_samples_leaf': 10,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.6627897035983005,
#    'max_depth': 24,
#    'min_samples_leaf': 21,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.0011126788925493287,
#    'max_depth': 22,
#    'min_samples_leaf': 6,
#    'min_samples_split': 25},
#   {'ccp_alpha': 0.7777856590163643,
#    'max_depth': 17,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.3576102963485505,
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.6433752092130683,
#    'max_depth': 11,
#    'min_samples_leaf': 8,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.0699876933175238,
#    'max_depth': 29,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.42866617503671595,
#    'max_depth': 12,
#    'min_samples_leaf': 11,
#    'min_samples_split': 12},
#   {'ccp_alpha': 0.011980458901470975,
#    'max_depth': 4,
#    'min_samples_leaf': 15,
#    'min_samples_split': 15},
#   {'ccp_alpha': 0.39922428866315024,
#    'max_depth': 20,
#    'min_samples_leaf': 7,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.2482478734421257,
#    'max_depth': 10,
#    'min_samples_leaf': 11,
#    'min_samples_split': 15},
#   {'ccp_alpha': 0.46775240101761445,
#    'max_depth': 4,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.05430507564500919,
#    'max_depth': 1,
#    'min_samples_leaf': 6,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.007238086291181392,
#    'max_depth': 9,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.29363084977630116,
#    'max_depth': 5,
#    'min_samples_leaf': 2,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.20416470207182763,
#    'max_depth': 3,
#    'min_samples_leaf': 9,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.001429042560943209,
#    'max_depth': 7,
#    'min_samples_leaf': 8,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.15075579010793652,
#    'max_depth': 26,
#    'min_samples_leaf': 7,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.2429733179622299,
#    'max_depth': 3,
#    'min_samples_leaf': 6,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.001191385280870283,
#    'max_depth': 25,
#    'min_samples_leaf': 16,
#    'min_samples_split': 12},
#   {'ccp_alpha': 0.016860049029950277,
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.04443037656955538,
#    'max_depth': 12,
#    'min_samples_leaf': 10,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.7321428778380782,
#    'max_depth': 12,
#    'min_samples_leaf': 8,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.018146805619521558,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'min_samples_split': 14},
#   {'ccp_alpha': 0.001104537501931838,
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.3684527073621865,
#    'max_depth': 11,
#    'min_samples_leaf': 6,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.02984335364446721,
#    'max_depth': 6,
#    'min_samples_leaf': 2,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.015686071966628894,
#    'max_depth': 9,
#    'min_samples_leaf': 10,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.013299577479431826,
#    'max_depth': 9,
#    'min_samples_leaf': 7,
#    'min_samples_split': 17},
#   {'ccp_alpha': 0.09464134308150154,
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.001200974902063027,
#    'max_depth': 8,
#    'min_samples_leaf': 23,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.014605276344629997,
#    'max_depth': 10,
#    'min_samples_leaf': 6,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.6674126383295353,
#    'max_depth': 5,
#    'min_samples_leaf': 25,
#    'min_samples_split': 20},
#   {'ccp_alpha': 0.0038669931642850274,
#    'max_depth': 1,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.0019201222592871415,
#    'max_depth': 11,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.3424726804566915,
#    'max_depth': 1,
#    'min_samples_leaf': 15,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.002262009803754499,
#    'max_depth': 11,
#    'min_samples_leaf': 9,
#    'min_samples_split': 19},
#   {'ccp_alpha': 0.16040323816074398,
#    'max_depth': 15,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.1785847026161884,
#    'max_depth': 15,
#    'min_samples_leaf': 29,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.013063340811682273,
#    'max_depth': 14,
#    'min_samples_leaf': 4,
#    'min_samples_split': 22},
#   {'ccp_alpha': 0.3760436466200045,
#    'max_depth': 6,
#    'min_samples_leaf': 13,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.0020387858300971347,
#    'max_depth': 20,
#    'min_samples_leaf': 7,
#    'min_samples_split': 16},
#   {'ccp_alpha': 0.009123233767937082,
#    'max_depth': 19,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.5201707521043376,
#    'max_depth': 1,
#    'min_samples_leaf': 4,
#    'min_samples_split': 24},
#   {'ccp_alpha': 0.7109211599410472,
#    'max_depth': 8,
#    'min_samples_leaf': 9,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.007579356154838334,
#    'max_depth': 4,
#    'min_samples_leaf': 10,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.2369938800028333,
#    'max_depth': 14,
#    'min_samples_leaf': 1,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.0014882513324386763,
#    'max_depth': 8,
#    'min_samples_leaf': 6,
#    'min_samples_split': 19},
#   {'ccp_alpha': 0.011291328372260002,
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 14},
#   {'ccp_alpha': 0.07155734029264278,
#    'max_depth': 1,
#    'min_samples_leaf': 1,
#    'min_samples_split': 12},
#   {'ccp_alpha': 0.0016530615299177754,
#    'max_depth': 15,
#    'min_samples_leaf': 11,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.001796855454284371,
#    'max_depth': 28,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.27440922153863356,
#    'max_depth': 23,
#    'min_samples_leaf': 28,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.013451749046413188,
#    'max_depth': 1,
#    'min_samples_leaf': 14,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.01873553192400017,
#    'max_depth': 20,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.0010815856940648103,
#    'max_depth': 6,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.0022520536912838,
#    'max_depth': 10,
#    'min_samples_leaf': 13,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.7700477308294275,
#    'max_depth': 5,
#    'min_samples_leaf': 4,
#    'min_samples_split': 18},
#   {'ccp_alpha': 0.0046858406496824235,
#    'max_depth': 25,
#    'min_samples_leaf': 1,
#    'min_samples_split': 26},
#   {'ccp_alpha': 0.0013473478567267631,
#    'max_depth': 19,
#    'min_samples_leaf': 7,
#    'min_samples_split': 29},
#   {'ccp_alpha': 0.0016649059071639674,
#    'max_depth': 8,
#    'min_samples_leaf': 26,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.0773029227349874,
#    'max_depth': 11,
#    'min_samples_leaf': 6,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.05661648927748013,
#    'max_depth': 20,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.7099609342475929,
#    'max_depth': 19,
#    'min_samples_leaf': 6,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.006794281693842807,
#    'max_depth': 2,
#    'min_samples_leaf': 6,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.056359656245490636,
#    'max_depth': 1,
#    'min_samples_leaf': 26,
#    'min_samples_split': 28},
#   {'ccp_alpha': 0.1243040108635543,
#    'max_depth': 7,
#    'min_samples_leaf': 4,
#    'min_samples_split': 16},
#   {'ccp_alpha': 0.11329050629496729,
#    'max_depth': 2,
#    'min_samples_leaf': 20,
#    'min_samples_split': 16},
#   {'ccp_alpha': 0.7069679730050327,
#    'max_depth': 12,
#    'min_samples_leaf': 9,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.6283266061384214,
#    'max_depth': 17,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.013470698026386344,
#    'max_depth': 15,
#    'min_samples_leaf': 28,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.060588771394020566,
#    'max_depth': 5,
#    'min_samples_leaf': 26,
#    'min_samples_split': 17},
#   {'ccp_alpha': 0.3273302288546507,
#    'max_depth': 6,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.0014761364011262933,
#    'max_depth': 17,
#    'min_samples_leaf': 15,
#    'min_samples_split': 30},
#   {'ccp_alpha': 0.9770358765701468,
#    'max_depth': 8,
#    'min_samples_leaf': 13,
#    'min_samples_split': 23},
#   {'ccp_alpha': 0.3539502081244624,
#    'max_depth': 3,
#    'min_samples_leaf': 6,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.7280363803561534,
#    'max_depth': 9,
#    'min_samples_leaf': 3,
#    'min_samples_split': 11},
#   {'ccp_alpha': 0.07151295457181828,
#    'max_depth': 5,
#    'min_samples_leaf': 2,
#    'min_samples_split': 11},
#   {'ccp_alpha': 0.036385060610699696,
#    'max_depth': 13,
#    'min_samples_leaf': 7,
#    'min_samples_split': 17},
#   {'ccp_alpha': 0.04526062182441458,
#    'max_depth': 8,
#    'min_samples_leaf': 18,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.002523746242515088,
#    'max_depth': 1,
#    'min_samples_leaf': 13,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.12949091638211224,
#    'max_depth': 3,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.011265816586723027,
#    'max_depth': 9,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.5157937596208981,
#    'max_depth': 4,
#    'min_samples_leaf': 7,
#    'min_samples_split': 14},
#   {'ccp_alpha': 0.015474917663181311,
#    'max_depth': 9,
#    'min_samples_leaf': 17,
#    'min_samples_split': 24},
#   {'ccp_alpha': 0.0027619794488595788,
#    'max_depth': 21,
#    'min_samples_leaf': 7,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.02384554587013989,
#    'max_depth': 27,
#    'min_samples_leaf': 7,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.07946988104669664,
#    'max_depth': 3,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.0024217957731734736,
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.0035126934685242132,
#    'max_depth': 4,
#    'min_samples_leaf': 19,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.1006174289132155,
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.003212219315322682,
#    'max_depth': 3,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.0023009522878251272,
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.03237813373628107,
#    'max_depth': 11,
#    'min_samples_leaf': 1,
#    'min_samples_split': 15},
#   {'ccp_alpha': 0.07650699925531627,
#    'max_depth': 1,
#    'min_samples_leaf': 18,
#    'min_samples_split': 21},
#   {'ccp_alpha': 0.00152487371930397,
#    'max_depth': 3,
#    'min_samples_leaf': 15,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.0035773633889511465,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.07157548748539429,
#    'max_depth': 5,
#    'min_samples_leaf': 6,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.001288396714510227,
#    'max_depth': 3,
#    'min_samples_leaf': 12,
#    'min_samples_split': 20},
#   {'ccp_alpha': 0.03427933011298978,
#    'max_depth': 7,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.03961428295971845,
#    'max_depth': 3,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.0011487184416481935,
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.002287106538387776,
#    'max_depth': 19,
#    'min_samples_leaf': 9,
#    'min_samples_split': 11},
#   {'ccp_alpha': 0.23308467265656618,
#    'max_depth': 7,
#    'min_samples_leaf': 1,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.05761337991585722,
#    'max_depth': 13,
#    'min_samples_leaf': 6,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.00710113415427611,
#    'max_depth': 5,
#    'min_samples_leaf': 10,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.01170281063477968,
#    'max_depth': 28,
#    'min_samples_leaf': 9,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.0020199816203830536,
#    'max_depth': 2,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.0036282823166258315,
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 20},
#   {'ccp_alpha': 0.0017406090490085764,
#    'max_depth': 7,
#    'min_samples_leaf': 5,
#    'min_samples_split': 28},
#   {'ccp_alpha': 0.002168286702972878,
#    'max_depth': 5,
#    'min_samples_leaf': 26,
#    'min_samples_split': 18},
#   {'ccp_alpha': 0.2826286687254135,
#    'max_depth': 3,
#    'min_samples_leaf': 2,
#    'min_samples_split': 11},
#   {'ccp_alpha': 0.6139428803386755,
#    'max_depth': 8,
#    'min_samples_leaf': 8,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.20345988728938627,
#    'max_depth': 2,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.03332967939040693,
#    'max_depth': 3,
#    'min_samples_leaf': 2,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.007343306571887159,
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.03960666706189496,
#    'max_depth': 1,
#    'min_samples_leaf': 4,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.0015492621523313817,
#    'max_depth': 29,
#    'min_samples_leaf': 4,
#    'min_samples_split': 15},
#   {'ccp_alpha': 0.005806600729040602,
#    'max_depth': 11,
#    'min_samples_leaf': 13,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.025985349693911305,
#    'max_depth': 5,
#    'min_samples_leaf': 4,
#    'min_samples_split': 22},
#   {'ccp_alpha': 0.31035462614604026,
#    'max_depth': 25,
#    'min_samples_leaf': 2,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.6531626922356584,
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.05289557464187063,
#    'max_depth': 16,
#    'min_samples_leaf': 2,
#    'min_samples_split': 15},
#   {'ccp_alpha': 0.00402607591992069,
#    'max_depth': 2,
#    'min_samples_leaf': 2,
#    'min_samples_split': 16},
#   {'ccp_alpha': 0.09899007700402486,
#    'max_depth': 7,
#    'min_samples_leaf': 5,
#    'min_samples_split': 18},
#   {'ccp_alpha': 0.015043030022755118,
#    'max_depth': 15,
#    'min_samples_leaf': 6,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.024436519933969402,
#    'max_depth': 4,
#    'min_samples_leaf': 13,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.004973224739993164,
#    'max_depth': 19,
#    'min_samples_leaf': 5,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.5241026225805877,
#    'max_depth': 9,
#    'min_samples_leaf': 2,
#    'min_samples_split': 23},
#   {'ccp_alpha': 0.0764054185635115,
#    'max_depth': 4,
#    'min_samples_leaf': 2,
#    'min_samples_split': 15},
#   {'ccp_alpha': 0.07248001387147507,
#    'max_depth': 7,
#    'min_samples_leaf': 19,
#    'min_samples_split': 15},
#   {'ccp_alpha': 0.002851180021336776,
#    'max_depth': 4,
#    'min_samples_leaf': 3,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.0012606580582274817,
#    'max_depth': 8,
#    'min_samples_leaf': 13,
#    'min_samples_split': 18},
#   {'ccp_alpha': 0.010622952661232919,
#    'max_depth': 15,
#    'min_samples_leaf': 2,
#    'min_samples_split': 17},
#   {'ccp_alpha': 0.0024124925839939223,
#    'max_depth': 5,
#    'min_samples_leaf': 14,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.004872526229872035,
#    'max_depth': 12,
#    'min_samples_leaf': 12,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.1207383769321602,
#    'max_depth': 8,
#    'min_samples_leaf': 3,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.003505848545428618,
#    'max_depth': 20,
#    'min_samples_leaf': 8,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.02432301518460197,
#    'max_depth': 23,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.03293563466517265,
#    'max_depth': 9,
#    'min_samples_leaf': 1,
#    'min_samples_split': 18},
#   {'ccp_alpha': 0.6256837091475114,
#    'max_depth': 8,
#    'min_samples_leaf': 11,
#    'min_samples_split': 21},
#   {'ccp_alpha': 0.13234754903375762,
#    'max_depth': 2,
#    'min_samples_leaf': 8,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.01872371465271093,
#    'max_depth': 12,
#    'min_samples_leaf': 22,
#    'min_samples_split': 22},
#   {'ccp_alpha': 0.02251739333742484,
#    'max_depth': 2,
#    'min_samples_leaf': 28,
#    'min_samples_split': 17},
#   {'ccp_alpha': 0.0023658545631797174,
#    'max_depth': 21,
#    'min_samples_leaf': 18,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.059405452352337046,
#    'max_depth': 5,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.2561889217260502,
#    'max_depth': 1,
#    'min_samples_leaf': 4,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.04094367382824367,
#    'max_depth': 21,
#    'min_samples_leaf': 4,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.1631186972668686,
#    'max_depth': 6,
#    'min_samples_leaf': 3,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.0026458855905382144,
#    'max_depth': 2,
#    'min_samples_leaf': 7,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.5553128244188592,
#    'max_depth': 5,
#    'min_samples_leaf': 8,
#    'min_samples_split': 10},
#   {'ccp_alpha': 0.001094670387118113,
#    'max_depth': 10,
#    'min_samples_leaf': 2,
#    'min_samples_split': 25},
#   {'ccp_alpha': 0.0027924678598035342,
#    'max_depth': 5,
#    'min_samples_leaf': 1,
#    'min_samples_split': 30},
#   {'ccp_alpha': 0.032105913478842125,
#    'max_depth': 9,
#    'min_samples_leaf': 1,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.0042630142001228435,
#    'max_depth': 19,
#    'min_samples_leaf': 3,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.0012872088100474581,
#    'max_depth': 6,
#    'min_samples_leaf': 8,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.21212060156309007,
#    'max_depth': 6,
#    'min_samples_leaf': 7,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.01593269280315734,
#    'max_depth': 8,
#    'min_samples_leaf': 2,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.38490793387817623,
#    'max_depth': 23,
#    'min_samples_leaf': 5,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.08550640149883473,
#    'max_depth': 5,
#    'min_samples_leaf': 1,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.14057778190091602,
#    'max_depth': 10,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.004934286811215815,
#    'max_depth': 10,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.2510430809059627,
#    'max_depth': 2,
#    'min_samples_leaf': 10,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.0019875779875247884,
#    'max_depth': 3,
#    'min_samples_leaf': 12,
#    'min_samples_split': 17},
#   {'ccp_alpha': 0.30949924483757857,
#    'max_depth': 5,
#    'min_samples_leaf': 10,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.007576056254648097,
#    'max_depth': 19,
#    'min_samples_leaf': 1,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.004203961842138754,
#    'max_depth': 1,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.01837695922763329,
#    'max_depth': 19,
#    'min_samples_leaf': 15,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.006001644960741877,
#    'max_depth': 5,
#    'min_samples_leaf': 9,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.0745498413469623,
#    'max_depth': 5,
#    'min_samples_leaf': 8,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.007645348356750785,
#    'max_depth': 23,
#    'min_samples_leaf': 13,
#    'min_samples_split': 3},
#   {'ccp_alpha': 0.40309176677166875,
#    'max_depth': 7,
#    'min_samples_leaf': 19,
#    'min_samples_split': 15},
#   {'ccp_alpha': 0.018864292137651815,
#    'max_depth': 1,
#    'min_samples_leaf': 3,
#    'min_samples_split': 8},
#   {'ccp_alpha': 0.07951236285054585,
#    'max_depth': 3,
#    'min_samples_leaf': 2,
#    'min_samples_split': 16},
#   {'ccp_alpha': 0.8978556958963885,
#    'max_depth': 7,
#    'min_samples_leaf': 2,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.0011354604971432899,
#    'max_depth': 20,
#    'min_samples_leaf': 2,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.006639963041506417,
#    'max_depth': 8,
#    'min_samples_leaf': 10,
#    'min_samples_split': 16},
#   {'ccp_alpha': 0.004161633351138872,
#    'max_depth': 1,
#    'min_samples_leaf': 2,
#    'min_samples_split': 20},
#   {'ccp_alpha': 0.41847568861954615,
#    'max_depth': 9,
#    'min_samples_leaf': 9,
#    'min_samples_split': 11},
#   {'ccp_alpha': 0.0033582562823916006,
#    'max_depth': 20,
#    'min_samples_leaf': 5,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.0360373722494619,
#    'max_depth': 1,
#    'min_samples_leaf': 2,
#    'min_samples_split': 13},
#   {'ccp_alpha': 0.001771723737091282,
#    'max_depth': 9,
#    'min_samples_leaf': 3,
#    'min_samples_split': 6},
#   {'ccp_alpha': 0.007346512304317999,
#    'max_depth': 5,
#    'min_samples_leaf': 12,
#    'min_samples_split': 5},
#   {'ccp_alpha': 0.05002808981856132,
#    'max_depth': 6,
#    'min_samples_leaf': 10,
#    'min_samples_split': 23},
#   {'ccp_alpha': 0.15765810117132095,
#    'max_depth': 3,
#    'min_samples_leaf': 1,
#    'min_samples_split': 4},
#   {'ccp_alpha': 0.06098651152617814,
#    'max_depth': 1,
#    'min_samples_leaf': 7,
#    'min_samples_split': 9},
#   {'ccp_alpha': 0.01006309731277181,
#    'max_depth': 13,
#    'min_samples_leaf': 2,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.15295591226864455,
#    'max_depth': 7,
#    'min_samples_leaf': 11,
#    'min_samples_split': 7},
#   {'ccp_alpha': 0.005485372181571515,
#    'max_depth': 15,
#    'min_samples_leaf': 14,
#    'min_samples_split': 12},
#   {'ccp_alpha': 0.006552928233851988,
#    'max_depth': 9,
#    'min_samples_leaf': 5,
#    'min_samples_split': 2},
#   {'ccp_alpha': 0.5648598760414232,
#    'max_depth': 2,
#    'min_samples_leaf': 24,
#    'min_samples_split': 7}],
#  'Random Forest': [{'n_estimators': 13,
#    'max_samples': 0.5877108526405224,
#    'max_features': 0.8392985440825879,
#    'min_samples_leaf': 12},
#   {'n_estimators': 97,
#    'max_samples': 0.6929050300396457,
#    'max_features': 0.6676627362919598,
#    'min_samples_leaf': 17},
#   {'n_estimators': 18,
#    'max_samples': 0.5404824672788264,
#    'max_features': 0.2201489697286221,
#    'min_samples_leaf': 28},
#   {'n_estimators': 152,
#    'max_samples': 0.13548413023165531,
#    'max_features': 0.680296413889904,
#    'min_samples_leaf': 21},
#   {'n_estimators': 13,
#    'max_samples': 0.6111507074973666,
#    'max_features': 0.8797138827086397,
#    'min_samples_leaf': 1},
#   {'n_estimators': 73,
#    'max_samples': 0.3676141066352957,
#    'max_features': 0.8881763856077038,
#    'min_samples_leaf': 26},
#   {'n_estimators': 152,
#    'max_samples': 0.5267927949917174,
#    'max_features': 0.8289405184398477,
#    'min_samples_leaf': 16},
#   {'n_estimators': 24,
#    'max_samples': 0.8460239267356096,
#    'max_features': 0.04515725297971799,
#    'min_samples_leaf': 9},
#   {'n_estimators': 17,
#    'max_samples': 0.20851019719955094,
#    'max_features': 0.08310554154774868,
#    'min_samples_leaf': 11},
#   {'n_estimators': 26,
#    'max_samples': 0.7522900943758853,
#    'max_features': 0.07208852375899524,
#    'min_samples_leaf': 4},
#   {'n_estimators': 48,
#    'max_samples': 0.8116508483550672,
#    'max_features': 0.3128148777854664,
#    'min_samples_leaf': 9},
#   {'n_estimators': 123,
#    'max_samples': 0.6542768693640741,
#    'max_features': 0.23131150101595208,
#    'min_samples_leaf': 1},
#   {'n_estimators': 117,
#    'max_samples': 0.11914246976534842,
#    'max_features': 0.8409665890499894,
#    'min_samples_leaf': 7},
#   {'n_estimators': 149,
#    'max_samples': 0.8189049121962988,
#    'max_features': 0.9580374050066706,
#    'min_samples_leaf': 4},
#   {'n_estimators': 87,
#    'max_samples': 0.46173782224831794,
#    'max_features': 0.4658818392887134,
#    'min_samples_leaf': 9},
#   {'n_estimators': 118,
#    'max_samples': 0.9856751222793656,
#    'max_features': 0.7398597431712922,
#    'min_samples_leaf': 5},
#   {'n_estimators': 34,
#    'max_samples': 0.7638240714300023,
#    'max_features': 0.23683828847988722,
#    'min_samples_leaf': 2},
#   {'n_estimators': 28,
#    'max_samples': 0.3585150924886735,
#    'max_features': 0.2914927144331906,
#    'min_samples_leaf': 3},
#   {'n_estimators': 3,
#    'max_samples': 0.11608654126007244,
#    'max_features': 0.94833627024923,
#    'min_samples_leaf': 6},
#   {'n_estimators': 31,
#    'max_samples': 0.7116825544237628,
#    'max_features': 0.21734119347181097,
#    'min_samples_leaf': 23},
#   {'n_estimators': 92,
#    'max_samples': 0.18046990208103358,
#    'max_features': 0.4067017369956819,
#    'min_samples_leaf': 18},
#   {'n_estimators': 152,
#    'max_samples': 0.5206613601248827,
#    'max_features': 0.5927408197501723,
#    'min_samples_leaf': 2},
#   {'n_estimators': 190,
#    'max_samples': 0.3085045312450991,
#    'max_features': 0.9055951854283694,
#    'min_samples_leaf': 10},
#   {'n_estimators': 58,
#    'max_samples': 0.5614196599148578,
#    'max_features': 0.22913632113187074,
#    'min_samples_leaf': 2},
#   {'n_estimators': 16,
#    'max_samples': 0.2677944359298291,
#    'max_features': 0.7506052498884156,
#    'min_samples_leaf': 4},
#   {'n_estimators': 4,
#    'max_samples': 0.9721923671267302,
#    'max_features': 0.8495965907152544,
#    'min_samples_leaf': 22},
#   {'n_estimators': 194,
#    'max_samples': 0.2565057242975386,
#    'max_features': 0.3864299179575258,
#    'min_samples_leaf': 13},
#   {'n_estimators': 72,
#    'max_samples': 0.23850631570586955,
#    'max_features': 0.7850414687410868,
#    'min_samples_leaf': 3},
#   {'n_estimators': 16,
#    'max_samples': 0.5832769806040722,
#    'max_features': 0.573292938099618,
#    'min_samples_leaf': 8},
#   {'n_estimators': 7,
#    'max_samples': 0.8897147763673423,
#    'max_features': 0.26232004045927076,
#    'min_samples_leaf': 2},
#   {'n_estimators': 124,
#    'max_samples': 0.960086348406778,
#    'max_features': 0.8290212364021781,
#    'min_samples_leaf': 15},
#   {'n_estimators': 65,
#    'max_samples': 0.5957716335482254,
#    'max_features': 0.09263742191583962,
#    'min_samples_leaf': 5},
#   {'n_estimators': 30,
#    'max_samples': 0.3337784053842936,
#    'max_features': 0.6972491080041556,
#    'min_samples_leaf': 7},
#   {'n_estimators': 6,
#    'max_samples': 0.29816488175483025,
#    'max_features': 0.6590958254766162,
#    'min_samples_leaf': 1},
#   {'n_estimators': 110,
#    'max_samples': 0.5456318743125769,
#    'max_features': 0.4665572484603156,
#    'min_samples_leaf': 9},
#   {'n_estimators': 102,
#    'max_samples': 0.4130282871119738,
#    'max_features': 0.6541153449311103,
#    'min_samples_leaf': 8},
#   {'n_estimators': 20,
#    'max_samples': 0.8907669877196421,
#    'max_features': 0.7675547205265817,
#    'min_samples_leaf': 10},
#   {'n_estimators': 110,
#    'max_samples': 0.8805647808638222,
#    'max_features': 0.682944827879283,
#    'min_samples_leaf': 16},
#   {'n_estimators': 73,
#    'max_samples': 0.7121266945842704,
#    'max_features': 0.597680809304425,
#    'min_samples_leaf': 13},
#   {'n_estimators': 11,
#    'max_samples': 0.8927836832790356,
#    'max_features': 0.8382513513579704,
#    'min_samples_leaf': 1},
#   {'n_estimators': 103,
#    'max_samples': 0.21598288072610067,
#    'max_features': 0.3283629115461848,
#    'min_samples_leaf': 12},
#   {'n_estimators': 12,
#    'max_samples': 0.836170321707156,
#    'max_features': 0.8005274690598548,
#    'min_samples_leaf': 7},
#   {'n_estimators': 1,
#    'max_samples': 0.3583343198574215,
#    'max_features': 0.5960805724569551,
#    'min_samples_leaf': 27},
#   {'n_estimators': 61,
#    'max_samples': 0.3338232229577438,
#    'max_features': 0.6123054179446308,
#    'min_samples_leaf': 8},
#   {'n_estimators': 90,
#    'max_samples': 0.19628257494426257,
#    'max_features': 0.7329765073769265,
#    'min_samples_leaf': 8},
#   {'n_estimators': 165,
#    'max_samples': 0.4076849494348175,
#    'max_features': 0.6109907984772507,
#    'min_samples_leaf': 22},
#   {'n_estimators': 7,
#    'max_samples': 0.943505638512806,
#    'max_features': 0.6634914361857727,
#    'min_samples_leaf': 1},
#   {'n_estimators': 23,
#    'max_samples': 0.7373548797807534,
#    'max_features': 0.07398307139533311,
#    'min_samples_leaf': 8},
#   {'n_estimators': 27,
#    'max_samples': 0.6588239659907293,
#    'max_features': 0.053454932121887205,
#    'min_samples_leaf': 18},
#   {'n_estimators': 173,
#    'max_samples': 0.9719900697571223,
#    'max_features': 0.7221692401557784,
#    'min_samples_leaf': 2},
#   {'n_estimators': 85,
#    'max_samples': 0.12212822481292136,
#    'max_features': 0.03101737395254739,
#    'min_samples_leaf': 4},
#   {'n_estimators': 42,
#    'max_samples': 0.7933666760270138,
#    'max_features': 0.6591306077761799,
#    'min_samples_leaf': 6},
#   {'n_estimators': 20,
#    'max_samples': 0.99741205014194,
#    'max_features': 0.4148722371241743,
#    'min_samples_leaf': 6},
#   {'n_estimators': 12,
#    'max_samples': 0.8153285938749364,
#    'max_features': 0.6689981144924142,
#    'min_samples_leaf': 3},
#   {'n_estimators': 6,
#    'max_samples': 0.7124493718672418,
#    'max_features': 0.6317856535670785,
#    'min_samples_leaf': 3},
#   {'n_estimators': 156,
#    'max_samples': 0.23595210260281022,
#    'max_features': 0.4207180609904718,
#    'min_samples_leaf': 23},
#   {'n_estimators': 34,
#    'max_samples': 0.6746733528976769,
#    'max_features': 0.38771467806465454,
#    'min_samples_leaf': 3},
#   {'n_estimators': 183,
#    'max_samples': 0.4684006056835387,
#    'max_features': 0.8593942434951777,
#    'min_samples_leaf': 3},
#   {'n_estimators': 16,
#    'max_samples': 0.12802067459606023,
#    'max_features': 0.6290834841070908,
#    'min_samples_leaf': 5},
#   {'n_estimators': 115,
#    'max_samples': 0.5258889160224015,
#    'max_features': 0.9297837565189856,
#    'min_samples_leaf': 2},
#   {'n_estimators': 117,
#    'max_samples': 0.7989371675125676,
#    'max_features': 0.7423757524118494,
#    'min_samples_leaf': 16},
#   {'n_estimators': 86,
#    'max_samples': 0.6635982894682738,
#    'max_features': 0.1346826337982682,
#    'min_samples_leaf': 1},
#   {'n_estimators': 139,
#    'max_samples': 0.6549852830686642,
#    'max_features': 0.7667104264273674,
#    'min_samples_leaf': 6},
#   {'n_estimators': 8,
#    'max_samples': 0.2126672129822954,
#    'max_features': 0.6612870228675227,
#    'min_samples_leaf': 6},
#   {'n_estimators': 15,
#    'max_samples': 0.5424350920672932,
#    'max_features': 0.07099849022137737,
#    'min_samples_leaf': 8},
#   {'n_estimators': 20,
#    'max_samples': 0.8178031905734693,
#    'max_features': 0.3048438609773951,
#    'min_samples_leaf': 6},
#   {'n_estimators': 1,
#    'max_samples': 0.165202199015103,
#    'max_features': 0.38286887858635055,
#    'min_samples_leaf': 6},
#   {'n_estimators': 57,
#    'max_samples': 0.3624963208383729,
#    'max_features': 0.6702327918202154,
#    'min_samples_leaf': 17},
#   {'n_estimators': 90,
#    'max_samples': 0.13565694281352145,
#    'max_features': 0.4664815998949375,
#    'min_samples_leaf': 2},
#   {'n_estimators': 18,
#    'max_samples': 0.9879963339404318,
#    'max_features': 0.14537076575643756,
#    'min_samples_leaf': 7},
#   {'n_estimators': 59,
#    'max_samples': 0.7322184734896936,
#    'max_features': 0.5416662493125683,
#    'min_samples_leaf': 1},
#   {'n_estimators': 25,
#    'max_samples': 0.5659404790462403,
#    'max_features': 0.09347317418759168,
#    'min_samples_leaf': 4},
#   {'n_estimators': 3,
#    'max_samples': 0.17072064743951867,
#    'max_features': 0.38707711239151626,
#    'min_samples_leaf': 2},
#   {'n_estimators': 52,
#    'max_samples': 0.7205184722235392,
#    'max_features': 0.7705573641536287,
#    'min_samples_leaf': 3},
#   {'n_estimators': 12,
#    'max_samples': 0.19411105630096023,
#    'max_features': 0.6146087370664548,
#    'min_samples_leaf': 11},
#   {'n_estimators': 3,
#    'max_samples': 0.9425910216193208,
#    'max_features': 0.05937271946889879,
#    'min_samples_leaf': 8},
#   {'n_estimators': 75,
#    'max_samples': 0.883872211371477,
#    'max_features': 0.6883825855258063,
#    'min_samples_leaf': 15},
#   {'n_estimators': 26,
#    'max_samples': 0.833342602371861,
#    'max_features': 0.08610910406544138,
#    'min_samples_leaf': 19},
#   {'n_estimators': 49,
#    'max_samples': 0.8355679929662443,
#    'max_features': 0.4397023702923851,
#    'min_samples_leaf': 10},
#   {'n_estimators': 47,
#    'max_samples': 0.7584305695797987,
#    'max_features': 0.08754848292906009,
#    'min_samples_leaf': 1},
#   {'n_estimators': 18,
#    'max_samples': 0.2435902121018695,
#    'max_features': 0.8381943882625916,
#    'min_samples_leaf': 3},
#   {'n_estimators': 175,
#    'max_samples': 0.40320621259399614,
#    'max_features': 0.18301201990426433,
#    'min_samples_leaf': 14},
#   {'n_estimators': 66,
#    'max_samples': 0.5483761448078251,
#    'max_features': 0.5375953733907497,
#    'min_samples_leaf': 12},
#   {'n_estimators': 17,
#    'max_samples': 0.9967005244510677,
#    'max_features': 0.936053504039444,
#    'min_samples_leaf': 10},
#   {'n_estimators': 14,
#    'max_samples': 0.7122054181881622,
#    'max_features': 0.07858848853021705,
#    'min_samples_leaf': 1},
#   {'n_estimators': 19,
#    'max_samples': 0.5163606610653847,
#    'max_features': 0.8348588801379615,
#    'min_samples_leaf': 12},
#   {'n_estimators': 82,
#    'max_samples': 0.48294400100326784,
#    'max_features': 0.33863824291961475,
#    'min_samples_leaf': 5},
#   {'n_estimators': 186,
#    'max_samples': 0.13609827227123425,
#    'max_features': 0.8336799213163261,
#    'min_samples_leaf': 8},
#   {'n_estimators': 36,
#    'max_samples': 0.7527318943736229,
#    'max_features': 0.4723354943534677,
#    'min_samples_leaf': 18},
#   {'n_estimators': 129,
#    'max_samples': 0.47954883418610994,
#    'max_features': 0.272986407373299,
#    'min_samples_leaf': 9},
#   {'n_estimators': 135,
#    'max_samples': 0.28959597010509996,
#    'max_features': 0.6018182543853087,
#    'min_samples_leaf': 9},
#   {'n_estimators': 80,
#    'max_samples': 0.21841091661453382,
#    'max_features': 0.6900337164479841,
#    'min_samples_leaf': 20},
#   {'n_estimators': 13,
#    'max_samples': 0.3137889924314899,
#    'max_features': 0.9328253393395576,
#    'min_samples_leaf': 2},
#   {'n_estimators': 112,
#    'max_samples': 0.5430500708032313,
#    'max_features': 0.24486952068301818,
#    'min_samples_leaf': 18},
#   {'n_estimators': 37,
#    'max_samples': 0.5633356185367212,
#    'max_features': 0.3512717009297774,
#    'min_samples_leaf': 9},
#   {'n_estimators': 12,
#    'max_samples': 0.4519733829865846,
#    'max_features': 0.9309417062185231,
#    'min_samples_leaf': 3},
#   {'n_estimators': 65,
#    'max_samples': 0.39267105780222544,
#    'max_features': 0.7447994694022706,
#    'min_samples_leaf': 2},
#   {'n_estimators': 170,
#    'max_samples': 0.5084105872452753,
#    'max_features': 0.23424794017914075,
#    'min_samples_leaf': 1},
#   {'n_estimators': 12,
#    'max_samples': 0.5677965537004159,
#    'max_features': 0.330153017609722,
#    'min_samples_leaf': 16},
#   {'n_estimators': 35,
#    'max_samples': 0.3238428453288669,
#    'max_features': 0.5962877372738286,
#    'min_samples_leaf': 11},
#   {'n_estimators': 12,
#    'max_samples': 0.2508572946594859,
#    'max_features': 0.04483785558686582,
#    'min_samples_leaf': 12},
#   {'n_estimators': 67,
#    'max_samples': 0.5271677881748326,
#    'max_features': 0.8119619265207373,
#    'min_samples_leaf': 15},
#   {'n_estimators': 54,
#    'max_samples': 0.8814441524619328,
#    'max_features': 0.20554914953492984,
#    'min_samples_leaf': 2},
#   {'n_estimators': 20,
#    'max_samples': 0.15137817048038338,
#    'max_features': 0.5146110516009804,
#    'min_samples_leaf': 22},
#   {'n_estimators': 3,
#    'max_samples': 0.20989892260902412,
#    'max_features': 0.4395890768692635,
#    'min_samples_leaf': 22},
#   {'n_estimators': 24,
#    'max_samples': 0.5565113278195533,
#    'max_features': 0.049494216097872495,
#    'min_samples_leaf': 2},
#   {'n_estimators': 185,
#    'max_samples': 0.9686068267924409,
#    'max_features': 0.014692981887689135,
#    'min_samples_leaf': 24},
#   {'n_estimators': 63,
#    'max_samples': 0.88112646506802,
#    'max_features': 0.4420028628521661,
#    'min_samples_leaf': 7},
#   {'n_estimators': 42,
#    'max_samples': 0.700177831791494,
#    'max_features': 0.14266869201849727,
#    'min_samples_leaf': 1},
#   {'n_estimators': 23,
#    'max_samples': 0.734212686462982,
#    'max_features': 0.20176077951680094,
#    'min_samples_leaf': 10},
#   {'n_estimators': 170,
#    'max_samples': 0.18451064421047655,
#    'max_features': 0.6489720123138699,
#    'min_samples_leaf': 6},
#   {'n_estimators': 116,
#    'max_samples': 0.25943481050264733,
#    'max_features': 0.6679946546148563,
#    'min_samples_leaf': 16},
#   {'n_estimators': 152,
#    'max_samples': 0.7149232254606812,
#    'max_features': 0.4823160258080059,
#    'min_samples_leaf': 9},
#   {'n_estimators': 117,
#    'max_samples': 0.6135487719749467,
#    'max_features': 0.03886770671199501,
#    'min_samples_leaf': 22},
#   {'n_estimators': 71,
#    'max_samples': 0.7088620471995218,
#    'max_features': 0.2148913947778313,
#    'min_samples_leaf': 10},
#   {'n_estimators': 32,
#    'max_samples': 0.6861096793373429,
#    'max_features': 0.11126337879259117,
#    'min_samples_leaf': 10},
#   {'n_estimators': 200,
#    'max_samples': 0.14339083497450045,
#    'max_features': 0.9383154750102514,
#    'min_samples_leaf': 5},
#   {'n_estimators': 117,
#    'max_samples': 0.8041469356524461,
#    'max_features': 0.5486654479373344,
#    'min_samples_leaf': 12},
#   {'n_estimators': 120,
#    'max_samples': 0.46372628948592964,
#    'max_features': 0.32068150348507674,
#    'min_samples_leaf': 10},
#   {'n_estimators': 97,
#    'max_samples': 0.7860566212989542,
#    'max_features': 0.7679229664157027,
#    'min_samples_leaf': 6},
#   {'n_estimators': 100,
#    'max_samples': 0.2081881498335476,
#    'max_features': 0.5272646430628071,
#    'min_samples_leaf': 1},
#   {'n_estimators': 25,
#    'max_samples': 0.4298153813842581,
#    'max_features': 0.3863640570287926,
#    'min_samples_leaf': 11},
#   {'n_estimators': 31,
#    'max_samples': 0.5038242603602776,
#    'max_features': 0.2356669243306111,
#    'min_samples_leaf': 5},
#   {'n_estimators': 17,
#    'max_samples': 0.1658763313915993,
#    'max_features': 0.583276163712309,
#    'min_samples_leaf': 10},
#   {'n_estimators': 59,
#    'max_samples': 0.5171446394205151,
#    'max_features': 0.3707964911702683,
#    'min_samples_leaf': 17},
#   {'n_estimators': 46,
#    'max_samples': 0.5312636898667579,
#    'max_features': 0.0343599625161139,
#    'min_samples_leaf': 4},
#   {'n_estimators': 30,
#    'max_samples': 0.45894050280721044,
#    'max_features': 0.5611637507659657,
#    'min_samples_leaf': 7},
#   {'n_estimators': 58,
#    'max_samples': 0.7883949353879154,
#    'max_features': 0.7823364517802888,
#    'min_samples_leaf': 12},
#   {'n_estimators': 159,
#    'max_samples': 0.11640932440872548,
#    'max_features': 0.1959890863993688,
#    'min_samples_leaf': 1},
#   {'n_estimators': 64,
#    'max_samples': 0.9082274940549883,
#    'max_features': 0.2413081817474843,
#    'min_samples_leaf': 21},
#   {'n_estimators': 4,
#    'max_samples': 0.9409924241249629,
#    'max_features': 0.3440415528776527,
#    'min_samples_leaf': 1},
#   {'n_estimators': 42,
#    'max_samples': 0.33109891094845717,
#    'max_features': 0.28062925686382667,
#    'min_samples_leaf': 4},
#   {'n_estimators': 96,
#    'max_samples': 0.5852451490077291,
#    'max_features': 0.30574231419820347,
#    'min_samples_leaf': 9},
#   {'n_estimators': 76,
#    'max_samples': 0.3453616006601804,
#    'max_features': 0.4028716464490839,
#    'min_samples_leaf': 2},
#   {'n_estimators': 13,
#    'max_samples': 0.7130060685684845,
#    'max_features': 0.1823664303108456,
#    'min_samples_leaf': 7},
#   {'n_estimators': 75,
#    'max_samples': 0.19618923078526945,
#    'max_features': 0.5489466086474584,
#    'min_samples_leaf': 3},
#   {'n_estimators': 165,
#    'max_samples': 0.5351910820479323,
#    'max_features': 0.7756929222864002,
#    'min_samples_leaf': 8},
#   {'n_estimators': 3,
#    'max_samples': 0.6698362380346201,
#    'max_features': 0.9138331750963241,
#    'min_samples_leaf': 9},
#   {'n_estimators': 101,
#    'max_samples': 0.895785817013567,
#    'max_features': 0.22667578335148586,
#    'min_samples_leaf': 3},
#   {'n_estimators': 58,
#    'max_samples': 0.46992562282603423,
#    'max_features': 0.8078682377233843,
#    'min_samples_leaf': 19},
#   {'n_estimators': 28,
#    'max_samples': 0.31318350307703385,
#    'max_features': 0.7514992394816687,
#    'min_samples_leaf': 3},
#   {'n_estimators': 102,
#    'max_samples': 0.4813644282838866,
#    'max_features': 0.6441724043268969,
#    'min_samples_leaf': 1},
#   {'n_estimators': 60,
#    'max_samples': 0.5065909108635063,
#    'max_features': 0.5672780400167003,
#    'min_samples_leaf': 2},
#   {'n_estimators': 81,
#    'max_samples': 0.8765173697889057,
#    'max_features': 0.21590281008623685,
#    'min_samples_leaf': 1},
#   {'n_estimators': 2,
#    'max_samples': 0.6777743503989394,
#    'max_features': 0.5867393342843417,
#    'min_samples_leaf': 8},
#   {'n_estimators': 17,
#    'max_samples': 0.45181539631496326,
#    'max_features': 0.5747525184268644,
#    'min_samples_leaf': 7},
#   {'n_estimators': 186,
#    'max_samples': 0.22279577730105982,
#    'max_features': 0.670387326345214,
#    'min_samples_leaf': 5},
#   {'n_estimators': 35,
#    'max_samples': 0.7458379890923587,
#    'max_features': 0.6678143437581512,
#    'min_samples_leaf': 29},
#   {'n_estimators': 9,
#    'max_samples': 0.19369868444574972,
#    'max_features': 0.698121876272304,
#    'min_samples_leaf': 8},
#   {'n_estimators': 21,
#    'max_samples': 0.17147743209008795,
#    'max_features': 0.091375337116609,
#    'min_samples_leaf': 19},
#   {'n_estimators': 14,
#    'max_samples': 0.39103440590396865,
#    'max_features': 0.2253235821156386,
#    'min_samples_leaf': 5},
#   {'n_estimators': 5,
#    'max_samples': 0.5671538118174434,
#    'max_features': 0.07423193541260414,
#    'min_samples_leaf': 14},
#   {'n_estimators': 17,
#    'max_samples': 0.5860107231440596,
#    'max_features': 0.8460751331833853,
#    'min_samples_leaf': 10},
#   {'n_estimators': 47,
#    'max_samples': 0.391900377803838,
#    'max_features': 0.326351817405288,
#    'min_samples_leaf': 10},
#   {'n_estimators': 193,
#    'max_samples': 0.6956552708644408,
#    'max_features': 0.5398942465015236,
#    'min_samples_leaf': 12},
#   {'n_estimators': 39,
#    'max_samples': 0.1541281083407067,
#    'max_features': 0.5441819750840143,
#    'min_samples_leaf': 24},
#   {'n_estimators': 13,
#    'max_samples': 0.7210044017385991,
#    'max_features': 0.20088700422610364,
#    'min_samples_leaf': 7},
#   {'n_estimators': 7,
#    'max_samples': 0.5053338426323667,
#    'max_features': 0.7283551624504837,
#    'min_samples_leaf': 4},
#   {'n_estimators': 67,
#    'max_samples': 0.8159049647107562,
#    'max_features': 0.89081892850548,
#    'min_samples_leaf': 3},
#   {'n_estimators': 32,
#    'max_samples': 0.2371744119973757,
#    'max_features': 0.9528593270504564,
#    'min_samples_leaf': 21},
#   {'n_estimators': 48,
#    'max_samples': 0.8578299649387792,
#    'max_features': 0.50491007840844,
#    'min_samples_leaf': 9},
#   {'n_estimators': 6,
#    'max_samples': 0.7797433784471272,
#    'max_features': 0.13132780945347308,
#    'min_samples_leaf': 16},
#   {'n_estimators': 91,
#    'max_samples': 0.7378702279686787,
#    'max_features': 0.04435236149852401,
#    'min_samples_leaf': 4},
#   {'n_estimators': 20,
#    'max_samples': 0.4241227667243672,
#    'max_features': 0.09326060942564661,
#    'min_samples_leaf': 22},
#   {'n_estimators': 50,
#    'max_samples': 0.3749718795922212,
#    'max_features': 0.3871324412205692,
#    'min_samples_leaf': 6},
#   {'n_estimators': 57,
#    'max_samples': 0.564111484926848,
#    'max_features': 0.8834223745536964,
#    'min_samples_leaf': 7},
#   {'n_estimators': 191,
#    'max_samples': 0.8662824619705861,
#    'max_features': 0.208084988639469,
#    'min_samples_leaf': 22},
#   {'n_estimators': 8,
#    'max_samples': 0.8357047376420724,
#    'max_features': 0.37159212880275105,
#    'min_samples_leaf': 18},
#   {'n_estimators': 116,
#    'max_samples': 0.825332860105859,
#    'max_features': 0.7605289144917082,
#    'min_samples_leaf': 4},
#   {'n_estimators': 6,
#    'max_samples': 0.46268216088864533,
#    'max_features': 0.17484828923718324,
#    'min_samples_leaf': 11},
#   {'n_estimators': 27,
#    'max_samples': 0.9780491807739234,
#    'max_features': 0.6189234734780654,
#    'min_samples_leaf': 15},
#   {'n_estimators': 9,
#    'max_samples': 0.8758130340453603,
#    'max_features': 0.8866193309877246,
#    'min_samples_leaf': 7},
#   {'n_estimators': 57,
#    'max_samples': 0.7883288208126958,
#    'max_features': 0.17609669589739194,
#    'min_samples_leaf': 7},
#   {'n_estimators': 32,
#    'max_samples': 0.23173659294602422,
#    'max_features': 0.35915770117695484,
#    'min_samples_leaf': 1},
#   {'n_estimators': 2,
#    'max_samples': 0.2216496602393405,
#    'max_features': 0.9249593560097151,
#    'min_samples_leaf': 8},
#   {'n_estimators': 167,
#    'max_samples': 0.4892480904971188,
#    'max_features': 0.3062253264309966,
#    'min_samples_leaf': 7},
#   {'n_estimators': 36,
#    'max_samples': 0.19509821583556952,
#    'max_features': 0.6187849989556959,
#    'min_samples_leaf': 3},
#   {'n_estimators': 60,
#    'max_samples': 0.6851809831583381,
#    'max_features': 0.1544236104722157,
#    'min_samples_leaf': 1},
#   {'n_estimators': 90,
#    'max_samples': 0.5138203813923882,
#    'max_features': 0.06525560573020199,
#    'min_samples_leaf': 29},
#   {'n_estimators': 4,
#    'max_samples': 0.7255317059726979,
#    'max_features': 0.9444949790002429,
#    'min_samples_leaf': 3},
#   {'n_estimators': 10,
#    'max_samples': 0.209246445480186,
#    'max_features': 0.2981113901892158,
#    'min_samples_leaf': 1},
#   {'n_estimators': 72,
#    'max_samples': 0.15606261831705642,
#    'max_features': 0.4939510217423002,
#    'min_samples_leaf': 30},
#   {'n_estimators': 99,
#    'max_samples': 0.6536974944079098,
#    'max_features': 0.3009409397472811,
#    'min_samples_leaf': 9},
#   {'n_estimators': 47,
#    'max_samples': 0.48347504550133436,
#    'max_features': 0.1341748579031895,
#    'min_samples_leaf': 19},
#   {'n_estimators': 38,
#    'max_samples': 0.2751602606386886,
#    'max_features': 0.3593713833334251,
#    'min_samples_leaf': 5},
#   {'n_estimators': 103,
#    'max_samples': 0.7602529425052619,
#    'max_features': 0.7408396489592728,
#    'min_samples_leaf': 1},
#   {'n_estimators': 34,
#    'max_samples': 0.5332097364717913,
#    'max_features': 0.02823266298190385,
#    'min_samples_leaf': 3},
#   {'n_estimators': 86,
#    'max_samples': 0.22339873515609915,
#    'max_features': 0.518544624879962,
#    'min_samples_leaf': 3},
#   {'n_estimators': 1,
#    'max_samples': 0.3170813118395873,
#    'max_features': 0.9370800671645511,
#    'min_samples_leaf': 15},
#   {'n_estimators': 162,
#    'max_samples': 0.5390686395337262,
#    'max_features': 0.11424938874362832,
#    'min_samples_leaf': 8},
#   {'n_estimators': 38,
#    'max_samples': 0.8599213744656543,
#    'max_features': 0.10317845174503235,
#    'min_samples_leaf': 7},
#   {'n_estimators': 11,
#    'max_samples': 0.39220833420105394,
#    'max_features': 0.7104892235184096,
#    'min_samples_leaf': 6},
#   {'n_estimators': 30,
#    'max_samples': 0.4550286507130318,
#    'max_features': 0.4464744299856873,
#    'min_samples_leaf': 14},
#   {'n_estimators': 126,
#    'max_samples': 0.9598012178535354,
#    'max_features': 0.7575582169425303,
#    'min_samples_leaf': 4},
#   {'n_estimators': 71,
#    'max_samples': 0.4938428116498528,
#    'max_features': 0.2519370909437486,
#    'min_samples_leaf': 16},
#   {'n_estimators': 3,
#    'max_samples': 0.9115857929218811,
#    'max_features': 0.44840359139349745,
#    'min_samples_leaf': 10},
#   {'n_estimators': 66,
#    'max_samples': 0.9056059666358828,
#    'max_features': 0.6148361980588469,
#    'min_samples_leaf': 9},
#   {'n_estimators': 5,
#    'max_samples': 0.5665672197506837,
#    'max_features': 0.15266055077618956,
#    'min_samples_leaf': 12},
#   {'n_estimators': 45,
#    'max_samples': 0.712205001287518,
#    'max_features': 0.049589255572265054,
#    'min_samples_leaf': 1},
#   {'n_estimators': 76,
#    'max_samples': 0.16487590239880603,
#    'max_features': 0.07769389137699566,
#    'min_samples_leaf': 1}]}

# %%
optimization_metric = roc_auc_score
j=0
best_random_exp = {
    'Random Forest': {'diabetes': None,'students': None,'telco': None,'pistachio': None},
    'Decision Tree': {'diabetes': None,'students': None,'telco': None,'pistachio': None},
    'Logistic Regression' : {'diabetes': None,'students': None,'telco': None,'pistachio': None}
}

best_random_exp_history = {
    'Random Forest': {'diabetes': [],'students': [],'telco': [],'pistachio':  []},
    'Decision Tree': {'diabetes': [],'students': [],'telco': [],'pistachio': []},
    'Logistic Regression' : {'diabetes': [],'students': [],'telco': [],'pistachio': []}
}

best_random_exp_history_params = {
    'Random Forest': {'diabetes': [],'students': [],'telco': [],'pistachio':  []},
    'Decision Tree': {'diabetes': [],'students': [],'telco': [],'pistachio': []},
    'Logistic Regression' : {'diabetes': [],'students': [],'telco': [],'pistachio': []}
}
random_exp_history = {
    'Random Forest': {'diabetes': [],'students': [],'telco': [],'pistachio':  []},
    'Decision Tree': {'diabetes': [],'students': [],'telco': [],'pistachio': []},
    'Logistic Regression' : {'diabetes': [],'students': [],'telco': [],'pistachio': []}
}
def optimize_exp(model, param_samples):
    i = 0
    for dataset in datasets_wanted_size.keys():
        best_score = float('-inf')
        best_params = []
        for params in param_samples:
            
            estimator = models[model]()
            estimator.set_params(**params)
            pipe = Pipeline([("trans",col_trans),("model",estimator)])
            scores = cross_val_score(Pipeline([("trans",col_trans),("model",models[model]().set_params(**params))]), datasets_X_train[dataset], datasets_y_train[dataset], cv=3, scoring='roc_auc')  

            mean_score = scores.mean()
            std_score = scores.std()
            # estimator.fit(datasets_X_train[dataset], datasets_y_train[dataset]
            # y_pred = estimator.predict(datasets_X_test[dataset])
            # score = optimization_metric(datasets_y_test[dataset], y_pred)
            random_exp_history[model][dataset].append(mean_score)
            if mean_score > best_score:
                best_score = mean_score
                best_params = params
                best_random_exp[model][dataset] = Pipeline([("trans",copy.deepcopy(col_trans)),("model",models[model]().set_params(**params))])
                best_random_exp[model][dataset].fit(datasets_X_train[dataset], datasets_y_train[dataset])
            best_random_exp_history[model][dataset].append(best_score)
            best_random_exp_history_params[model][dataset].append(best_params)
            i+=1
            # print(i,j)

# %%
optimize_exp('Decision Tree', param_samples_exp['Decision Tree'])

# %%
optimize_exp('Random Forest', param_samples_exp['Random Forest'])

# %%
optimize_exp('Logistic Regression', param_samples_exp['Logistic Regression'])

# %%
save_models(best_random_exp, '.\\Wyniki\\RandomSearchExp')

# %%
for model in models.keys():
    for dataset in datasets_wanted_size.keys():
        print(model,dataset)
        print(np.mean(random_exp_history[model][dataset]))
        print(np.std(random_exp_history[model][dataset]))

# %%
# ile iteracji każdej metody potrzebujemy żeby uzyskać stabilne wyniki optymalizacji
def best_metric_so_far_exp(model):
    kolory = {
        'diabetes': 'red',
        'students': 'green',
        'telco': 'blue',
        'pistachio': 'purple'
    }
    for key  in best_random_exp_history[model].keys():
        plt.plot(best_random_exp_history[model][key],label = key,c = kolory[key])
    plt.legend()
    plt.title(f'{model}: best roc_auc_score')
    # plt.xticks([i for i in range(n_iter)], labels=[i+1 for i in range(n_iter)])
    plt.show()
    return

def chart_exp_dist():
    for i,key  in enumerate(best_random_exp_history.keys()):
        # print(i,key)
        plt.subplot(3, 1, i+1)
        best_metric_so_far_exp(key)
    return
chart_exp_dist()

# %% [markdown]
# # Critical difference diagrams

# %%
# jakies gówno mozna babeczki o to spytac bo dziwne wyniki daje i python sie wywala xd

# %%
example_df = pd.DataFrame(data = None, columns=['classifier_name','dataset_name','accuracy'])
for model,scores in best_scores_bayes.items():
    # print(model, scores)

    for dataset, score in scores.items():
        example_df = example_df._append({'classifier_name':model+' B','dataset_name':dataset,'accuracy':score},ignore_index=True)

for model,scores in best_scores_random.items():
    # print(model, scores)

    for dataset, score in scores.items():
        example_df = example_df._append({'classifier_name':model+' R','dataset_name':dataset,'accuracy':score},ignore_index=True)


for model,scores in best_scores_random_exp.items():
    # print(model, scores)
    for dataset, score in scores.items():
        example_df = example_df._append({'classifier_name':model+' RE','dataset_name':dataset,'accuracy':score},ignore_index=True)

example_df.to_csv('example.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 15
#      11     for dataset, score in scores.items():
#      12         example_df = example_df._append({'classifier_name':model+' R','dataset_name':dataset,'accuracy':score},ignore_index=True)
# ---> 15 for model,scores in best_scores_random_exp.items():
#      16     # print(model, scores)
#      17     for dataset, score in scores.items():
#      18         example_df = example_df._append({'classifier_name':model+' RE','dataset_name':dataset,'accuracy':score},ignore_index=True)
#
# NameError: name 'best_scores_random_exp' is not defined

# %%
# Author: Hassan Ismail Fawaz <hassan.ismail-fawaz@uha.fr>
#         Germain Forestier <germain.forestier@uha.fr>
#         Jonathan Weber <jonathan.weber@uha.fr>
#         Lhassane Idoumghar <lhassane.idoumghar@uha.fr>
#         Pierre-Alain Muller <pierre-alain.muller@uha.fr>
# License: GPL3

import numpy as np
import pandas as pd
import matplotlib

matplotlib.use('agg')
import matplotlib.pyplot as plt

matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['font.sans-serif'] = 'Arial'

import operator
import math
from scipy.stats import wilcoxon
from scipy.stats import friedmanchisquare
import networkx

# inspired from orange3 https://docs.orange.biolab.si/3/data-mining-library/reference/evaluation.cd.html
def graph_ranks(avranks, names, p_values, cd=None, cdmethod=None, lowv=None, highv=None,
                width=6, textspace=1, reverse=False, filename=None, labels=False, **kwargs):
    """
    Draws a CD graph, which is used to display  the differences in methods'
    performance. See Janez Demsar, Statistical Comparisons of Classifiers over
    Multiple Data Sets, 7(Jan):1--30, 2006.

    Needs matplotlib to work.

    The image is ploted on `plt` imported using
    `import matplotlib.pyplot as plt`.

    Args:
        avranks (list of float): average ranks of methods.
        names (list of str): names of methods.
        cd (float): Critical difference used for statistically significance of
            difference between methods.
        cdmethod (int, optional): the method that is compared with other methods
            If omitted, show pairwise comparison of methods
        lowv (int, optional): the lowest shown rank
        highv (int, optional): the highest shown rank
        width (int, optional): default width in inches (default: 6)
        textspace (int, optional): space on figure sides (in inches) for the
            method names (default: 1)
        reverse (bool, optional):  if set to `True`, the lowest rank is on the
            right (default: `False`)
        filename (str, optional): output file name (with extension). If not
            given, the function does not write a file.
        labels (bool, optional): if set to `True`, the calculated avg rank
        values will be displayed
    """
    try:
        import matplotlib
        import matplotlib.pyplot as plt
        from matplotlib.backends.backend_agg import FigureCanvasAgg
    except ImportError:
        raise ImportError("Function graph_ranks requires matplotlib.")

    width = float(width)
    textspace = float(textspace)

    def nth(l, n):
        """
        Returns only nth elemnt in a list.
        """
        n = lloc(l, n)
        return [a[n] for a in l]

    def lloc(l, n):
        """
        List location in list of list structure.
        Enable the use of negative locations:
        -1 is the last element, -2 second last...
        """
        if n < 0:
            return len(l[0]) + n
        else:
            return n

    def mxrange(lr):
        """
        Multiple xranges. Can be used to traverse matrices.
        This function is very slow due to unknown number of
        parameters.

        >>> mxrange([3,5])
        [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)]

        >>> mxrange([[3,5,1],[9,0,-3]])
        [(3, 9), (3, 6), (3, 3), (4, 9), (4, 6), (4, 3)]

        """
        if not len(lr):
            yield ()
        else:
            # it can work with single numbers
            index = lr[0]
            if isinstance(index, int):
                index = [index]
            for a in range(*index):
                for b in mxrange(lr[1:]):
                    yield tuple([a] + list(b))

    def print_figure(fig, *args, **kwargs):
        canvas = FigureCanvasAgg(fig)
        canvas.print_figure(*args, **kwargs)

    sums = avranks

    nnames = names
    ssums = sums

    if lowv is None:
        lowv = min(1, int(math.floor(min(ssums))))
    if highv is None:
        highv = max(len(avranks), int(math.ceil(max(ssums))))

    cline = 0.4

    k = len(sums)

    lines = None

    linesblank = 0
    scalewidth = width - 2 * textspace

    def rankpos(rank):
        if not reverse:
            a = rank - lowv
        else:
            a = highv - rank
        return textspace + scalewidth / (highv - lowv) * a

    distanceh = 0.25

    cline += distanceh

    # calculate height needed height of an image
    minnotsignificant = max(2 * 0.2, linesblank)
    height = cline + ((k + 1) / 2) * 0.2 + minnotsignificant

    fig = plt.figure(figsize=(width, height))
    fig.set_facecolor('white')
    ax = fig.add_axes([0, 0, 1, 1])  # reverse y axis
    ax.set_axis_off()

    hf = 1. / height  # height factor
    wf = 1. / width

    def hfl(l):
        return [a * hf for a in l]

    def wfl(l):
        return [a * wf for a in l]

    # Upper left corner is (0,0).
    ax.plot([0, 1], [0, 1], c="w")
    ax.set_xlim(0, 1)
    ax.set_ylim(1, 0)

    def line(l, color='k', **kwargs):
        """
        Input is a list of pairs of points.
        """
        ax.plot(wfl(nth(l, 0)), hfl(nth(l, 1)), color=color, **kwargs)

    def text(x, y, s, *args, **kwargs):
        ax.text(wf * x, hf * y, s, *args, **kwargs)

    line([(textspace, cline), (width - textspace, cline)], linewidth=2)

    bigtick = 0.3
    smalltick = 0.15
    linewidth = 2.0
    linewidth_sign = 4.0

    tick = None
    for a in list(np.arange(lowv, highv, 0.5)) + [highv]:
        tick = smalltick
        if a == int(a):
            tick = bigtick
        line([(rankpos(a), cline - tick / 2),
              (rankpos(a), cline)],
             linewidth=2)

    for a in range(lowv, highv + 1):
        text(rankpos(a), cline - tick / 2 - 0.05, str(a),
             ha="center", va="bottom", size=16)

    k = len(ssums)

    def filter_names(name):
        return name

    space_between_names = 0.24

    for i in range(math.ceil(k / 2)):
        chei = cline + minnotsignificant + i * space_between_names
        line([(rankpos(ssums[i]), cline),
              (rankpos(ssums[i]), chei),
              (textspace - 0.1, chei)],
             linewidth=linewidth)
        if labels:
            text(textspace + 0.3, chei - 0.075, format(ssums[i], '.4f'), ha="right", va="center", size=10)
        text(textspace - 0.2, chei, filter_names(nnames[i]), ha="right", va="center", size=16)

    for i in range(math.ceil(k / 2), k):
        chei = cline + minnotsignificant + (k - i - 1) * space_between_names
        line([(rankpos(ssums[i]), cline),
              (rankpos(ssums[i]), chei),
              (textspace + scalewidth + 0.1, chei)],
             linewidth=linewidth)
        if labels:
            text(textspace + scalewidth - 0.3, chei - 0.075, format(ssums[i], '.4f'), ha="left", va="center", size=10)
        text(textspace + scalewidth + 0.2, chei, filter_names(nnames[i]),
             ha="left", va="center", size=16)

    # no-significance lines
    def draw_lines(lines, side=0.05, height=0.1):
        start = cline + 0.2

        for l, r in lines:
            line([(rankpos(ssums[l]) - side, start),
                  (rankpos(ssums[r]) + side, start)],
                 linewidth=linewidth_sign)
            start += height
            print('drawing: ', l, r)

    # draw_lines(lines)
    start = cline + 0.2
    side = -0.02
    height = 0.1

    # draw no significant lines
    # get the cliques
    cliques = form_cliques(p_values, nnames)
    i = 1
    achieved_half = False
    print(nnames)
    for clq in cliques:
        if len(clq) == 1:
            continue
        print(clq)
        min_idx = np.array(clq).min()
        max_idx = np.array(clq).max()
        if min_idx >= len(nnames) / 2 and achieved_half == False:
            start = cline + 0.25
            achieved_half = True
        line([(rankpos(ssums[min_idx]) - side, start),
              (rankpos(ssums[max_idx]) + side, start)],
             linewidth=linewidth_sign)
        start += height


def form_cliques(p_values, nnames):
    """
    This method forms the cliques
    """
    # first form the numpy matrix data
    m = len(nnames)
    g_data = np.zeros((m, m), dtype=np.int64)
    for p in p_values:
        if p[3] == False:
            i = np.where(nnames == p[0])[0][0]
            j = np.where(nnames == p[1])[0][0]
            min_i = min(i, j)
            max_j = max(i, j)
            g_data[min_i, max_j] = 1

    g = networkx.Graph(g_data)
    return networkx.find_cliques(g)


def draw_cd_diagram(df_perf=None, alpha=0.05, title=None, labels=False):
    """
    Draws the critical difference diagram given the list of pairwise classifiers that are
    significant or not
    """
    p_values, average_ranks, _ = wilcoxon_holm(df_perf=df_perf, alpha=alpha)

    print(average_ranks)

    for p in p_values:
        print(p)


    graph_ranks(average_ranks.values, average_ranks.keys(), p_values,
                cd=None, reverse=True, width=9, textspace=1.5, labels=labels)

    font = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'normal',
        'size': 22,
        }
    if title:
        plt.title(title,fontdict=font, y=0.9, x=0.5)
    plt.savefig('cd-diagram.png',bbox_inches='tight')

def wilcoxon_holm(alpha=0.05, df_perf=None):
    """
    Applies the wilcoxon signed rank test between each pair of algorithm and then use Holm
    to reject the null's hypothesis
    """
    print(pd.unique(df_perf['classifier_name']))
    # count the number of tested datasets per classifier
    df_counts = pd.DataFrame({'count': df_perf.groupby(
        ['classifier_name']).size()}).reset_index()
    # get the maximum number of tested datasets
    max_nb_datasets = df_counts['count'].max()
    # get the list of classifiers who have been tested on nb_max_datasets
    classifiers = list(df_counts.loc[df_counts['count'] == max_nb_datasets]
                       ['classifier_name'])
    # test the null hypothesis using friedman before doing a post-hoc analysis
    friedman_p_value = friedmanchisquare(*(
        np.array(df_perf.loc[df_perf['classifier_name'] == c]['accuracy'])
        for c in classifiers))[1]
    if friedman_p_value >= alpha:
        # then the null hypothesis over the entire classifiers cannot be rejected
        print('the null hypothesis over the entire classifiers cannot be rejected')
        exit()
    # get the number of classifiers
    m = len(classifiers)
    # init array that contains the p-values calculated by the Wilcoxon signed rank test
    p_values = []
    # loop through the algorithms to compare pairwise
    for i in range(m - 1):
        # get the name of classifier one
        classifier_1 = classifiers[i]
        # get the performance of classifier one
        perf_1 = np.array(df_perf.loc[df_perf['classifier_name'] == classifier_1]['accuracy']
                          , dtype=np.float64)
        for j in range(i + 1, m):
            # get the name of the second classifier
            classifier_2 = classifiers[j]
            # get the performance of classifier one
            perf_2 = np.array(df_perf.loc[df_perf['classifier_name'] == classifier_2]
                              ['accuracy'], dtype=np.float64)
            # calculate the p_value
            p_value = wilcoxon(perf_1, perf_2, zero_method='pratt')[1]
            # appen to the list
            p_values.append((classifier_1, classifier_2, p_value, False))
    # get the number of hypothesis
    k = len(p_values)
    # sort the list in acsending manner of p-value
    p_values.sort(key=operator.itemgetter(2))

    # loop through the hypothesis
    for i in range(k):
        # correct alpha with holm
        new_alpha = float(alpha / (k - i))
        # test if significant after holm's correction of alpha
        if p_values[i][2] <= new_alpha:
            p_values[i] = (p_values[i][0], p_values[i][1], p_values[i][2], True)
        else:
            # stop
            break
    # compute the average ranks to be returned (useful for drawing the cd diagram)
    # sort the dataframe of performances
    sorted_df_perf = df_perf.loc[df_perf['classifier_name'].isin(classifiers)]. \
        sort_values(['classifier_name', 'dataset_name'])
    # get the rank data
    rank_data = np.array(sorted_df_perf['accuracy']).reshape(m, max_nb_datasets)

    # create the data frame containg the accuracies
    df_ranks = pd.DataFrame(data=rank_data, index=np.sort(classifiers), columns=
    np.unique(sorted_df_perf['dataset_name']))

    # number of wins
    dfff = df_ranks.rank(ascending=False)
    print(dfff[dfff == 1.0].sum(axis=1))

    # average the ranks
    average_ranks = df_ranks.rank(ascending=False).mean(axis=1).sort_values(ascending=False)
    # return the p-values and the average ranks
    return p_values, average_ranks, max_nb_datasets


df_perf = pd.read_csv('example.csv', index_col=False)

draw_cd_diagram(df_perf=df_perf, title='Roc Auc', labels=True)

# %% [markdown]
# # Model tunability

# %%
import json

def save_dict_to_txt(data, filepath):

    with open(filepath, 'w', encoding='utf-8') as file:
        json.dump(data, file, ensure_ascii=False, indent=4) 
    
    print(f"Słownik zapisano w {filepath}")

# %%
from sklearn.metrics import log_loss
from sklearn.metrics import roc_auc_score

criterion = roc_auc_score

best_scores_random = {}
deafult_scores = {}
tunability_random = {}

# %%
# loss dla deafult modeli

for model in models.keys():
    deafult_model = Pipeline([("trans",col_trans),("model",models[model]())])
    deafult_scores[model] = {}
    for dataset in datasets_wanted_size.keys():
        deafult_model.fit(datasets_X_train[dataset] , datasets_y_train[dataset])
        deafult_scores[model][dataset] =  criterion(datasets_y_test[dataset] , deafult_model.predict(datasets_X_test[dataset]))

save_dict_to_txt(deafult_scores,'.\\Wyniki\\ScoreModeli\\default.txt')
# Out:
# Słownik zapisano w .\Wyniki\ScoreModeli\default.txt

# %%
# tunability random

for model in models.keys():
    best_scores_random[model] = {}
    for dataset in datasets_wanted_size.keys():
        best_scores_random[model][dataset] =  criterion(
            datasets_y_test[dataset],
            best_random[model][dataset].predict(datasets_X_test[dataset])
            )

save_dict_to_txt(best_scores_random,'.\\Wyniki\\ScoreModeli\\RandomSearch.txt')

tunability_random = {}
for model in models.keys():
    tunability_random[model] = {}
    for dataset in datasets_wanted_size.keys():
        tunability_random[model][dataset] = deafult_scores[model][dataset] - best_scores_random[model][dataset]
    
save_dict_to_txt(tunability_random,'.\\Wyniki\\TunabilityModeli\\RandomSearch.txt')
# Out:
# Słownik zapisano w .\Wyniki\ScoreModeli\RandomSearch.txt
# Słownik zapisano w .\Wyniki\TunabilityModeli\RandomSearch.txt

# %%
# tunability random exp
criterion = roc_auc_score

best_scores_random_exp = {}
tunability_random_exp = {}

for model in models.keys():
    best_scores_random_exp[model] = {}
    for dataset in datasets_wanted_size.keys():
        best_scores_random_exp[model][dataset] =  criterion(
            datasets_y_test[dataset],
            best_random_exp[model][dataset].predict(datasets_X_test[dataset])
            )

save_dict_to_txt(best_scores_random_exp,'.\\Wyniki\\ScoreModeli\\RandomSearchExp.txt')

for model in models.keys():
    tunability_random_exp[model] = {}
    for dataset in datasets_wanted_size.keys():
        tunability_random_exp[model][dataset] = deafult_scores[model][dataset] - best_scores_random_exp[model][dataset]
        
save_dict_to_txt(tunability_random_exp,'.\\Wyniki\\TunabilityModeli\\RandomSearchExp.txt')
# Out:
# Słownik zapisano w .\Wyniki\ScoreModeli\RandomSearchExp.txt
# Słownik zapisano w .\Wyniki\TunabilityModeli\RandomSearchExp.txt

# %%
# tunability bayes
criterion = roc_auc_score

best_scores_bayes = {}
tunability_bayes = {}

for model in models.keys():
    best_scores_bayes[model] = {}
    for dataset in datasets_wanted_size.keys():
        best_scores_bayes[model][dataset] =  criterion(
            datasets_y_test[dataset],
            best_bayes[model][dataset].predict(datasets_X_test[dataset])
            )
save_dict_to_txt(best_scores_bayes,'.\\Wyniki\\ScoreModeli\\BayesSearch.txt')


for model in models.keys():
    tunability_bayes[model] = {}
    for dataset in datasets_wanted_size.keys():
        tunability_bayes[model][dataset] = deafult_scores[model][dataset] - best_scores_bayes[model][dataset]

save_dict_to_txt(tunability_bayes,'.\\Wyniki\\TunabilityModeli\\BayesSearch.txt')
# Out:
# Słownik zapisano w .\Wyniki\ScoreModeli\BayesSearch.txt
# Słownik zapisano w .\Wyniki\TunabilityModeli\BayesSearch.txt

# %%
from sklearn.metrics import log_loss

criterion = roc_auc_score

def randomSearchForSingleParam(model,param,n_iter=n_iter):
    best_random_history = {key: [] for key in datasets_wanted_size.keys()}
    best_random_param = {key: None for key in datasets_wanted_size.keys()}

    param_distributions_for_param  = {param: param_distributions[model][param]}
    param_samples_for_param = list(ParameterSampler(param_distributions_for_param, n_iter=n_iter, random_state=seed))
       
    for dataset in datasets_wanted_size.keys():
        best_score = float('-inf')
        for params in param_samples_for_param:
            
            estimator = models[model]()
            estimator.set_params(**params)
            pipe = Pipeline([("trans",col_trans),("model",estimator)])
            scores = cross_val_score(Pipeline([("trans",col_trans),("model",models[model]().set_params(**params))]), datasets_X_train[dataset], datasets_y_train[dataset], cv=3, scoring='roc_auc')  

            mean_score = scores.mean()
            std_score = scores.std()
            if mean_score > best_score:
                best_score = mean_score
                best_params = params
            best_random_history[dataset].append(best_score)
        best_random_param[dataset] = best_params
    return best_random_param,best_random_history

def tunabilityForSingleParamSingleDataset(model,params):
    # param w postaci np.{'diabetes': {'n_estimators': 1127},
#                         'students': {'n_estimators': 1127},
#                         'telco': {'n_estimators': 1131},
#                         'pistachio': {'n_estimators': 861}},

    res = {dataset: None for dataset in params.keys()}

    for dataset in params.keys():
        best_param_model = Pipeline([("trans",copy.deepcopy(col_trans)),("model",models[model]().set_params(**params[dataset]))])
        best_param_model.fit(datasets_X_train[dataset], datasets_y_train[dataset])
        best_scores =  criterion(datasets_y_test[dataset],best_param_model.predict(datasets_X_test[dataset]))

        deafult_model = Pipeline([("trans",col_trans),("model",models[model]())])
        deafult_model.fit(datasets_X_train[dataset] , datasets_y_train[dataset])
        deafult_scores =  criterion(datasets_y_test[dataset] , deafult_model.predict(datasets_X_test[dataset]))
        res[dataset] = (deafult_scores - best_scores)
    return res

# %%
# randomSearchForSingleParam('Random Forest', 'n_estimators')
# ({'diabetes': {'n_estimators': 1127},
#   'students': {'n_estimators': 1127},
#   'telco': {'n_estimators': 1131},
#   'pistachio': {'n_estimators': 861}},
#  {'diabetes': [0.9299126754526946,
#    0.9299126754526946,
#    0.9299126754526946,
#    0.9299126754526946,
#    0.9299126754526946],
#   'students': [0.9471904063242688,
#    0.9471904063242688,
#    0.9471904063242688,
#    0.9471904063242688,
#    0.9471904063242688],
#   'telco': [0.8314294271167588,
#    0.8314294271167588,
#    0.8334884268172679,
#    0.8334884268172679,
#    0.8337290891199247],
#   'pistachio': [0.9559172555668348,
#    0.9559172555668348,
#    0.9560065384295608,
#    0.9560065384295608,
#    0.9560065384295608]})
# Out:
# [{'n_estimators': 1127}, {'n_estimators': 1460}, {'n_estimators': 861}, {'n_estimators': 1295}, {'n_estimators': 1131}]
# ({'diabetes': {'n_estimators': 1127},
#   'students': {'n_estimators': 1127},
#   'telco': {'n_estimators': 1131},
#   'pistachio': {'n_estimators': 861}},
#  {'diabetes': [0.9299126754526946,
#    0.9299126754526946,
#    0.9299126754526946,
#    0.9299126754526946,
#    0.9299126754526946],
#   'students': [0.9471904063242688,
#    0.9471904063242688,
#    0.9471904063242688,
#    0.9471904063242688,
#    0.9471904063242688],
#   'telco': [0.8314294271167588,
#    0.8314294271167588,
#    0.8334884268172679,
#    0.8334884268172679,
#    0.8337290891199247],
#   'pistachio': [0.9559172555668348,
#    0.9559172555668348,
#    0.9560065384295608,
#    0.9560065384295608,
#    0.9560065384295608]})

# %%
# tunabilityForSingleParamSingleDataset('Random Forest', {'diabetes': {'n_estimators': 1127},
#   'students': {'n_estimators': 1127},
#   'telco': {'n_estimators': 1131},
#   'pistachio': {'n_estimators': 861}})
# Out:
# {'diabetes': -0.0018181818181818299,
#  'students': 0.0015412638363457853,
#  'telco': -0.017045454545454475,
#  'pistachio': 0.008720930232558044}

# %%
# tunability poszczególnych hiperparam
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def chart_2(parametry,wartosci):
    # Przykładowe dane:
    # parametry = ['param1', 'param2', 'param3', 'param4'], parametry to mogą być nazwy modeli wyjdzie na to samo
    # wartosci = [
    #     {'diabetes': -0.0018, 'students': 0.0015, 'telco': -0.017, 'pistachio': 0.0087},
    #     {'diabetes': -0.005, 'students': 0.0021, 'telco': -0.013, 'pistachio': 0.0103},
    #     {'diabetes': -0.003, 'students': 0.0019, 'telco': -0.015, 'pistachio': 0.0098},
    #     {'diabetes': -0.0042, 'students': 0.0017, 'telco': -0.016, 'pistachio': 0.0112}
    # ]

    # Przekształć dane na DataFrame
    dane = []
    for param, slownik in zip(parametry, wartosci):
        for klucz, wartosc in slownik.items():
            dane.append({'Parametr': param, 'Klucz': klucz, 'Wartość': wartosc})
    df = pd.DataFrame(dane)

    # Definiowanie kolorów dla kluczy
    kolory = {
        'diabetes': 'red',
        'students': 'green',
        'telco': 'blue',
        'pistachio': 'purple'
    }

    # Tworzenie wykresu
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='Parametr', y='Wartość', data=df,color='white',showcaps = False) 
    sns.stripplot(
        x='Parametr', 
        y='Wartość', 
        hue='Klucz', 
        data=df, 
        palette=kolory, 
        dodge=True,  # Oddziel punkty dla różnych kluczy
        # jitter=True  # Rozproszenie punktów wzdłuż osi X dla lepszej widoczności,
    )
    plt.xlabel('')
    plt.axhline(y=0, color='r', linestyle='-')
    # Dostosowanie legendy
    plt.legend(title='Klucz', loc='upper left', bbox_to_anchor=(1, 1))
    plt.title('Tunability dla różnych parametrów/modeli')
    plt.show()

parametry = ['param1', 'param2', 'param3', 'param4']
wartosci = [
    {'diabetes': -0.0018, 'students': 0.0015, 'telco': -0.017, 'pistachio': 0.0087},
    {'diabetes': -0.005, 'students': 0.0021, 'telco': -0.013, 'pistachio': 0.0103},
    {'diabetes': -0.003, 'students': 0.0019, 'telco': -0.015, 'pistachio': 0.0098},
    {'diabetes': -0.0042, 'students': 0.0017, 'telco': -0.016, 'pistachio': 0.0112}
]
# chart_2(parametry,wartosci)

# %%
# tunability random chart
l1 = []
l2 = []
for key,val in tunability_random.items():
    l1.append(key)
    l2.append(val)
chart_2(l1,l2)
tunability_random
# Out:
# {'Decision Tree': {'diabetes': -0.0018181818181818299,
#   'students': 0.005674653215636871,
#   'telco': 0.040909090909091006,
#   'pistachio': -0.02316497093023251},
#  'Random Forest': {'diabetes': 0.020000000000000018,
#   'students': 0.025290738405492563,
#   'telco': 0.05340909090909096,
#   'pistachio': 0.0},
#  'Logistic Regression': {'diabetes': -0.03454545454545466,
#   'students': -0.015552753257671359,
#   'telco': 0.006249999999999978,
#   'pistachio': 0.0009992732558139483}}

# %%
# tunability random exp chart

l1 = []
l2 = []
for key,val in tunability_random_exp.items():
    l1.append(key)
    l2.append(val)
chart_2(l1,l2)

print(deafult_scores)
print(best_scores_random_exp)
# Out:
# {'Decision Tree': {'diabetes': 0.8781818181818182, 'students': 0.8727056186072579, 'telco': 0.709659090909091, 'pistachio': 0.8033248546511628}, 'Random Forest': {'diabetes': 0.88, 'students': 0.913689225164635, 'telco': 0.7477272727272728, 'pistachio': 0.8490188953488373}, 'Logistic Regression': {'diabetes': 0.76, 'students': 0.8926719910326467, 'telco': 0.7329545454545454, 'pistachio': 0.8754542151162791}}
# {'Decision Tree': {'diabetes': 0.8727272727272727, 'students': 0.902760263416001, 'telco': 0.7397727272727272, 'pistachio': 0.8148619186046512}, 'Random Forest': {'diabetes': 0.76, 'students': 0.8969454953061511, 'telco': 0.7107954545454546, 'pistachio': 0.8519258720930233}, 'Logistic Regression': {'diabetes': 0.7945454545454547, 'students': 0.9039512400168138, 'telco': 0.7295454545454546, 'pistachio': 0.8734556686046512}}

# %%
# tunability bayes chart
l1 = []
l2 = []
for key,val in tunability_bayes.items():
    l1.append(key)
    l2.append(val)
chart_2(l1,l2)
