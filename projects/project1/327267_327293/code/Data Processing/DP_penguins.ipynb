# %% [markdown]
# # Data processing for penguins dataset

# %%
import pandas as pd

data = pd.read_csv("../../data/penguins.csv")

# %%
data.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
# 5  Adelie  Torgersen            38.9           17.8              181.0
# 6  Adelie  Torgersen            39.2           19.6              195.0
# 7  Adelie  Torgersen            34.1           18.1              193.0
# 8  Adelie  Torgersen            42.0           20.2              190.0
# 9  Adelie  Torgersen            37.8           17.1              186.0
#
#    body_mass_g  year
# 0       3750.0  2007
# 1       3800.0  2007
# 2       3250.0  2007
# 3       3450.0  2007
# 4       3650.0  2007
# 5       3625.0  2007
# 6       4675.0  2007
# ...

# %%
data['species'] = data['species'].map({
    'Adelie' : 1,
    'Gentoo' : 0
})
data.head(10)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0        1  Torgersen            39.1           18.7              181.0
# 1        1  Torgersen            39.5           17.4              186.0
# 2        1  Torgersen            40.3           18.0              195.0
# 3        1  Torgersen            36.7           19.3              193.0
# 4        1  Torgersen            39.3           20.6              190.0
# 5        1  Torgersen            38.9           17.8              181.0
# 6        1  Torgersen            39.2           19.6              195.0
# 7        1  Torgersen            34.1           18.1              193.0
# 8        1  Torgersen            42.0           20.2              190.0
# 9        1  Torgersen            37.8           17.1              186.0
#
#    body_mass_g  year
# 0       3750.0  2007
# 1       3800.0  2007
# 2       3250.0  2007
# 3       3450.0  2007
# 4       3650.0  2007
# 5       3625.0  2007
# ...

# %%
data_columns = data.columns.tolist()
data_columns
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'year']

# %%
df = data[(data_columns[1:data.shape[1]] + [data_columns[0]])]
df.head(10)
# Out:
#       island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Torgersen            39.1           18.7              181.0       3750.0
# 1  Torgersen            39.5           17.4              186.0       3800.0
# 2  Torgersen            40.3           18.0              195.0       3250.0
# 3  Torgersen            36.7           19.3              193.0       3450.0
# 4  Torgersen            39.3           20.6              190.0       3650.0
# 5  Torgersen            38.9           17.8              181.0       3625.0
# 6  Torgersen            39.2           19.6              195.0       4675.0
# 7  Torgersen            34.1           18.1              193.0       3475.0
# 8  Torgersen            42.0           20.2              190.0       4250.0
# 9  Torgersen            37.8           17.1              186.0       3300.0
#
#    year  species
# 0  2007        1
# 1  2007        1
# 2  2007        1
# 3  2007        1
# 4  2007        1
# 5  2007        1
# ...

# %% [markdown]
# ## Check

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

r = 6
c = 4

plt.figure(figsize=(13, 13))

for i, column in enumerate(['species']):
    plt.subplot(r, c, i+1)
    dis_dist = sns.distplot(df[column], bins=20)
    dis_dist.set_title(f'{column}')  

plt.tight_layout() 
plt.show()

# %% [markdown]
# ## Save

# %%
df.to_csv("../../data/processed/penguins.csv", index=False)

# %% [markdown]
# ## Double Check

# %%
import pandas as pd
data = pd.read_csv("../../data/processed/penguins.csv")
data.head()
# Out:
#       island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Torgersen            39.1           18.7              181.0       3750.0
# 1  Torgersen            39.5           17.4              186.0       3800.0
# 2  Torgersen            40.3           18.0              195.0       3250.0
# 3  Torgersen            36.7           19.3              193.0       3450.0
# 4  Torgersen            39.3           20.6              190.0       3650.0
#
#    year  species
# 0  2007        1
# 1  2007        1
# 2  2007        1
# 3  2007        1
# 4  2007        1
